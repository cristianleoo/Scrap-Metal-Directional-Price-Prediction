# %% [markdown]
# # FRED API

# %% [markdown]
# ## Ferrous Metals - Daily

# %%
import requests
import pandas as pd

# %%
api_key = '6345687e2d64e031d2517c3a78d0dbbb'

# %%
url = 'https://api.stlouisfed.org/fred/series/observations'
params = {'series_id': 'WPU10121501',
           'observation_start': '2018-01-01',
          'observation_end': '2023-10-01',
          'api_key': api_key,
          'file_type':'json'}
response = requests.get(url, params = params)

# %%
response.status_code
# Out:
# 200

# %%
df_ferrous_price = pd.DataFrame(response.json()['observations'])
df_ferrous_price
# Out:
#    realtime_start realtime_end        date    value
# 0      2023-10-17   2023-10-17  2018-01-01    118.3
# 1      2023-10-17   2023-10-17  2018-02-01    120.1
# 2      2023-10-17   2023-10-17  2018-03-01    125.5
# 3      2023-10-17   2023-10-17  2018-04-01    131.3
# 4      2023-10-17   2023-10-17  2018-05-01    128.6
# ..            ...          ...         ...      ...
# 63     2023-10-17   2023-10-17  2023-04-01  123.329
# 64     2023-10-17   2023-10-17  2023-05-01  117.179
# 65     2023-10-17   2023-10-17  2023-06-01   99.916
# 66     2023-10-17   2023-10-17  2023-07-01  101.282
# 67     2023-10-17   2023-10-17  2023-08-01   96.716
#
# [68 rows x 4 columns]

# %%
df_ferrous_price.to_csv('df_ferrous_price.csv', index = False)

# %% [markdown]
# ## Non-Ferrous Metals - Daily

# %%
params1 = {'series_id': 'WPS102',
           'observation_start': '2018-01-01',
          'observation_end': '2023-10-01',
          'api_key': api_key,
          'file_type':'json'}
response1 = requests.get(url, params = params1)

# %%
response1.status_code
# Out:
# 200

# %%
df_nonferrous_price = pd.DataFrame(response1.json()['observations'])
df_nonferrous_price
# Out:
#    realtime_start realtime_end        date    value
# 0      2023-10-17   2023-10-17  2018-01-01    247.9
# 1      2023-10-17   2023-10-17  2018-02-01    248.3
# 2      2023-10-17   2023-10-17  2018-03-01    249.0
# 3      2023-10-17   2023-10-17  2018-04-01    249.7
# 4      2023-10-17   2023-10-17  2018-05-01    252.5
# ..            ...          ...         ...      ...
# 64     2023-10-17   2023-10-17  2023-05-01  333.262
# 65     2023-10-17   2023-10-17  2023-06-01  328.708
# 66     2023-10-17   2023-10-17  2023-07-01  325.201
# 67     2023-10-17   2023-10-17  2023-08-01  321.991
# 68     2023-10-17   2023-10-17  2023-09-01  321.237
#
# [69 rows x 4 columns]

# %% [markdown]
# ## Ferrous Metals - Monthly (Avg.)

# %%
params2 = {'series_id': 'WPU10121501',
           'observation_start': '2018-01-01',
          'observation_end': '2023-10-01',
           'frequency': 'm',
          'api_key': api_key,
          'file_type':'json'}
response2 = requests.get(url, params = params2)

# %%
response2.status_code
# Out:
# 200

# %%
df_ferrous_price_m = pd.DataFrame(response2.json()['observations'])
df_ferrous_price_m
# Out:
#    realtime_start realtime_end        date    value
# 0      2023-10-17   2023-10-17  2018-01-01    118.3
# 1      2023-10-17   2023-10-17  2018-02-01    120.1
# 2      2023-10-17   2023-10-17  2018-03-01    125.5
# 3      2023-10-17   2023-10-17  2018-04-01    131.3
# 4      2023-10-17   2023-10-17  2018-05-01    128.6
# ..            ...          ...         ...      ...
# 63     2023-10-17   2023-10-17  2023-04-01  123.329
# 64     2023-10-17   2023-10-17  2023-05-01  117.179
# 65     2023-10-17   2023-10-17  2023-06-01   99.916
# 66     2023-10-17   2023-10-17  2023-07-01  101.282
# 67     2023-10-17   2023-10-17  2023-08-01   96.716
#
# [68 rows x 4 columns]

# %% [markdown]
# ## Non-Ferrous Metals - Monthly (Avg.)

# %%
params3 = {'series_id': 'WPS102',
           'observation_start': '2018-01-01',
          'observation_end': '2023-10-01',
           'frequency': 'm',
          'api_key': api_key,
          'file_type':'json'}
response3 = requests.get(url, params = params3)

# %%
response3.status_code
# Out:
# 200

# %%
df_nonferrous_price_m = pd.DataFrame(response3.json()['observations'])
df_nonferrous_price_m
# Out:
#    realtime_start realtime_end        date    value
# 0      2023-10-17   2023-10-17  2018-01-01    247.9
# 1      2023-10-17   2023-10-17  2018-02-01    248.3
# 2      2023-10-17   2023-10-17  2018-03-01    249.0
# 3      2023-10-17   2023-10-17  2018-04-01    249.7
# 4      2023-10-17   2023-10-17  2018-05-01    252.5
# ..            ...          ...         ...      ...
# 64     2023-10-17   2023-10-17  2023-05-01  333.262
# 65     2023-10-17   2023-10-17  2023-06-01  328.708
# 66     2023-10-17   2023-10-17  2023-07-01  325.201
# 67     2023-10-17   2023-10-17  2023-08-01  321.991
# 68     2023-10-17   2023-10-17  2023-09-01  321.237
#
# [69 rows x 4 columns]

# %% [markdown]
# # Series Data

# %% [markdown]
# ## Ferrous Metals (Daily)

# %%
url2 = 'https://api.stlouisfed.org/fred/series/search'

# %%
params4 = {'search_text': 'ferrous metals',
           'observation_start': '2018-01-01',
          'observation_end': '2023-10-01',
          'api_key': api_key,
          'file_type':'json'}
response4 = requests.get(url2, params = params4)

# %%
response4.status_code
# Out:
# 200

# %%
df_ferrous_search_d = pd.DataFrame(response4.json()['seriess'])
df_ferrous_search_d
# Out:
#                     id realtime_start realtime_end  \
# 0               AANMNO     2023-10-17   2023-10-17
# 1               UANMNO     2023-10-17   2023-10-17
# 2               WPU102     2023-10-17   2023-10-17
# 3               WPS102     2023-10-17   2023-10-17
# 4     PCU4299304299301     2023-10-17   2023-10-17
# ..                 ...            ...          ...
# 257        WPU10151318     2023-10-17   2023-10-17
# 258  RGMPPRIMETMANUSMP     2023-10-17   2023-10-17
# 259  NGMPPRIMETMANUSMP     2023-10-17   2023-10-17
# 260  QGMPPRIMETMANUSMP     2023-10-17   2023-10-17
# 261   A0198ADEA324NNBR     2023-10-17   2023-10-17
#
#                                                  title observation_start  \
# 0    Manufacturers' New Orders: Aluminum and Nonfer...        1992-02-01
# 1    Manufacturers' New Orders: Aluminum and Nonfer...        1992-02-01
# 2    Producer Price Index by Commodity: Metals and ...        1926-01-01
# ...

# %%
df_ferrous_search_d.to_csv('df_ferrous_search_d.csv', index = False)

# %% [markdown]
# ## Non-Ferrous Metals (Daily)

# %%
params5 = {'search_text': 'nonferrous metals',
           'observation_start': '2018-01-01',
          'observation_end': '2023-10-01',
          'api_key': api_key,
          'file_type':'json'}
response5 = requests.get(url2, params = params5)

# %%
response5.status_code
# Out:
# 200

# %%
df_nonferrous_search_d = pd.DataFrame(response5.json()['seriess'])
df_nonferrous_search_d
# Out:
#                    id realtime_start realtime_end  \
# 0              AANMNO     2023-10-17   2023-10-17
# 1              UANMNO     2023-10-17   2023-10-17
# 2              WPU102     2023-10-17   2023-10-17
# 3              WPS102     2023-10-17   2023-10-17
# 4    PCU3315233315231     2023-10-17   2023-10-17
# ..                ...            ...          ...
# 245  M0684BUSM144NNBR     2023-10-17   2023-10-17
# 246  M0684CUSM144NNBR     2023-10-17   2023-10-17
# 247  M0103AUSM331SNBR     2023-10-17   2023-10-17
# 248  M0103BUSM343SNBR     2023-10-17   2023-10-17
# 249  M0103CUSM349NNBR     2023-10-17   2023-10-17
#
#                                                  title observation_start  \
# 0    Manufacturers' New Orders: Aluminum and Nonfer...        1992-02-01
# 1    Manufacturers' New Orders: Aluminum and Nonfer...        1992-02-01
# 2    Producer Price Index by Commodity: Metals and ...        1926-01-01
# ...

# %% [markdown]
# ## Ferrous Metals (Monthly)

# %%
params6 = {'search_text': 'ferrous metals',
           'observation_start': '2018-01-01',
          'observation_end': '2023-10-01',
           'frequency': 'm',
          'api_key': api_key,
          'file_type':'json'}
response6 = requests.get(url2, params = params6)

# %%
response6.status_code
# Out:
# 200

# %%
df_ferrous_search_m = pd.DataFrame(response6.json()['seriess'])
df_ferrous_search_m
# Out:
#                     id realtime_start realtime_end  \
# 0               AANMNO     2023-10-17   2023-10-17
# 1               UANMNO     2023-10-17   2023-10-17
# 2               WPU102     2023-10-17   2023-10-17
# 3               WPS102     2023-10-17   2023-10-17
# 4     PCU4299304299301     2023-10-17   2023-10-17
# ..                 ...            ...          ...
# 257        WPU10151318     2023-10-17   2023-10-17
# 258  RGMPPRIMETMANUSMP     2023-10-17   2023-10-17
# 259  NGMPPRIMETMANUSMP     2023-10-17   2023-10-17
# 260  QGMPPRIMETMANUSMP     2023-10-17   2023-10-17
# 261   A0198ADEA324NNBR     2023-10-17   2023-10-17
#
#                                                  title observation_start  \
# 0    Manufacturers' New Orders: Aluminum and Nonfer...        1992-02-01
# 1    Manufacturers' New Orders: Aluminum and Nonfer...        1992-02-01
# 2    Producer Price Index by Commodity: Metals and ...        1926-01-01
# ...

# %% [markdown]
# ## Non-Ferrous Metals (Monthly)

# %%
params7 = {'search_text': 'nonferrous metals',
           'observation_start': '2018-01-01',
          'observation_end': '2023-10-01',
           'frequency': 'm',
          'api_key': api_key,
          'file_type':'json'}
response7 = requests.get(url2, params = params7)

# %%
response7.status_code
# Out:
# 200

# %%
df_nonferrous_search_m = pd.DataFrame(response7.json()['seriess'])
df_nonferrous_search_m
# Out:
#                    id realtime_start realtime_end  \
# 0              AANMNO     2023-10-17   2023-10-17
# 1              UANMNO     2023-10-17   2023-10-17
# 2              WPU102     2023-10-17   2023-10-17
# 3              WPS102     2023-10-17   2023-10-17
# 4    PCU3315233315231     2023-10-17   2023-10-17
# ..                ...            ...          ...
# 245  M0684BUSM144NNBR     2023-10-17   2023-10-17
# 246  M0684CUSM144NNBR     2023-10-17   2023-10-17
# 247  M0103AUSM331SNBR     2023-10-17   2023-10-17
# 248  M0103BUSM343SNBR     2023-10-17   2023-10-17
# 249  M0103CUSM349NNBR     2023-10-17   2023-10-17
#
#                                                  title observation_start  \
# 0    Manufacturers' New Orders: Aluminum and Nonfer...        1992-02-01
# 1    Manufacturers' New Orders: Aluminum and Nonfer...        1992-02-01
# 2    Producer Price Index by Commodity: Metals and ...        1926-01-01
# ...

# %% [markdown]
# ## Ferrous Metals (Total Inventories)

# %%
params8 = {'series_id': 'A31CTI',
           'observation_start': '2018-01-01',
          'observation_end': '2023-10-01',
          'api_key': api_key,
          'file_type':'json'}
response8 = requests.get(url, params = params8)

response8.status_code

df_ferrous_inv = pd.DataFrame(response8.json()['observations'])
df_ferrous_inv
# Out:
#    realtime_start realtime_end        date   value
# 0      2023-10-17   2023-10-17  2018-01-01    2249
# 1      2023-10-17   2023-10-17  2018-02-01    2250
# 2      2023-10-17   2023-10-17  2018-03-01    2246
# 3      2023-10-17   2023-10-17  2018-04-01    2259
# 4      2023-10-17   2023-10-17  2018-05-01    2291
# ..            ...          ...         ...     ...
# 63     2023-10-17   2023-10-17  2023-04-01    3112
# 64     2023-10-17   2023-10-17  2023-05-01  3159.0
# 65     2023-10-17   2023-10-17  2023-06-01  3153.0
# 66     2023-10-17   2023-10-17  2023-07-01  3128.0
# 67     2023-10-17   2023-10-17  2023-08-01  3145.0
#
# [68 rows x 4 columns]

# %% [markdown]
# ## Aluminum & Non-Ferrous Metal (Total Inventory)

# %%
params9 = {'series_id': 'AANMTI',
           'observation_start': '2018-01-01',
          'observation_end': '2023-10-01',
          'api_key': api_key,
          'file_type':'json'}
response9 = requests.get(url, params = params9)

response9.status_code

df_nonferrous_inv = pd.DataFrame(response9.json()['observations'])
df_nonferrous_inv
# Out:
#    realtime_start realtime_end        date    value
# 0      2023-10-17   2023-10-17  2018-01-01    12545
# 1      2023-10-17   2023-10-17  2018-02-01    12735
# 2      2023-10-17   2023-10-17  2018-03-01    12701
# 3      2023-10-17   2023-10-17  2018-04-01    12861
# 4      2023-10-17   2023-10-17  2018-05-01    13049
# ..            ...          ...         ...      ...
# 63     2023-10-17   2023-10-17  2023-04-01    16226
# 64     2023-10-17   2023-10-17  2023-05-01  16247.0
# 65     2023-10-17   2023-10-17  2023-06-01  16091.0
# 66     2023-10-17   2023-10-17  2023-07-01  16030.0
# 67     2023-10-17   2023-10-17  2023-08-01  16004.0
#
# [68 rows x 4 columns]

# %% [markdown]
# ## Ferrous Metal (New Orders)

# %%
params10 = {'series_id': 'A31CNO',
           'observation_start': '2018-01-01',
          'observation_end': '2023-10-01',
          'api_key': api_key,
          'file_type':'json'}
response10 = requests.get(url, params = params10)

response10.status_code

df_ferrous_newor = pd.DataFrame(response10.json()['observations'])
df_ferrous_newor
# Out:
#    realtime_start realtime_end        date   value
# 0      2023-10-17   2023-10-17  2018-01-01    1145
# 1      2023-10-17   2023-10-17  2018-02-01    1217
# 2      2023-10-17   2023-10-17  2018-03-01     982
# 3      2023-10-17   2023-10-17  2018-04-01    1240
# 4      2023-10-17   2023-10-17  2018-05-01    1259
# ..            ...          ...         ...     ...
# 63     2023-10-17   2023-10-17  2023-04-01    1695
# 64     2023-10-17   2023-10-17  2023-05-01  1662.0
# 65     2023-10-17   2023-10-17  2023-06-01  1642.0
# 66     2023-10-17   2023-10-17  2023-07-01  1562.0
# 67     2023-10-17   2023-10-17  2023-08-01  1566.0
#
# [68 rows x 4 columns]

# %% [markdown]
# ## Non-Ferrous Metals (New Orders)

# %%
params11 = {'series_id': 'AANMNO',
           'observation_start': '2018-01-01',
          'observation_end': '2023-10-01',
          'api_key': api_key,
          'file_type':'json'}
response11 = requests.get(url, params = params11)

response11.status_code

df_nonferrous_newor = pd.DataFrame(response11.json()['observations'])
df_nonferrous_newor
# Out:
#    realtime_start realtime_end        date    value
# 0      2023-10-17   2023-10-17  2018-01-01     8419
# 1      2023-10-17   2023-10-17  2018-02-01     8617
# 2      2023-10-17   2023-10-17  2018-03-01     8807
# 3      2023-10-17   2023-10-17  2018-04-01     9033
# 4      2023-10-17   2023-10-17  2018-05-01     9045
# ..            ...          ...         ...      ...
# 63     2023-10-17   2023-10-17  2023-04-01    10057
# 64     2023-10-17   2023-10-17  2023-05-01  10276.0
# 65     2023-10-17   2023-10-17  2023-06-01  10385.0
# 66     2023-10-17   2023-10-17  2023-07-01  10493.0
# 67     2023-10-17   2023-10-17  2023-08-01  10320.0
#
# [68 rows x 4 columns]

# %% [markdown]
# ## FERROUS METALS (COMPLETE TABLE)

# %%
df_ferrous_newor.head()
# Out:
#   realtime_start realtime_end        date value
# 0     2023-10-17   2023-10-17  2018-01-01  1145
# 1     2023-10-17   2023-10-17  2018-02-01  1217
# 2     2023-10-17   2023-10-17  2018-03-01   982
# 3     2023-10-17   2023-10-17  2018-04-01  1240
# 4     2023-10-17   2023-10-17  2018-05-01  1259

# %%
ferrous_metal_data = pd.merge(df_ferrous_price_m[['date', 'value']], df_ferrous_inv[['date', 'value']], on='date', how='left', suffixes=('_price', '_inv'))
ferrous_metal_data
# Out:
#           date value_price value_inv
# 0   2018-01-01       118.3      2249
# 1   2018-02-01       120.1      2250
# 2   2018-03-01       125.5      2246
# 3   2018-04-01       131.3      2259
# 4   2018-05-01       128.6      2291
# ..         ...         ...       ...
# 63  2023-04-01     123.329      3112
# 64  2023-05-01     117.179    3159.0
# 65  2023-06-01      99.916    3153.0
# 66  2023-07-01     101.282    3128.0
# 67  2023-08-01      96.716    3145.0
#
# [68 rows x 3 columns]

# %%
ferrous_metal_data = pd.merge(ferrous_metal_data, df_ferrous_newor[['date', 'value']], on='date', how='left', suffixes=('', '_newor'))
ferrous_metal_data
# Out:
#           date value_price value_inv   value
# 0   2018-01-01       118.3      2249    1145
# 1   2018-02-01       120.1      2250    1217
# 2   2018-03-01       125.5      2246     982
# 3   2018-04-01       131.3      2259    1240
# 4   2018-05-01       128.6      2291    1259
# ..         ...         ...       ...     ...
# 63  2023-04-01     123.329      3112    1695
# 64  2023-05-01     117.179    3159.0  1662.0
# 65  2023-06-01      99.916    3153.0  1642.0
# 66  2023-07-01     101.282    3128.0  1562.0
# 67  2023-08-01      96.716    3145.0  1566.0
#
# [68 rows x 4 columns]

# %%
ferrous_metal_data = ferrous_metal_data.rename(columns = {'value_x': 'producer_price_index',
                           'value_y': 'total_inventory',
                           'value': 'new_orders'})

# %%
ferrous_metal_data = ferrous_metal_data.drop(columns=['realtime_start_x', 'realtime_end_x', 'realtime_start_y','realtime_end_y', 'realtime_start', 'realtime_end'])

# %%
ferrous_metal_data
# Out:
#           date producer_price_index total_inventory new_orders
# 0   2018-01-01                118.3            2249       1145
# 1   2018-02-01                120.1            2250       1217
# 2   2018-03-01                125.5            2246        982
# 3   2018-04-01                131.3            2259       1240
# 4   2018-05-01                128.6            2291       1259
# ..         ...                  ...             ...        ...
# 63  2023-04-01              123.329            3112       1695
# 64  2023-05-01              117.179          3159.0     1662.0
# 65  2023-06-01               99.916          3153.0     1642.0
# 66  2023-07-01              101.282          3128.0     1562.0
# 67  2023-08-01               96.716          3145.0     1566.0
#
# [68 rows x 4 columns]

# %% [markdown]
# ## NON-FERROUS METALS (COMPLETE TABLE)

# %%
nonferrous_metal_data = pd.merge(df_nonferrous_price_m, df_nonferrous_inv, on='date', how='left')
nonferrous_metal_data
# Out:
#    realtime_start_x realtime_end_x        date  value_x realtime_start_y  \
# 0        2023-10-17     2023-10-17  2018-01-01    247.9       2023-10-17
# 1        2023-10-17     2023-10-17  2018-02-01    248.3       2023-10-17
# 2        2023-10-17     2023-10-17  2018-03-01    249.0       2023-10-17
# 3        2023-10-17     2023-10-17  2018-04-01    249.7       2023-10-17
# 4        2023-10-17     2023-10-17  2018-05-01    252.5       2023-10-17
# ..              ...            ...         ...      ...              ...
# 64       2023-10-17     2023-10-17  2023-05-01  333.262       2023-10-17
# 65       2023-10-17     2023-10-17  2023-06-01  328.708       2023-10-17
# 66       2023-10-17     2023-10-17  2023-07-01  325.201       2023-10-17
# 67       2023-10-17     2023-10-17  2023-08-01  321.991       2023-10-17
# 68       2023-10-17     2023-10-17  2023-09-01  321.237              NaN
#
#    realtime_end_y  value_y
# 0      2023-10-17    12545
# 1      2023-10-17    12735
# ...

# %%
nonferrous_metal_data = pd.merge(nonferrous_metal_data, df_nonferrous_newor, on='date', how='left')
nonferrous_metal_data
# Out:
#    realtime_start_x realtime_end_x        date  value_x realtime_start_y  \
# 0        2023-10-17     2023-10-17  2018-01-01    247.9       2023-10-17
# 1        2023-10-17     2023-10-17  2018-02-01    248.3       2023-10-17
# 2        2023-10-17     2023-10-17  2018-03-01    249.0       2023-10-17
# 3        2023-10-17     2023-10-17  2018-04-01    249.7       2023-10-17
# 4        2023-10-17     2023-10-17  2018-05-01    252.5       2023-10-17
# ..              ...            ...         ...      ...              ...
# 64       2023-10-17     2023-10-17  2023-05-01  333.262       2023-10-17
# 65       2023-10-17     2023-10-17  2023-06-01  328.708       2023-10-17
# 66       2023-10-17     2023-10-17  2023-07-01  325.201       2023-10-17
# 67       2023-10-17     2023-10-17  2023-08-01  321.991       2023-10-17
# 68       2023-10-17     2023-10-17  2023-09-01  321.237              NaN
#
#    realtime_end_y  value_y realtime_start realtime_end    value
# ...

# %%
nonferrous_metal_data = nonferrous_metal_data.rename(columns = {'value_x': 'producer_price_index',
                           'value_y': 'total_inventory',
                           'value': 'new_orders'})

# %%
nonferrous_metal_data = nonferrous_metal_data.drop(columns=['realtime_start_x', 'realtime_end_x', 'realtime_start_y','realtime_end_y', 'realtime_start', 'realtime_end'])

# %%
nonferrous_metal_data
# Out:
#           date producer_price_index total_inventory new_orders
# 0   2018-01-01                247.9           12545       8419
# 1   2018-02-01                248.3           12735       8617
# 2   2018-03-01                249.0           12701       8807
# 3   2018-04-01                249.7           12861       9033
# 4   2018-05-01                252.5           13049       9045
# ..         ...                  ...             ...        ...
# 64  2023-05-01              333.262         16247.0    10276.0
# 65  2023-06-01              328.708         16091.0    10385.0
# 66  2023-07-01              325.201         16030.0    10493.0
# 67  2023-08-01              321.991         16004.0    10320.0
# 68  2023-09-01              321.237             NaN        NaN
#
# [69 rows x 4 columns]
