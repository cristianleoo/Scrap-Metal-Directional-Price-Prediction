# %%
import openai_secret_manager

assert "openai" in openai_secret_manager.get_services()
secrets = openai_secret_manager.get_secret("openai")

import openai
openai.api_key = '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'
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/cristianleo/Documents/GitHub/capstone-columbia/app.ipynb Cell 1 line 1
# ----> <a href='vscode-notebook-cell:/Users/cristianleo/Documents/GitHub/capstone-columbia/app.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import openai_secret_manager
#       <a href='vscode-notebook-cell:/Users/cristianleo/Documents/GitHub/capstone-columbia/app.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> assert "openai" in openai_secret_manager.get_services()
#       <a href='vscode-notebook-cell:/Users/cristianleo/Documents/GitHub/capstone-columbia/app.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a> secrets = openai_secret_manager.get_secret("openai")
#
# ModuleNotFoundError: No module named 'openai_secret_manager'

# %%
# Set up the GPT-3 API
from openai import api_key
import openai
import requests
import json

def gpt3_request(prompt, model, max_tokens, temperature):
    headers = {
        'Content-Type': 'application/json',
        'Authorization': f'Bearer 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'
    }

    data = {
        'prompt': prompt,
        'model': model,
        'max_tokens': max_tokens,
        'temperature': temperature
    }

    response = requests.post('https://api.openai.com/v1/engines/davinci-codex/completions', headers=headers, data=json.dumps(data))
    return response.json()['choices'][0]['text']

# %%
import os
import openai
#openai.organization = "YOUR_ORG_ID"
openai.api_key = "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"
openai.Model.list()
# Out:
# <OpenAIObject list at 0x127387a70> JSON: {
#   "data": [
#     {
#       "created": 1651172509,
#       "id": "text-search-babbage-doc-001",
#       "object": "model",
#       "owned_by": "openai-dev",
#       "parent": null,
#       "permission": [
#         {
#           "allow_create_engine": false,
#           "allow_fine_tuning": false,
#           "allow_logprobs": true,
#           "allow_sampling": true,
#           "allow_search_indices": true,
#           "allow_view": true,
#           "created": 1695933794,
#           "group": null,
#           "id": "modelperm-s9n5HnzbtVn7kNc5TIZWiCFS",
#           "is_blocking": false,
#           "object": "model_permission",
#           "organization": "*"
#         }
#       ],
#       "root": "text-search-babbage-doc-001"
#     },
#     {
#       "created": 1651172509,
#       "id": "curie-search-query",
#       "object": "model",
#       "owned_by": "openai-dev",
#       "parent": null,
#       "permission": [
#         {
# ...

# %%
import openai
# import openai_secret_manager

# assert "openai" in openai_secret_manager.get_services()
# secrets = openai_secret_manager.get_secret("openai")

openai.api_key = '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'

prompt = "What is the capital of France?"
model_engine = "text-davinci-002"
response = openai.Completion.create(
    engine=model_engine,
    prompt=prompt,
    max_tokens=5,
    n=1,
    stop=None,
    temperature=0.5,
)

answer = response.choices[0].text.strip()
print(answer)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# /Users/cristianleo/Documents/GitHub/capstone-columbia/app.ipynb Cell 4 line 1
#       <a href='vscode-notebook-cell:/Users/cristianleo/Documents/GitHub/capstone-columbia/app.ipynb#W3sZmlsZQ%3D%3D?line=8'>9</a> prompt = "What is the capital of France?"
#      <a href='vscode-notebook-cell:/Users/cristianleo/Documents/GitHub/capstone-columbia/app.ipynb#W3sZmlsZQ%3D%3D?line=9'>10</a> model_engine = "text-davinci-002"
# ---> <a href='vscode-notebook-cell:/Users/cristianleo/Documents/GitHub/capstone-columbia/app.ipynb#W3sZmlsZQ%3D%3D?line=10'>11</a> response = openai.Completion.create(
#      <a href='vscode-notebook-cell:/Users/cristianleo/Documents/GitHub/capstone-columbia/app.ipynb#W3sZmlsZQ%3D%3D?line=11'>12</a>     engine=model_engine,
# ...

# %%
token = "bQjBZumWT_yngjXC1yDew_AcBwPl0DZA-okR8YUSVcraFAPDzuwj4FQBmg8dMBA3Qvzeuw."

from bardapi import Bard
import os
os.environ['_BARD_API_KEY']=token

Bard(token=token).get_answer("나와 내 동년배들이 좋아하는 뉴진스에 대해서 알려줘")['content']
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[1], line 7
#       4 import os
#       5 os.environ['_BARD_API_KEY']=token
# ----> 7 Bard(token=token).get_answer("나와 내 동년배들이 좋아하는 뉴진스에 대해서 알려줘")['content']
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/bardapi/core.py:70, in Bard.__init__(self, token, timeout, proxies, session, conversation_id, google_translator_api_key, language, run_code, token_from_browser)
#      68 self.choice_id = ""
#      69 self.session = self._get_session(session)
# ---> 70 self.SNlM0e = self._get_snim0e()
#      71 self.language = language or os.getenv("_BARD_API_LANG")
#      72 self.run_code = run_code
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/bardapi/core.py:143, in Bard._get_snim0e(self)
#     141 snim0e = re.search(r"SNlM0e\":\"(.*?)\"", resp.text)
# ...

# %%
import pandas as pd
import os

parent_dir = os.path.dirname(os.getcwd())

data_dir = os.path.join(parent_dir, 'capstone-columbia','data')
benzinga = os.path.join(data_dir, 'TSM', 'benzinga.csv')
pd.read_csv(benzinga).head()
# Out:
#       created  \
# 0  2018-01-03
# 1  2018-01-16
# 2  2018-01-16
# 3  2018-01-17
# 4  2018-01-18
#
#                                                                      title  \
# 0  Intel's Potentially Major Security Flaw Boosting AMD, Other Chip Stocks
# 1                 Benzinga's Top Upgrades, Downgrades For January 16, 2018
# 2              Dow Earnings: Analysts Expect Goldman Sachs Revenue Decline
# 3                First Blockchain ETFs Debut: Here's What You Need To Know
# 4                                  Earnings Scheduled For January 18, 2018
#
# ...

# %%
file = os.path.join(data_dir, 'TSM','finbert_sentiment.csv')
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
pd.read_csv(file)
# Out:
#         created  sentiment
# 0    2018-01-03          0
# 1    2018-01-16          2
# 2    2018-01-17          0
# 3    2018-01-18          0
# 4    2018-01-22          1
# 5    2018-01-25          0
# 6    2018-01-30          0
# 7    2018-01-31          0
# 8    2018-02-02          0
# 9    2018-02-18          0
# 10   2018-04-03          0
# 11   2018-04-19          0
# 12   2018-04-20          1
# 13   2018-04-30          1
# 14   2018-05-10          0
# 15   2018-05-16          0
# 16   2018-05-17          0
# 17   2018-07-19          1
# 18   2018-07-24          1
# 19   2018-08-08          0
# 20   2018-08-10          1
# 21   2018-08-13          2
# 22   2018-08-17          2
# 23   2018-08-23          0
# 24   2018-08-28          0
# 25   2018-09-07          0
# 26   2018-10-01          0
# 27   2018-10-12          0
# 28   2018-10-17          0
# 29   2018-10-18          1
# 30   2018-10-30          0
# 31   2018-11-02          0
# 32   2018-11-16          2
# ...
