# %%
from lstm import Trainer
model = Trainer()
# model.train()
model.predict(X='train')
# Out:
# Using mps
# Epoch: 1/1000, Loss: 1.5367, Val Loss: 1.0826, Best Val Loss: 1.0826
# Epoch: 2/1000, Loss: 1.4579, Val Loss: 1.0181, Best Val Loss: 1.0181
# Epoch: 3/1000, Loss: 1.3896, Val Loss: 0.9551, Best Val Loss: 0.9551
# Epoch: 4/1000, Loss: 1.3241, Val Loss: 0.8940, Best Val Loss: 0.8940
# Epoch: 5/1000, Loss: 1.2585, Val Loss: 0.8342, Best Val Loss: 0.8342
# Epoch: 6/1000, Loss: 1.1903, Val Loss: 0.7678, Best Val Loss: 0.7678
# Epoch: 7/1000, Loss: 1.1214, Val Loss: 0.6982, Best Val Loss: 0.6982
# Epoch: 8/1000, Loss: 1.0533, Val Loss: 0.6402, Best Val Loss: 0.6402
# Epoch: 9/1000, Loss: 0.9929, Val Loss: 0.5861, Best Val Loss: 0.5861
# Epoch: 10/1000, Loss: 0.9353, Val Loss: 0.5338, Best Val Loss: 0.5338
# Epoch: 11/1000, Loss: 0.8789, Val Loss: 0.4852, Best Val Loss: 0.4852
# Epoch: 12/1000, Loss: 0.8242, Val Loss: 0.4378, Best Val Loss: 0.4378
# Epoch: 13/1000, Loss: 0.7724, Val Loss: 0.3929, Best Val Loss: 0.3929
# ...

# %%
X_train =
