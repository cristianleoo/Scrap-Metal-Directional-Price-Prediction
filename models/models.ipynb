# %%
from dl import DL
model = DL()
X_train, X_val, X_test, y_train, y_val, y_test = model.split()
preds = model.predict('train')
print(preds)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/cristianleo/Documents/GitHub/capstone-columbia/models/models.ipynb Cell 1 line 1
# ----> <a href='vscode-notebook-cell:/Users/cristianleo/Documents/GitHub/capstone-columbia/models/models.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> from dl import DL
#       <a href='vscode-notebook-cell:/Users/cristianleo/Documents/GitHub/capstone-columbia/models/models.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> model = DL()
#       <a href='vscode-notebook-cell:/Users/cristianleo/Documents/GitHub/capstone-columbia/models/models.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> X_train, X_val, X_test, y_train, y_val, y_test = model.split()
#
# File ~/Documents/GitHub/capstone-columbia/models/dl.py:218
#     215         return model
#     217 model = DL()
# --> 218 model.train()
#
# File ~/Documents/GitHub/capstone-columbia/models/dl.py:49, in DL.train(self, epochs, early_stopping, n_layers)
#      47 X_val = X_val.reshape(X_val.shape[0], 1, X_val.shape[1])
#      48 X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])
# ---> 49 y_train = y_train.values.reshape(-1, 1)
#      50 y_val = y_val.values.reshape(-1, 1)
#      51 y_test = y_test.values.reshape(-1, 1)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'values'

# %%
from ingest import Ingest
ingest = Ingest()
df = ingest.get_data()
df['Target'].isna().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# date                     0
# XME                      0
# PICK                     0
# REMX                     0
# DBB                      0
# GLD                      0
# IAU                      0
# GDX                      0
# price_ferrous            0
# inventory_ferrous        0
# orders_ferrous           0
# price_non_ferrous        0
# inventory_non_ferrous    0
# orders_non_ferrous       0
# NUE_sentiment            0
# STLD_sentiment           0
# NSC_sentiment            0
# Target                   0
# dtype: int64

# %%
from ml import ML
model = ML()

preds = model.predict('train')
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=3, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=3, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=3, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=3, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=3, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=3, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=3, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=3, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=3, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=3, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=3, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=3, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=3, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=3, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=3, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=5, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=5, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=5, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=5, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=5, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=5, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=5, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=5, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=5, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=5, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=7, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=7, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=7, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=7, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=7, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=5, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=5, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=5, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.2s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=5, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.2s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=5, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.2s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=7, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=7, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=3, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=3, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=7, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=3, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=3, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=7, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=3, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=3, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=3, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=7, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=3, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=3, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=3, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=3, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=3, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=5, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=3, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=3, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=5, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=3, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=7, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.2s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=5, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=5, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=5, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=5, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=7, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.3s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=7, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.3s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=5, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=5, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=7, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.3s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=7, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=7, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.3s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=5, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=7, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=5, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=7, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=5, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=3, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=7, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=3, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=5, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=3, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=3, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=7, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=7, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=3, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=3, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=7, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=3, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=5, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.2s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=7, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=3, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=3, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=3, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=7, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=7, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=3, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=5, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.2s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=3, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=5, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=3, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=3, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=5, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=3, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=5, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=5, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=5, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.2s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=5, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=7, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.3s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=7, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.3s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=5, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=5, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=5, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=5, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=5, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=5, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=5, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=5, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=7, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=5, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=5, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=7, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=7, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.4s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=7, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=7, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=7, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=7, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=7, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=7, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=7, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=7, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=7, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=7, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=7, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=7, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=7, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.3s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=7, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=7, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.3s
# {'booster': 'gbtree', 'learning_rate': 0.001, 'max_depth': 7, 'n_estimators': 100, 'n_jobs': -1, 'objective': 'reg:squarederror', 'random_state': 42}
# Train MSE: 0.0684
# Val MSE: 0.0861
# Test MSE: 0.1298
# Model is not trained yet. Training now...
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=3, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=3, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=3, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=3, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=3, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=3, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=3, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=3, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=3, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=3, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=5, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=5, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=5, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=5, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [11:12:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=5, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=3, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=3, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=3, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=3, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=3, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=5, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=5, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=7, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=5, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=7, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=7, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=5, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=7, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=7, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=5, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=7, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=3, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=7, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=5, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.2s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=3, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=3, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=3, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=7, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=3, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=5, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.2s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=5, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.2s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=3, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=7, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=3, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=3, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=7, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=3, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=5, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=5, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.2s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=5, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=3, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=3, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=5, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=5, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=7, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.2s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=5, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=3, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=5, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=5, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=7, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.3s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=3, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=5, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=3, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=7, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.3s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=3, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=7, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=3, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=5, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=5, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=3, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=5, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=3, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=7, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=7, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=7, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=3, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=5, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=7, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=3, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=7, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=3, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=3, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=7, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.3s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=7, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=5, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.2s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=3, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=3, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.001, max_depth=7, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.3s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=5, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.2s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=3, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=3, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=3, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=5, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=5, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=5, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=7, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=7, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.3s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=3, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=5, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=5, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=5, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=5, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=5, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=7, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.3s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=5, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=5, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.2s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=5, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=5, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=7, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=5, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=5, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=5, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=5, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=7, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=7, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=7, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=7, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=5, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=7, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=7, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=7, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=7, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=7, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=7, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=7, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.3s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=7, n_estimators=200, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=7, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=7, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=3, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=7, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=7, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=3, n_estimators=100, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.0s
# [CV] END booster=gbtree, learning_rate=0.1, max_depth=7, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.1s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=7, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.3s
# [CV] END booster=gbtree, learning_rate=0.01, max_depth=7, n_estimators=500, n_jobs=-1, objective=reg:squarederror, random_state=42; total time=   0.2s
# {'booster': 'gbtree', 'learning_rate': 0.001, 'max_depth': 7, 'n_estimators': 100, 'n_jobs': -1, 'objective': 'reg:squarederror', 'random_state': 42}
# Train MSE: 0.0684
# Val MSE: 0.0861
# Test MSE: 0.1298
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [11:12:30] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %%
X_train, X_val, X_test, y_train, y_val, y_test = ingest.split()
y_train, preds
# Out:
# (     Target
#  0   -0.2598
#  1    0.1213
#  2    0.3856
#  3    0.4284
#  4   -0.0862
#  ..      ...
#  118 -0.0714
#  119  0.5020
#  120  0.0000
#  121  0.1110
#  122  0.8563
#
#  [123 rows x 1 columns],
#  array([ 0.01206353,  0.01206353,  0.02030448,  0.02030448,  0.01161528,
#          0.01206353,  0.01206353,  0.01206353,  0.01206353,  0.01206353,
#          0.01206353,  0.01206353,  0.01206353,  0.01206353,  0.01206353,
#          0.01206353,  0.01206353,  0.01206353,  0.01206353,  0.01206353,
#         -0.00280452, -0.00280452,  0.04361097,  0.00433482, -0.00280452,
#          0.01206353,  0.01206353,  0.01206353,  0.01206353,  0.01206353,
#          0.01206353,  0.01206353, -0.00082279,  0.01206353,  0.01206353,
#          0.01206353,  0.01206353,  0.01206353,  0.01206353,  0.01206353,
#          0.00433482,  0.01206353,  0.01206353,  0.01206353,  0.01206353,
#          0.01206353,  0.01206353,  0.01206353, -0.0043974 , -0.0043974 ,
#          0.01189804,  0.01674446, -0.0330225 , -0.00657527,  0.01051794,
#          0.01346628,  0.04471016,  0.00272561, -0.00657527,  0.00792885,
#         -0.0330225 , -0.0330225 ,  0.01051794,  0.0350282 ,  0.01115167,
#          0.031733  ,  0.04471016,  0.04471016, -0.0043974 , -0.0043974 ,
#         -0.0043974 , -0.0043974 , -0.0330225 ,  0.04727489,  0.04727489,
#          0.04727489,  0.00433482,  0.04727489, -0.0043974 , -0.0043974 ,
#          0.01056944,  0.00433482,  0.00433482,  0.01716978, -0.0043974 ,
#          0.00880913,  0.04361097,  0.05174959,  0.00433482,  0.01889833,
#          0.01206353,  0.00433482, -0.00280452,  0.01238587, -0.0043974 ,
#         -0.0043974 ,  0.01674446,  0.02507973,  0.01115167, -0.0043974 ,
#         -0.00254609,  0.01959109, -0.00254609, -0.01903192, -0.00657527,
#          0.00817594,  0.0350282 , -0.01903192, -0.01903192,  0.0350282 ,
#          0.04471016,  0.04471016,  0.00272561,  0.01283467, -0.01903192,
#          0.05174959,  0.01088337, -0.01903192,  0.00822905,  0.03574867,
#          0.00908094,  0.01656652,  0.05174959], dtype=float32))

# %%
import copy

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
# read data and apply one-hot encoding
from ucimlrepo import fetch_ucirepo

# %%
# fetch dataset 
iris = fetch_ucirepo(id=53) 
  
# data (as pandas dataframes) 
X = iris.data.features 
y = iris.data.targets 
  
# metadata 
print(iris.metadata) 
  
# variable information 
print(iris.variables)
# Out:
# {'uci_id': 53, 'name': 'Iris', 'repository_url': 'https://archive.ics.uci.edu/dataset/53/iris', 'data_url': 'https://archive.ics.uci.edu/static/public/53/data.csv', 'abstract': 'A small classic dataset from Fisher, 1936. One of the earliest known datasets used for evaluating classification methods.\n', 'area': 'Life Science', 'tasks': ['Classification'], 'characteristics': ['Tabular'], 'num_instances': 150, 'num_features': 4, 'feature_types': ['Real'], 'demographics': [], 'target_col': ['class'], 'index_col': None, 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 1936, 'last_updated': 'Tue Sep 12 2023', 'dataset_doi': '10.24432/C56C76', 'creators': ['R. A. Fisher'], 'intro_paper': {'title': 'The Iris data set: In search of the source of virginica', 'authors': 'A. Unwin, K. Kleinman', 'published_in': 'Significance, 2021', 'year': 2021, 'url': 'https://www.semanticscholar.org/paper/4599862ea877863669a6a8e63a3c707a787d5d7e', 'doi': '1740-9713.01589'}, 'additional_info': {'summary': 'This is one of the earliest datasets used in the literature on classification methods and widely used in statistics and machine learning.  The data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant.  One class is linearly separable from the other 2; the latter are not linearly separable from each other.\n\nPredicted attribute: class of iris plant.\n\nThis is an exceedingly simple domain.\n\nThis data differs from the data presented in Fishers article (identified by Steve Chadwick,  spchadwick@espeedaz.net ).  The 35th sample should be: 4.9,3.1,1.5,0.2,"Iris-setosa" where the error is in the fourth feature. The 38th sample: 4.9,3.6,1.4,0.1,"Iris-setosa" where the errors are in the second and third features.  ', 'purpose': 'N/A', 'funded_by': None, 'instances_represent': 'Each instance is a plant', 'recommended_data_splits': None, 'sensitive_data': None, 'preprocessing_description': None, 'variable_info': None, 'citation': None}}
#            name     role         type demographic  \
# 0  sepal length  Feature   Continuous        None
# 1   sepal width  Feature   Continuous        None
# 2  petal length  Feature   Continuous        None
# 3   petal width  Feature   Continuous        None
# 4         class   Target  Categorical        None
#
#                                          description units missing_values
# 0                                               None    cm             no
# 1                                               None    cm             no
# 2                                               None    cm             no
# 3                                               None    cm             no
# 4  class of iris plant: Iris Setosa, Iris Versico...  None             no

# %%
ohe = OneHotEncoder(handle_unknown='ignore', sparse_output=False).fit(y)
y = ohe.transform(y)
# y

# %%
X_train.shape
# Out:
# (100, 1, 25)

# %%
# convert pandas DataFrame (X) and numpy array (y) into PyTorch tensors
X = torch.tensor(X_train.reshape(100, 20), dtype=torch.float32)
y = torch.tensor(y_train.reshape(100, 3), dtype=torch.float32)

# split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, shuffle=True)

class Multiclass(nn.Module):
    def __init__(self):
        super().__init__()
        self.hidden = nn.Linear(X_train.shape[-1], 8)
        self.act = nn.ReLU()
        self.output = nn.Linear(8, 3)

    def forward(self, x):
        x = self.act(self.hidden(x))
        x = self.output(x)
        return x

# loss metric and optimizer
model = Multiclass()
loss_fn = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# prepare model and training parameters
n_epochs = 200
batch_size = 5
batches_per_epoch = len(X_train) // batch_size

best_acc = - np.inf   # init to negative infinity
best_weights = None
train_loss_hist = []
train_acc_hist = []
test_loss_hist = []
test_acc_hist = []

# training loop
for epoch in range(n_epochs):
    epoch_loss = []
    epoch_acc = []
    # set model in training mode and run through each batch
    model.train()
    with tqdm.trange(batches_per_epoch, unit="batch", mininterval=0) as bar:
        bar.set_description(f"Epoch {epoch}")
        for i in bar:
            # take a batch
            start = i * batch_size
            X_batch = X_train[start:start+batch_size]
            y_batch = y_train[start:start+batch_size]
            # forward pass
            y_pred = model(X_batch)
            loss = loss_fn(y_pred, y_batch)
            # backward pass
            optimizer.zero_grad()
            loss.backward()
            # update weights
            optimizer.step()
            # compute and store metrics
            acc = (torch.argmax(y_pred, 1) == torch.argmax(y_batch, 1)).float().mean()
            epoch_loss.append(float(loss))
            epoch_acc.append(float(acc))
            bar.set_postfix(
                loss=float(loss),
                acc=float(acc)
            )
    # set model in evaluation mode and run through the test set
    model.eval()
    y_pred = model(X_test)
    ce = loss_fn(y_pred, y_test)
    acc = (torch.argmax(y_pred, 1) == torch.argmax(y_test, 1)).float().mean()
    ce = float(ce)
    acc = float(acc)
    train_loss_hist.append(np.mean(epoch_loss))
    train_acc_hist.append(np.mean(epoch_acc))
    test_loss_hist.append(ce)
    test_acc_hist.append(acc)
    if acc > best_acc:
        best_acc = acc
        best_weights = copy.deepcopy(model.state_dict())
    print(f"Epoch {epoch} validation: Cross-entropy={ce:.2f}, Accuracy={acc*100:.1f}%")

# Restore best model
model.load_state_dict(best_weights)

# Plot the loss and accuracy
plt.plot(train_loss_hist, label="train")
plt.plot(test_loss_hist, label="test")
plt.xlabel("epochs")
plt.ylabel("cross entropy")
plt.legend()
plt.show()

plt.plot(train_acc_hist, label="train")
plt.plot(test_acc_hist, label="test")
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/cristianleo/Documents/GitHub/capstone-columbia/models/mylstm/lstm.ipynb Cell 7 line 2
#       <a href='vscode-notebook-cell:/Users/cristianleo/Documents/GitHub/capstone-columbia/models/mylstm/lstm.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> # convert pandas DataFrame (X) and numpy array (y) into PyTorch tensors
# ----> <a href='vscode-notebook-cell:/Users/cristianleo/Documents/GitHub/capstone-columbia/models/mylstm/lstm.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> X = torch.tensor(X_train.reshape(100, 21), dtype=torch.float32)
#       <a href='vscode-notebook-cell:/Users/cristianleo/Documents/GitHub/capstone-columbia/models/mylstm/lstm.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a> y = torch.tensor(y_train.reshape(100, 3), dtype=torch.float32)
#       <a href='vscode-notebook-cell:/Users/cristianleo/Documents/GitHub/capstone-columbia/models/mylstm/lstm.ipynb#X10sZmlsZQ%3D%3D?line=4'>5</a> # split
#
# ValueError: cannot reshape array of size 2000 into shape (100,21)

# %%
y_pred
# Out:
# tensor([[[-1119.3744, -1218.5469,   553.6716]],
#
#         [[-1263.9401, -1356.0044,   614.1141]],
#
#         [[-1084.2223, -1153.4010,   520.9010]],
#
#         [[-1283.7467, -1441.5431,   659.7349]],
#
#         [[-1260.4536, -1354.3207,   613.4694]],
#
#         [[-1257.6625, -1403.5592,   641.7567]],
#
#         [[-1253.0940, -1347.6198,   610.2273]],
#
#         [[-1199.9338, -1275.3297,   575.9004]],
#
#         [[-1284.6846, -1425.6714,   650.2998]],
#
#         [[-1227.9615, -1349.7390,   615.2683]],
#
#         [[-1263.1530, -1357.7592,   614.8317]],
#
#         [[-1282.9653, -1436.8722,   657.6439]],
#
#         [[-1098.6914, -1197.2167,   544.5115]],
#
#         [[-1313.7844, -1484.0508,   679.8506]],
#
#         [[-1091.5017, -1175.0027,   532.5403]],
#
#         [[-1238.1921, -1378.0237,   629.7054]],
#
#         [[-1274.7393, -1418.0004,   647.1060]],
#
#         [[-1270.0024, -1409.3785,   643.8832]],
#
#         [[-1272.9852, -1426.2517,   652.5543]],
#
#         [[-1221.0238, -1306.4484,   591.0057]],
#
#         [[-1141.3923, -1247.1450,   567.4767]],
#
#         [[-1074.9929, -1158.6924,   525.2233]],
#
#         [[-1305.4122, -1468.4537,   671.9998]],
#
#         [[-1243.7205, -1360.2014,   619.2859]],
#
#         [[-1286.7578, -1450.1541,   664.3011]],
#
#         [[-1234.8824, -1360.2029,   620.4189]],
#
#         [[-1271.1259, -1409.5898,   643.7414]],
#
#         [[-1206.9702, -1329.2479,   606.1135]],
#
#         [[-1208.2043, -1318.4734,   599.9422]],
#
#         [[-1232.3094, -1376.2823,   629.6298]]], grad_fn=<ViewBackward0>)
