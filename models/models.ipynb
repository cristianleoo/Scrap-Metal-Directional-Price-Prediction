# %% [markdown]
# # **DL**

# %%
from dl import DL
model = DL()
model.train(
    epochs=500,
    hidden_size=32,
    batch_size=16,
    n_layers=1,
    lr=1e-3,
    weight_decay=1e-6,
    lstm_dropout=0.25,
    # initialization='Kaiming',
)
preds = model.predict('train')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# +-----------------------+---------------------+---------------------------+--------------------+
# |        Feature        |   Initial ROC_AUC   |       Transformation      | Tranformed ROC_AUC |
# +-----------------------+---------------------+---------------------------+--------------------+
# |          XME          | 0.47155940355940357 |          pow_XME          | 0.5704425204425203 |
# |          PICK         |  0.5180413660413661 |          pow_PICK         | 0.6363386243386243 |
# |          REMX         |  0.4314930254930255 |        log_sqrtREMX       | 0.6251361231361232 |
# |          DBB          |  0.6084011544011545 |          pow_DBB          | 0.6587195767195768 |
# |          GLD          |  0.5198239538239539 |            GLD            | 0.5198239538239539 |
# |          IAU          |  0.4296820586820586 |          log_IAU          | 0.5592462722462723 |
# |          GDX          |  0.518979316979317  |          pow_GDX          | 0.557024531024531  |
# |     price_ferrous     | 0.46938143338143334 |   log_sqrtprice_ferrous   | 0.5671053391053391 |
# |   inventory_ferrous   | 0.48176815776815773 |  bx_cx_inventory_ferrous  | 0.5865127465127464 |
# |     orders_ferrous    |  0.5286050986050986 |    pow2_orders_ferrous    | 0.580922558922559  |
# |   price_non_ferrous   |  0.5164569504569505 |   sqrt_price_non_ferrous  | 0.552075036075036  |
# | inventory_non_ferrous |   0.46098556998557  | y_J_inventory_non_ferrous | 0.6018451178451178 |
# |   orders_non_ferrous  |  0.4345930735930736 |   y_J_orders_non_ferrous  | 0.5964718614718615 |
# |     NUE_sentiment     | 0.48481240981240975 |     y_J_NUE_sentiment     | 0.5677272727272727 |
# |     STLD_sentiment    |  0.4729316979316979 |  STLD_sentiment_pca_comb  | 0.5193626743626745 |
# |     NSC_sentiment     | 0.48234199134199135 |     pow_NSC_sentiment     | 0.5530952380952382 |
# +-----------------------+---------------------+---------------------------+--------------------+
# overall best CV ROC AUC score:  0.6587195767195768
# Epoch 0 | Train Accuracy=46.43% | Train Loss=0.6721 | Val Accuracy=54.17% | Val Loss: 0.6997
# Epoch 1 | Train Accuracy=47.32% | Train Loss=0.6837 | Val Accuracy=50.00% | Val Loss: 0.7015
# Epoch 2 | Train Accuracy=46.43% | Train Loss=0.6818 | Val Accuracy=62.50% | Val Loss: 0.6916
# Epoch 3 | Train Accuracy=46.43% | Train Loss=0.6890 | Val Accuracy=62.50% | Val Loss: 0.6835
# Epoch 4 | Train Accuracy=42.86% | Train Loss=0.6712 | Val Accuracy=58.33% | Val Loss: 0.6828
# Epoch 5 | Train Accuracy=50.00% | Train Loss=0.6696 | Val Accuracy=54.17% | Val Loss: 0.6866
# Epoch 6 | Train Accuracy=45.54% | Train Loss=0.6770 | Val Accuracy=50.00% | Val Loss: 0.6900
# Epoch 7 | Train Accuracy=44.64% | Train Loss=0.6865 | Val Accuracy=45.83% | Val Loss: 0.6967
# Epoch 8 | Train Accuracy=42.86% | Train Loss=0.6915 | Val Accuracy=50.00% | Val Loss: 0.6965
# Epoch 9 | Train Accuracy=41.07% | Train Loss=0.6985 | Val Accuracy=50.00% | Val Loss: 0.7005
# Epoch 10 | Train Accuracy=44.64% | Train Loss=0.6901 | Val Accuracy=50.00% | Val Loss: 0.7063
# Epoch 11 | Train Accuracy=44.64% | Train Loss=0.6928 | Val Accuracy=45.83% | Val Loss: 0.7161
# Epoch 12 | Train Accuracy=49.11% | Train Loss=0.6969 | Val Accuracy=45.83% | Val Loss: 0.7168
# Epoch 13 | Train Accuracy=52.68% | Train Loss=0.6966 | Val Accuracy=41.67% | Val Loss: 0.7198
# Epoch 14 | Train Accuracy=52.68% | Train Loss=0.6868 | Val Accuracy=45.83% | Val Loss: 0.7121
# Epoch 15 | Train Accuracy=50.89% | Train Loss=0.6940 | Val Accuracy=37.50% | Val Loss: 0.7167
# Epoch 16 | Train Accuracy=59.82% | Train Loss=0.6939 | Val Accuracy=41.67% | Val Loss: 0.7123
# Epoch 17 | Train Accuracy=59.82% | Train Loss=0.6821 | Val Accuracy=54.17% | Val Loss: 0.6997
# Epoch 18 | Train Accuracy=59.82% | Train Loss=0.6837 | Val Accuracy=54.17% | Val Loss: 0.6994
# Epoch 19 | Train Accuracy=59.82% | Train Loss=0.6771 | Val Accuracy=54.17% | Val Loss: 0.6955
# Epoch 20 | Train Accuracy=59.82% | Train Loss=0.6753 | Val Accuracy=54.17% | Val Loss: 0.6956
# Epoch 21 | Train Accuracy=59.82% | Train Loss=0.6653 | Val Accuracy=45.83% | Val Loss: 0.7010
# Epoch 22 | Train Accuracy=59.82% | Train Loss=0.6698 | Val Accuracy=50.00% | Val Loss: 0.6965
# Epoch 23 | Train Accuracy=59.82% | Train Loss=0.6709 | Val Accuracy=45.83% | Val Loss: 0.7044
# Epoch 24 | Train Accuracy=59.82% | Train Loss=0.6726 | Val Accuracy=45.83% | Val Loss: 0.6987
# Epoch 25 | Train Accuracy=58.93% | Train Loss=0.6685 | Val Accuracy=50.00% | Val Loss: 0.6950
# Epoch 26 | Train Accuracy=58.93% | Train Loss=0.6652 | Val Accuracy=45.83% | Val Loss: 0.6996
# Epoch 27 | Train Accuracy=58.93% | Train Loss=0.6678 | Val Accuracy=54.17% | Val Loss: 0.7026
# Epoch 28 | Train Accuracy=58.93% | Train Loss=0.6654 | Val Accuracy=54.17% | Val Loss: 0.7056
# Epoch 29 | Train Accuracy=58.93% | Train Loss=0.6721 | Val Accuracy=54.17% | Val Loss: 0.7060
# Epoch 30 | Train Accuracy=58.93% | Train Loss=0.6736 | Val Accuracy=54.17% | Val Loss: 0.6975
# Epoch 31 | Train Accuracy=58.93% | Train Loss=0.6732 | Val Accuracy=54.17% | Val Loss: 0.6982
# Epoch 32 | Train Accuracy=58.93% | Train Loss=0.6726 | Val Accuracy=54.17% | Val Loss: 0.6951
# Epoch 33 | Train Accuracy=58.93% | Train Loss=0.6794 | Val Accuracy=54.17% | Val Loss: 0.6886
# Epoch 34 | Train Accuracy=58.93% | Train Loss=0.6789 | Val Accuracy=54.17% | Val Loss: 0.6885
# Epoch 35 | Train Accuracy=58.93% | Train Loss=0.6785 | Val Accuracy=54.17% | Val Loss: 0.6896
# Epoch 36 | Train Accuracy=58.93% | Train Loss=0.6782 | Val Accuracy=54.17% | Val Loss: 0.6937
# Epoch 37 | Train Accuracy=58.93% | Train Loss=0.6746 | Val Accuracy=54.17% | Val Loss: 0.6933
# Epoch 38 | Train Accuracy=58.93% | Train Loss=0.6742 | Val Accuracy=54.17% | Val Loss: 0.6928
# Epoch 39 | Train Accuracy=58.93% | Train Loss=0.6736 | Val Accuracy=54.17% | Val Loss: 0.6926
# Epoch 40 | Train Accuracy=58.93% | Train Loss=0.6733 | Val Accuracy=54.17% | Val Loss: 0.6915
# Epoch 41 | Train Accuracy=58.93% | Train Loss=0.6732 | Val Accuracy=58.33% | Val Loss: 0.6906
# Epoch 42 | Train Accuracy=58.93% | Train Loss=0.6729 | Val Accuracy=58.33% | Val Loss: 0.6897
# Epoch 43 | Train Accuracy=58.93% | Train Loss=0.6715 | Val Accuracy=58.33% | Val Loss: 0.6884
# Epoch 44 | Train Accuracy=58.93% | Train Loss=0.6734 | Val Accuracy=58.33% | Val Loss: 0.6870
# Epoch 45 | Train Accuracy=58.93% | Train Loss=0.6734 | Val Accuracy=58.33% | Val Loss: 0.6868
# Epoch 46 | Train Accuracy=58.93% | Train Loss=0.6733 | Val Accuracy=54.17% | Val Loss: 0.6921
# Epoch 47 | Train Accuracy=58.93% | Train Loss=0.6820 | Val Accuracy=54.17% | Val Loss: 0.6918
# Epoch 48 | Train Accuracy=58.93% | Train Loss=0.6812 | Val Accuracy=54.17% | Val Loss: 0.6913
# Epoch 49 | Train Accuracy=58.93% | Train Loss=0.6806 | Val Accuracy=54.17% | Val Loss: 0.6918
# Epoch 50 | Train Accuracy=58.93% | Train Loss=0.6767 | Val Accuracy=54.17% | Val Loss: 0.6936
# Epoch 51 | Train Accuracy=58.93% | Train Loss=0.6812 | Val Accuracy=54.17% | Val Loss: 0.6936
# Epoch 52 | Train Accuracy=58.93% | Train Loss=0.6803 | Val Accuracy=54.17% | Val Loss: 0.6948
# Epoch 53 | Train Accuracy=58.93% | Train Loss=0.6798 | Val Accuracy=54.17% | Val Loss: 0.6957
# Epoch 54 | Train Accuracy=58.93% | Train Loss=0.6790 | Val Accuracy=54.17% | Val Loss: 0.6956
# Epoch 55 | Train Accuracy=58.93% | Train Loss=0.6782 | Val Accuracy=54.17% | Val Loss: 0.6956
# Epoch 56 | Train Accuracy=58.93% | Train Loss=0.6775 | Val Accuracy=54.17% | Val Loss: 0.6897
# Epoch 57 | Train Accuracy=58.93% | Train Loss=0.6756 | Val Accuracy=54.17% | Val Loss: 0.6909
# Epoch 58 | Train Accuracy=58.93% | Train Loss=0.6752 | Val Accuracy=54.17% | Val Loss: 0.6888
# Epoch 59 | Train Accuracy=58.93% | Train Loss=0.6735 | Val Accuracy=54.17% | Val Loss: 0.6888
# Epoch 60 | Train Accuracy=58.93% | Train Loss=0.6734 | Val Accuracy=54.17% | Val Loss: 0.6890
# Epoch 61 | Train Accuracy=58.93% | Train Loss=0.6733 | Val Accuracy=54.17% | Val Loss: 0.6892
# Epoch 62 | Train Accuracy=58.93% | Train Loss=0.6733 | Val Accuracy=54.17% | Val Loss: 0.6893
# Epoch 63 | Train Accuracy=58.93% | Train Loss=0.6733 | Val Accuracy=54.17% | Val Loss: 0.6895
# Epoch 64 | Train Accuracy=58.93% | Train Loss=0.6733 | Val Accuracy=54.17% | Val Loss: 0.6896
# Epoch 65 | Train Accuracy=58.93% | Train Loss=0.6733 | Val Accuracy=54.17% | Val Loss: 0.6898
# Epoch 66 | Train Accuracy=58.93% | Train Loss=0.6733 | Val Accuracy=54.17% | Val Loss: 0.6898
# Epoch 67 | Train Accuracy=58.93% | Train Loss=0.6734 | Val Accuracy=54.17% | Val Loss: 0.6902
# Epoch 68 | Train Accuracy=58.93% | Train Loss=0.6741 | Val Accuracy=54.17% | Val Loss: 0.6907
# Epoch 69 | Train Accuracy=58.93% | Train Loss=0.6735 | Val Accuracy=54.17% | Val Loss: 0.6914
# Epoch 70 | Train Accuracy=58.93% | Train Loss=0.6736 | Val Accuracy=54.17% | Val Loss: 0.6908
# Epoch 71 | Train Accuracy=58.93% | Train Loss=0.6731 | Val Accuracy=54.17% | Val Loss: 0.6909
# Epoch 72 | Train Accuracy=58.93% | Train Loss=0.6734 | Val Accuracy=54.17% | Val Loss: 0.6914
# Epoch 73 | Train Accuracy=58.93% | Train Loss=0.6736 | Val Accuracy=54.17% | Val Loss: 0.6921
# Epoch 74 | Train Accuracy=58.93% | Train Loss=0.6738 | Val Accuracy=54.17% | Val Loss: 0.6934
# Epoch 75 | Train Accuracy=58.93% | Train Loss=0.6737 | Val Accuracy=54.17% | Val Loss: 0.6950
# Epoch 76 | Train Accuracy=58.93% | Train Loss=0.6736 | Val Accuracy=54.17% | Val Loss: 0.6961
# Epoch 77 | Train Accuracy=58.93% | Train Loss=0.6732 | Val Accuracy=54.17% | Val Loss: 0.6972
# Epoch 78 | Train Accuracy=58.93% | Train Loss=0.6726 | Val Accuracy=54.17% | Val Loss: 0.6985
# Epoch 79 | Train Accuracy=58.93% | Train Loss=0.6716 | Val Accuracy=54.17% | Val Loss: 0.6971
# Epoch 80 | Train Accuracy=58.93% | Train Loss=0.6717 | Val Accuracy=54.17% | Val Loss: 0.6982
# Epoch 81 | Train Accuracy=58.93% | Train Loss=0.6715 | Val Accuracy=54.17% | Val Loss: 0.6994
# Epoch 82 | Train Accuracy=58.93% | Train Loss=0.6713 | Val Accuracy=54.17% | Val Loss: 0.6992
# Epoch 83 | Train Accuracy=58.93% | Train Loss=0.6713 | Val Accuracy=54.17% | Val Loss: 0.7001
# Epoch 84 | Train Accuracy=58.93% | Train Loss=0.6710 | Val Accuracy=54.17% | Val Loss: 0.7019
# Epoch 85 | Train Accuracy=58.93% | Train Loss=0.6704 | Val Accuracy=54.17% | Val Loss: 0.7036
# Epoch 86 | Train Accuracy=58.93% | Train Loss=0.6706 | Val Accuracy=54.17% | Val Loss: 0.7037
# Epoch 87 | Train Accuracy=58.93% | Train Loss=0.6714 | Val Accuracy=54.17% | Val Loss: 0.7049
# Epoch 88 | Train Accuracy=58.93% | Train Loss=0.6716 | Val Accuracy=54.17% | Val Loss: 0.7061
# Epoch 89 | Train Accuracy=58.93% | Train Loss=0.6717 | Val Accuracy=54.17% | Val Loss: 0.7073
# Epoch 90 | Train Accuracy=58.93% | Train Loss=0.6719 | Val Accuracy=54.17% | Val Loss: 0.7059
# Epoch 91 | Train Accuracy=58.93% | Train Loss=0.6721 | Val Accuracy=54.17% | Val Loss: 0.7106
# Epoch 92 | Train Accuracy=58.93% | Train Loss=0.6722 | Val Accuracy=54.17% | Val Loss: 0.7116
# Epoch 93 | Train Accuracy=58.93% | Train Loss=0.6724 | Val Accuracy=54.17% | Val Loss: 0.7124
# Epoch 94 | Train Accuracy=58.93% | Train Loss=0.6709 | Val Accuracy=54.17% | Val Loss: 0.7099
# Epoch 95 | Train Accuracy=58.93% | Train Loss=0.6736 | Val Accuracy=54.17% | Val Loss: 0.7109
# Epoch 96 | Train Accuracy=58.93% | Train Loss=0.6730 | Val Accuracy=54.17% | Val Loss: 0.7110
# Epoch 97 | Train Accuracy=58.93% | Train Loss=0.6725 | Val Accuracy=54.17% | Val Loss: 0.7121
# Epoch 98 | Train Accuracy=58.93% | Train Loss=0.6721 | Val Accuracy=54.17% | Val Loss: 0.7132
# Epoch 99 | Train Accuracy=58.93% | Train Loss=0.6718 | Val Accuracy=54.17% | Val Loss: 0.7142
# Epoch 100 | Train Accuracy=58.93% | Train Loss=0.6716 | Val Accuracy=54.17% | Val Loss: 0.7152
# Epoch 101 | Train Accuracy=58.93% | Train Loss=0.6724 | Val Accuracy=54.17% | Val Loss: 0.7161
# Epoch 102 | Train Accuracy=58.93% | Train Loss=0.6723 | Val Accuracy=54.17% | Val Loss: 0.7170
# Epoch 103 | Train Accuracy=58.93% | Train Loss=0.6732 | Val Accuracy=54.17% | Val Loss: 0.7204
# Epoch 104 | Train Accuracy=58.93% | Train Loss=0.6732 | Val Accuracy=54.17% | Val Loss: 0.7210
# Epoch 105 | Train Accuracy=58.93% | Train Loss=0.6732 | Val Accuracy=54.17% | Val Loss: 0.7212
# Epoch 106 | Train Accuracy=58.93% | Train Loss=0.6733 | Val Accuracy=54.17% | Val Loss: 0.7214
# Epoch 107 | Train Accuracy=58.93% | Train Loss=0.6734 | Val Accuracy=54.17% | Val Loss: 0.7273
# Epoch 108 | Train Accuracy=58.93% | Train Loss=0.6735 | Val Accuracy=54.17% | Val Loss: 0.7279
# Epoch 109 | Train Accuracy=58.93% | Train Loss=0.6738 | Val Accuracy=54.17% | Val Loss: 0.7290
# Epoch 110 | Train Accuracy=58.93% | Train Loss=0.6651 | Val Accuracy=54.17% | Val Loss: 0.7298
# Epoch 111 | Train Accuracy=58.93% | Train Loss=0.6651 | Val Accuracy=54.17% | Val Loss: 0.7304
# Epoch 112 | Train Accuracy=58.93% | Train Loss=0.6651 | Val Accuracy=54.17% | Val Loss: 0.7308
# Epoch 113 | Train Accuracy=58.93% | Train Loss=0.6652 | Val Accuracy=54.17% | Val Loss: 0.7312
# Epoch 114 | Train Accuracy=58.93% | Train Loss=0.6652 | Val Accuracy=54.17% | Val Loss: 0.7377
# Epoch 115 | Train Accuracy=58.93% | Train Loss=0.6652 | Val Accuracy=54.17% | Val Loss: 0.7380
# Epoch 116 | Train Accuracy=58.93% | Train Loss=0.6653 | Val Accuracy=54.17% | Val Loss: 0.7384
# Epoch 117 | Train Accuracy=58.93% | Train Loss=0.6653 | Val Accuracy=54.17% | Val Loss: 0.7388
# Epoch 118 | Train Accuracy=58.93% | Train Loss=0.6653 | Val Accuracy=54.17% | Val Loss: 0.7393
# Epoch 119 | Train Accuracy=58.93% | Train Loss=0.6653 | Val Accuracy=54.17% | Val Loss: 0.7398
# Epoch 120 | Train Accuracy=58.93% | Train Loss=0.6654 | Val Accuracy=54.17% | Val Loss: 0.7404
# Epoch 121 | Train Accuracy=58.93% | Train Loss=0.6811 | Val Accuracy=54.17% | Val Loss: 0.7409
# Epoch 122 | Train Accuracy=58.93% | Train Loss=0.6812 | Val Accuracy=54.17% | Val Loss: 0.7411
# Epoch 123 | Train Accuracy=58.93% | Train Loss=0.6813 | Val Accuracy=54.17% | Val Loss: 0.7412
# Epoch 124 | Train Accuracy=58.93% | Train Loss=0.6814 | Val Accuracy=54.17% | Val Loss: 0.7412
# Epoch 125 | Train Accuracy=58.93% | Train Loss=0.6814 | Val Accuracy=54.17% | Val Loss: 0.7412
# Epoch 126 | Train Accuracy=58.93% | Train Loss=0.6718 | Val Accuracy=54.17% | Val Loss: 0.7412
# Epoch 127 | Train Accuracy=58.93% | Train Loss=0.6718 | Val Accuracy=54.17% | Val Loss: 0.7411
# Epoch 128 | Train Accuracy=58.93% | Train Loss=0.6719 | Val Accuracy=54.17% | Val Loss: 0.7412
# Epoch 129 | Train Accuracy=58.93% | Train Loss=0.6719 | Val Accuracy=54.17% | Val Loss: 0.7412
# Epoch 130 | Train Accuracy=58.93% | Train Loss=0.6719 | Val Accuracy=54.17% | Val Loss: 0.7478
# Epoch 131 | Train Accuracy=58.93% | Train Loss=0.6720 | Val Accuracy=54.17% | Val Loss: 0.7478
# Epoch 132 | Train Accuracy=58.93% | Train Loss=0.6720 | Val Accuracy=54.17% | Val Loss: 0.7478
# Epoch 133 | Train Accuracy=58.93% | Train Loss=0.6720 | Val Accuracy=54.17% | Val Loss: 0.7409
# Epoch 134 | Train Accuracy=58.93% | Train Loss=0.6666 | Val Accuracy=54.17% | Val Loss: 0.7410
# Epoch 135 | Train Accuracy=58.93% | Train Loss=0.6666 | Val Accuracy=54.17% | Val Loss: 0.7412
# Epoch 136 | Train Accuracy=58.93% | Train Loss=0.6666 | Val Accuracy=54.17% | Val Loss: 0.7414
# Epoch 137 | Train Accuracy=58.93% | Train Loss=0.6666 | Val Accuracy=54.17% | Val Loss: 0.7418
# Epoch 138 | Train Accuracy=58.93% | Train Loss=0.6666 | Val Accuracy=54.17% | Val Loss: 0.7421
# Epoch 139 | Train Accuracy=58.93% | Train Loss=0.6666 | Val Accuracy=54.17% | Val Loss: 0.7424
# Epoch 140 | Train Accuracy=58.93% | Train Loss=0.6667 | Val Accuracy=54.17% | Val Loss: 0.7425
# Epoch 141 | Train Accuracy=58.93% | Train Loss=0.6667 | Val Accuracy=54.17% | Val Loss: 0.7428
# Epoch 142 | Train Accuracy=58.93% | Train Loss=0.6667 | Val Accuracy=54.17% | Val Loss: 0.7430
# Epoch 143 | Train Accuracy=58.93% | Train Loss=0.6668 | Val Accuracy=54.17% | Val Loss: 0.7432
# Epoch 144 | Train Accuracy=58.93% | Train Loss=0.6668 | Val Accuracy=54.17% | Val Loss: 0.7432
# Epoch 145 | Train Accuracy=58.93% | Train Loss=0.6668 | Val Accuracy=54.17% | Val Loss: 0.7431
# Epoch 146 | Train Accuracy=58.93% | Train Loss=0.6668 | Val Accuracy=54.17% | Val Loss: 0.7430
# Epoch 147 | Train Accuracy=58.93% | Train Loss=0.6669 | Val Accuracy=54.17% | Val Loss: 0.7429
# Epoch 148 | Train Accuracy=58.93% | Train Loss=0.6669 | Val Accuracy=54.17% | Val Loss: 0.7426
# Epoch 149 | Train Accuracy=58.93% | Train Loss=0.6669 | Val Accuracy=54.17% | Val Loss: 0.7422
# Epoch 150 | Train Accuracy=58.93% | Train Loss=0.6830 | Val Accuracy=54.17% | Val Loss: 0.7416
# Epoch 151 | Train Accuracy=58.93% | Train Loss=0.6828 | Val Accuracy=54.17% | Val Loss: 0.7407
# Epoch 152 | Train Accuracy=58.93% | Train Loss=0.6826 | Val Accuracy=54.17% | Val Loss: 0.7398
# Epoch 153 | Train Accuracy=58.93% | Train Loss=0.6823 | Val Accuracy=54.17% | Val Loss: 0.7389
# Epoch 154 | Train Accuracy=58.93% | Train Loss=0.6821 | Val Accuracy=54.17% | Val Loss: 0.7380
# Epoch 155 | Train Accuracy=58.93% | Train Loss=0.6819 | Val Accuracy=54.17% | Val Loss: 0.7372
# Epoch 156 | Train Accuracy=58.93% | Train Loss=0.6817 | Val Accuracy=54.17% | Val Loss: 0.7364
# Epoch 157 | Train Accuracy=58.93% | Train Loss=0.6816 | Val Accuracy=54.17% | Val Loss: 0.7357
# Epoch 158 | Train Accuracy=58.93% | Train Loss=0.6814 | Val Accuracy=54.17% | Val Loss: 0.7350
# Epoch 159 | Train Accuracy=58.93% | Train Loss=0.6812 | Val Accuracy=54.17% | Val Loss: 0.7344
# Epoch 160 | Train Accuracy=58.93% | Train Loss=0.6811 | Val Accuracy=54.17% | Val Loss: 0.7339
# Epoch 161 | Train Accuracy=58.93% | Train Loss=0.6810 | Val Accuracy=54.17% | Val Loss: 0.7334
# Epoch 162 | Train Accuracy=58.93% | Train Loss=0.6809 | Val Accuracy=54.17% | Val Loss: 0.7330
# Epoch 163 | Train Accuracy=58.93% | Train Loss=0.6808 | Val Accuracy=54.17% | Val Loss: 0.7327
# Epoch 164 | Train Accuracy=58.93% | Train Loss=0.6807 | Val Accuracy=54.17% | Val Loss: 0.7324
# Epoch 165 | Train Accuracy=58.93% | Train Loss=0.6807 | Val Accuracy=54.17% | Val Loss: 0.7322
# Epoch 166 | Train Accuracy=58.93% | Train Loss=0.6807 | Val Accuracy=54.17% | Val Loss: 0.7377
# Epoch 167 | Train Accuracy=58.93% | Train Loss=0.6806 | Val Accuracy=54.17% | Val Loss: 0.7376
# Epoch 168 | Train Accuracy=58.93% | Train Loss=0.6806 | Val Accuracy=54.17% | Val Loss: 0.7374
# Epoch 169 | Train Accuracy=58.93% | Train Loss=0.6805 | Val Accuracy=54.17% | Val Loss: 0.7372
# Epoch 170 | Train Accuracy=58.93% | Train Loss=0.6805 | Val Accuracy=54.17% | Val Loss: 0.7369
# Epoch 171 | Train Accuracy=58.93% | Train Loss=0.6804 | Val Accuracy=54.17% | Val Loss: 0.7366
# Epoch 172 | Train Accuracy=58.93% | Train Loss=0.6804 | Val Accuracy=54.17% | Val Loss: 0.7363
# Epoch 173 | Train Accuracy=58.93% | Train Loss=0.6803 | Val Accuracy=54.17% | Val Loss: 0.7359
# Epoch 174 | Train Accuracy=58.93% | Train Loss=0.6802 | Val Accuracy=54.17% | Val Loss: 0.7356
# Epoch 175 | Train Accuracy=58.93% | Train Loss=0.6801 | Val Accuracy=54.17% | Val Loss: 0.7353
# Epoch 176 | Train Accuracy=58.93% | Train Loss=0.6801 | Val Accuracy=54.17% | Val Loss: 0.7349
# Epoch 177 | Train Accuracy=58.93% | Train Loss=0.6800 | Val Accuracy=54.17% | Val Loss: 0.7346
# Epoch 178 | Train Accuracy=58.93% | Train Loss=0.6799 | Val Accuracy=54.17% | Val Loss: 0.7343
# Epoch 179 | Train Accuracy=58.93% | Train Loss=0.6799 | Val Accuracy=54.17% | Val Loss: 0.7342
# Epoch 180 | Train Accuracy=58.93% | Train Loss=0.6799 | Val Accuracy=54.17% | Val Loss: 0.7340
# Epoch 181 | Train Accuracy=58.93% | Train Loss=0.6799 | Val Accuracy=54.17% | Val Loss: 0.7339
# Epoch 182 | Train Accuracy=58.93% | Train Loss=0.6799 | Val Accuracy=54.17% | Val Loss: 0.7339
# Epoch 183 | Train Accuracy=58.93% | Train Loss=0.6799 | Val Accuracy=54.17% | Val Loss: 0.7340
# Epoch 184 | Train Accuracy=58.93% | Train Loss=0.6799 | Val Accuracy=54.17% | Val Loss: 0.7341
# Epoch 185 | Train Accuracy=58.93% | Train Loss=0.6799 | Val Accuracy=54.17% | Val Loss: 0.7342
# Epoch 186 | Train Accuracy=58.93% | Train Loss=0.6789 | Val Accuracy=54.17% | Val Loss: 0.7336
# Epoch 187 | Train Accuracy=58.93% | Train Loss=0.6790 | Val Accuracy=54.17% | Val Loss: 0.7338
# Epoch 188 | Train Accuracy=58.93% | Train Loss=0.6790 | Val Accuracy=54.17% | Val Loss: 0.7340
# Epoch 189 | Train Accuracy=58.93% | Train Loss=0.6791 | Val Accuracy=54.17% | Val Loss: 0.7341
# Epoch 190 | Train Accuracy=58.93% | Train Loss=0.6791 | Val Accuracy=54.17% | Val Loss: 0.7344
# Epoch 191 | Train Accuracy=58.93% | Train Loss=0.6792 | Val Accuracy=54.17% | Val Loss: 0.7347
# Epoch 192 | Train Accuracy=58.93% | Train Loss=0.6793 | Val Accuracy=54.17% | Val Loss: 0.7350
# Epoch 193 | Train Accuracy=58.93% | Train Loss=0.6794 | Val Accuracy=54.17% | Val Loss: 0.7353
# Epoch 194 | Train Accuracy=58.93% | Train Loss=0.6715 | Val Accuracy=54.17% | Val Loss: 0.7158
# Epoch 195 | Train Accuracy=58.93% | Train Loss=0.6721 | Val Accuracy=54.17% | Val Loss: 0.6886
# Epoch 196 | Train Accuracy=58.93% | Train Loss=0.6739 | Val Accuracy=54.17% | Val Loss: 0.6889
# Epoch 197 | Train Accuracy=58.93% | Train Loss=0.6738 | Val Accuracy=54.17% | Val Loss: 0.6892
# Epoch 198 | Train Accuracy=58.93% | Train Loss=0.6736 | Val Accuracy=54.17% | Val Loss: 0.6895
# Epoch 199 | Train Accuracy=58.93% | Train Loss=0.6735 | Val Accuracy=54.17% | Val Loss: 0.6894
# Epoch 200 | Train Accuracy=58.93% | Train Loss=0.6734 | Val Accuracy=54.17% | Val Loss: 0.6898
# Epoch 201 | Train Accuracy=58.93% | Train Loss=0.6733 | Val Accuracy=54.17% | Val Loss: 0.6901
# Epoch 202 | Train Accuracy=58.93% | Train Loss=0.6732 | Val Accuracy=54.17% | Val Loss: 0.6904
# Epoch 203 | Train Accuracy=58.93% | Train Loss=0.6732 | Val Accuracy=54.17% | Val Loss: 0.6907
# Epoch 204 | Train Accuracy=58.93% | Train Loss=0.6731 | Val Accuracy=54.17% | Val Loss: 0.6909
# Epoch 205 | Train Accuracy=58.93% | Train Loss=0.6731 | Val Accuracy=54.17% | Val Loss: 0.6912
# Epoch 206 | Train Accuracy=58.93% | Train Loss=0.6730 | Val Accuracy=54.17% | Val Loss: 0.6914
# Epoch 207 | Train Accuracy=58.93% | Train Loss=0.6730 | Val Accuracy=54.17% | Val Loss: 0.6916
# Epoch 208 | Train Accuracy=58.93% | Train Loss=0.6730 | Val Accuracy=54.17% | Val Loss: 0.6918
# Epoch 209 | Train Accuracy=58.93% | Train Loss=0.6730 | Val Accuracy=54.17% | Val Loss: 0.6920
# Epoch 210 | Train Accuracy=58.93% | Train Loss=0.6729 | Val Accuracy=54.17% | Val Loss: 0.6922
# Epoch 211 | Train Accuracy=58.93% | Train Loss=0.6729 | Val Accuracy=54.17% | Val Loss: 0.6923
# Epoch 212 | Train Accuracy=58.93% | Train Loss=0.6729 | Val Accuracy=54.17% | Val Loss: 0.6924
# Epoch 213 | Train Accuracy=58.93% | Train Loss=0.6729 | Val Accuracy=54.17% | Val Loss: 0.6925
# Epoch 214 | Train Accuracy=58.93% | Train Loss=0.6729 | Val Accuracy=54.17% | Val Loss: 0.6927
# Epoch 215 | Train Accuracy=58.93% | Train Loss=0.6729 | Val Accuracy=54.17% | Val Loss: 0.6928
# Epoch 216 | Train Accuracy=58.93% | Train Loss=0.6729 | Val Accuracy=54.17% | Val Loss: 0.6928
# Epoch 217 | Train Accuracy=58.93% | Train Loss=0.6729 | Val Accuracy=54.17% | Val Loss: 0.6929
# Epoch 218 | Train Accuracy=58.93% | Train Loss=0.6728 | Val Accuracy=54.17% | Val Loss: 0.6930
# Epoch 219 | Train Accuracy=58.93% | Train Loss=0.6728 | Val Accuracy=54.17% | Val Loss: 0.6931
# Epoch 220 | Train Accuracy=58.93% | Train Loss=0.6728 | Val Accuracy=54.17% | Val Loss: 0.6931
# Epoch 221 | Train Accuracy=58.93% | Train Loss=0.6728 | Val Accuracy=54.17% | Val Loss: 0.6932
# Epoch 222 | Train Accuracy=58.93% | Train Loss=0.6728 | Val Accuracy=54.17% | Val Loss: 0.6933
# Epoch 223 | Train Accuracy=58.93% | Train Loss=0.6728 | Val Accuracy=54.17% | Val Loss: 0.6933
# Epoch 224 | Train Accuracy=58.93% | Train Loss=0.6728 | Val Accuracy=54.17% | Val Loss: 0.6934
# Epoch 225 | Train Accuracy=58.93% | Train Loss=0.6728 | Val Accuracy=54.17% | Val Loss: 0.6934
# Epoch 226 | Train Accuracy=58.93% | Train Loss=0.6728 | Val Accuracy=54.17% | Val Loss: 0.6934
# Epoch 227 | Train Accuracy=58.93% | Train Loss=0.6728 | Val Accuracy=54.17% | Val Loss: 0.6935
# Epoch 228 | Train Accuracy=58.93% | Train Loss=0.6728 | Val Accuracy=54.17% | Val Loss: 0.6935
# Epoch 229 | Train Accuracy=58.93% | Train Loss=0.6728 | Val Accuracy=54.17% | Val Loss: 0.6935
# Epoch 230 | Train Accuracy=58.93% | Train Loss=0.6728 | Val Accuracy=54.17% | Val Loss: 0.6936
# Epoch 231 | Train Accuracy=58.93% | Train Loss=0.6728 | Val Accuracy=54.17% | Val Loss: 0.6936
# Epoch 232 | Train Accuracy=58.93% | Train Loss=0.6728 | Val Accuracy=54.17% | Val Loss: 0.6936
# Epoch 233 | Train Accuracy=58.93% | Train Loss=0.6728 | Val Accuracy=54.17% | Val Loss: 0.6936
# Epoch 234 | Train Accuracy=58.93% | Train Loss=0.6728 | Val Accuracy=54.17% | Val Loss: 0.6937
# Epoch 235 | Train Accuracy=58.93% | Train Loss=0.6728 | Val Accuracy=54.17% | Val Loss: 0.6937
# Epoch 236 | Train Accuracy=58.93% | Train Loss=0.6728 | Val Accuracy=54.17% | Val Loss: 0.6937
# Epoch 237 | Train Accuracy=58.93% | Train Loss=0.6728 | Val Accuracy=54.17% | Val Loss: 0.6937
# Epoch 238 | Train Accuracy=58.93% | Train Loss=0.6728 | Val Accuracy=54.17% | Val Loss: 0.6937
# Epoch 239 | Train Accuracy=58.93% | Train Loss=0.6728 | Val Accuracy=54.17% | Val Loss: 0.6937
# Epoch 240 | Train Accuracy=58.93% | Train Loss=0.6728 | Val Accuracy=54.17% | Val Loss: 0.6938
# Epoch 241 | Train Accuracy=58.93% | Train Loss=0.6728 | Val Accuracy=54.17% | Val Loss: 0.6938
# Epoch 242 | Train Accuracy=58.93% | Train Loss=0.6728 | Val Accuracy=54.17% | Val Loss: 0.6938
# Epoch 243 | Train Accuracy=58.93% | Train Loss=0.6728 | Val Accuracy=54.17% | Val Loss: 0.6938
# Epoch 244 | Train Accuracy=58.93% | Train Loss=0.6728 | Val Accuracy=54.17% | Val Loss: 0.6938
# Epoch 245 | Train Accuracy=58.93% | Train Loss=0.6727 | Val Accuracy=54.17% | Val Loss: 0.6938
# Epoch 246 | Train Accuracy=58.93% | Train Loss=0.6727 | Val Accuracy=54.17% | Val Loss: 0.6938
# Epoch 247 | Train Accuracy=58.93% | Train Loss=0.6727 | Val Accuracy=54.17% | Val Loss: 0.6938
# Epoch 248 | Train Accuracy=58.93% | Train Loss=0.6727 | Val Accuracy=54.17% | Val Loss: 0.6938
# ...
# Epoch 336 | Train Accuracy=58.93% | Train Loss=0.6706 | Val Accuracy=54.17% | Val Loss: 0.6927
# Epoch 337 | Train Accuracy=58.93% | Train Loss=0.6706 | Val Accuracy=54.17% | Val Loss: 0.6927
# Epoch 338 | Train Accuracy=58.93% | Train Loss=0.6705 | Val Accuracy=54.17% | Val Loss: 0.6927
# Epoch 339 | Train Accuracy=58.93% | Train Loss=0.6705 | Val Accuracy=54.17% | Val Loss: 0.6927
# Epoch 340 | Train Accuracy=58.93% | Train Loss=0.6705 | Val Accuracy=54.17% | Val Loss: 0.6927
# Epoch 341 | Train Accuracy=58.93% | Train Loss=0.6704 | Val Accuracy=54.17% | Val Loss: 0.6927
# Epoch 342 | Train Accuracy=58.93% | Train Loss=0.6704 | Val Accuracy=54.17% | Val Loss: 0.6927
# Epoch 343 | Train Accuracy=58.93% | Train Loss=0.6704 | Val Accuracy=54.17% | Val Loss: 0.6928
# Epoch 344 | Train Accuracy=58.93% | Train Loss=0.6703 | Val Accuracy=54.17% | Val Loss: 0.6928
# Epoch 345 | Train Accuracy=58.93% | Train Loss=0.6703 | Val Accuracy=54.17% | Val Loss: 0.6936
# Epoch 346 | Train Accuracy=58.93% | Train Loss=0.6703 | Val Accuracy=54.17% | Val Loss: 0.6936
# Epoch 347 | Train Accuracy=58.93% | Train Loss=0.6703 | Val Accuracy=54.17% | Val Loss: 0.6936
# Epoch 348 | Train Accuracy=58.93% | Train Loss=0.6702 | Val Accuracy=54.17% | Val Loss: 0.6936
# Epoch 349 | Train Accuracy=58.93% | Train Loss=0.6702 | Val Accuracy=54.17% | Val Loss: 0.6947
# Epoch 350 | Train Accuracy=58.93% | Train Loss=0.6702 | Val Accuracy=54.17% | Val Loss: 0.6948
# Epoch 351 | Train Accuracy=58.93% | Train Loss=0.6701 | Val Accuracy=54.17% | Val Loss: 0.6948
# Epoch 352 | Train Accuracy=58.93% | Train Loss=0.6701 | Val Accuracy=54.17% | Val Loss: 0.6948
# Epoch 353 | Train Accuracy=58.93% | Train Loss=0.6701 | Val Accuracy=54.17% | Val Loss: 0.6949
# Epoch 354 | Train Accuracy=58.93% | Train Loss=0.6700 | Val Accuracy=54.17% | Val Loss: 0.6949
# Epoch 355 | Train Accuracy=58.93% | Train Loss=0.6700 | Val Accuracy=54.17% | Val Loss: 0.6949
# Epoch 356 | Train Accuracy=58.93% | Train Loss=0.6700 | Val Accuracy=54.17% | Val Loss: 0.6950
# Epoch 357 | Train Accuracy=58.93% | Train Loss=0.6699 | Val Accuracy=54.17% | Val Loss: 0.6950
# Epoch 358 | Train Accuracy=58.93% | Train Loss=0.6699 | Val Accuracy=54.17% | Val Loss: 0.6950
# Epoch 359 | Train Accuracy=58.93% | Train Loss=0.6699 | Val Accuracy=54.17% | Val Loss: 0.6950
# Epoch 360 | Train Accuracy=58.93% | Train Loss=0.6698 | Val Accuracy=54.17% | Val Loss: 0.6951
# Epoch 361 | Train Accuracy=58.93% | Train Loss=0.6698 | Val Accuracy=54.17% | Val Loss: 0.6951
# Epoch 362 | Train Accuracy=58.93% | Train Loss=0.6698 | Val Accuracy=54.17% | Val Loss: 0.6951
# Epoch 363 | Train Accuracy=58.93% | Train Loss=0.6697 | Val Accuracy=54.17% | Val Loss: 0.6952
# Epoch 364 | Train Accuracy=58.93% | Train Loss=0.6697 | Val Accuracy=54.17% | Val Loss: 0.6952
# Epoch 365 | Train Accuracy=58.93% | Train Loss=0.6697 | Val Accuracy=54.17% | Val Loss: 0.6952
# Epoch 366 | Train Accuracy=58.93% | Train Loss=0.6697 | Val Accuracy=54.17% | Val Loss: 0.6953
# Epoch 367 | Train Accuracy=58.93% | Train Loss=0.6696 | Val Accuracy=54.17% | Val Loss: 0.6953
# Epoch 368 | Train Accuracy=58.93% | Train Loss=0.6696 | Val Accuracy=54.17% | Val Loss: 0.6953
# Epoch 369 | Train Accuracy=58.93% | Train Loss=0.6696 | Val Accuracy=54.17% | Val Loss: 0.6953
# Epoch 370 | Train Accuracy=58.93% | Train Loss=0.6695 | Val Accuracy=54.17% | Val Loss: 0.6954
# Epoch 371 | Train Accuracy=58.93% | Train Loss=0.6695 | Val Accuracy=54.17% | Val Loss: 0.6954
# Epoch 372 | Train Accuracy=58.93% | Train Loss=0.6695 | Val Accuracy=54.17% | Val Loss: 0.6954
# Epoch 373 | Train Accuracy=58.93% | Train Loss=0.6694 | Val Accuracy=54.17% | Val Loss: 0.6954
# Epoch 374 | Train Accuracy=58.93% | Train Loss=0.6694 | Val Accuracy=54.17% | Val Loss: 0.6944
# Epoch 375 | Train Accuracy=58.93% | Train Loss=0.6694 | Val Accuracy=54.17% | Val Loss: 0.6944
# Epoch 376 | Train Accuracy=58.93% | Train Loss=0.6693 | Val Accuracy=54.17% | Val Loss: 0.6945
# Epoch 377 | Train Accuracy=58.93% | Train Loss=0.6693 | Val Accuracy=54.17% | Val Loss: 0.6945
# Epoch 378 | Train Accuracy=58.93% | Train Loss=0.6693 | Val Accuracy=54.17% | Val Loss: 0.6945
# Epoch 379 | Train Accuracy=58.93% | Train Loss=0.6693 | Val Accuracy=54.17% | Val Loss: 0.6945
# Epoch 380 | Train Accuracy=58.93% | Train Loss=0.6692 | Val Accuracy=54.17% | Val Loss: 0.6945
# Epoch 381 | Train Accuracy=58.93% | Train Loss=0.6692 | Val Accuracy=54.17% | Val Loss: 0.6945
# Epoch 382 | Train Accuracy=58.93% | Train Loss=0.6692 | Val Accuracy=54.17% | Val Loss: 0.6945
# Epoch 383 | Train Accuracy=58.93% | Train Loss=0.6691 | Val Accuracy=54.17% | Val Loss: 0.6945
# Epoch 384 | Train Accuracy=58.93% | Train Loss=0.6691 | Val Accuracy=54.17% | Val Loss: 0.6945
# Epoch 385 | Train Accuracy=58.93% | Train Loss=0.6691 | Val Accuracy=54.17% | Val Loss: 0.6946
# Epoch 386 | Train Accuracy=58.93% | Train Loss=0.6690 | Val Accuracy=54.17% | Val Loss: 0.6946
# Epoch 387 | Train Accuracy=58.93% | Train Loss=0.6690 | Val Accuracy=54.17% | Val Loss: 0.6946
# Epoch 388 | Train Accuracy=58.93% | Train Loss=0.6690 | Val Accuracy=54.17% | Val Loss: 0.6946
# Epoch 389 | Train Accuracy=58.93% | Train Loss=0.6690 | Val Accuracy=54.17% | Val Loss: 0.6946
# Epoch 390 | Train Accuracy=58.93% | Train Loss=0.6689 | Val Accuracy=54.17% | Val Loss: 0.6946
# Epoch 391 | Train Accuracy=58.93% | Train Loss=0.6689 | Val Accuracy=54.17% | Val Loss: 0.6946
# Epoch 392 | Train Accuracy=58.93% | Train Loss=0.6689 | Val Accuracy=54.17% | Val Loss: 0.6946
# Epoch 393 | Train Accuracy=58.93% | Train Loss=0.6688 | Val Accuracy=54.17% | Val Loss: 0.6946
# Epoch 394 | Train Accuracy=58.93% | Train Loss=0.6688 | Val Accuracy=54.17% | Val Loss: 0.6947
# Epoch 395 | Train Accuracy=58.93% | Train Loss=0.6688 | Val Accuracy=54.17% | Val Loss: 0.6947
# Epoch 396 | Train Accuracy=58.93% | Train Loss=0.6687 | Val Accuracy=54.17% | Val Loss: 0.6947
# Epoch 397 | Train Accuracy=58.93% | Train Loss=0.6687 | Val Accuracy=54.17% | Val Loss: 0.6947
# Epoch 398 | Train Accuracy=58.93% | Train Loss=0.6687 | Val Accuracy=54.17% | Val Loss: 0.6947
# Epoch 399 | Train Accuracy=58.93% | Train Loss=0.6687 | Val Accuracy=54.17% | Val Loss: 0.6947
# Epoch 400 | Train Accuracy=58.93% | Train Loss=0.6686 | Val Accuracy=54.17% | Val Loss: 0.6947
# Epoch 401 | Train Accuracy=58.93% | Train Loss=0.6686 | Val Accuracy=54.17% | Val Loss: 0.6947
# Epoch 402 | Train Accuracy=58.93% | Train Loss=0.6685 | Val Accuracy=54.17% | Val Loss: 0.6947
# Epoch 403 | Train Accuracy=58.93% | Train Loss=0.6685 | Val Accuracy=54.17% | Val Loss: 0.6947
# Epoch 404 | Train Accuracy=58.93% | Train Loss=0.6685 | Val Accuracy=54.17% | Val Loss: 0.6947
# Epoch 405 | Train Accuracy=58.93% | Train Loss=0.6684 | Val Accuracy=54.17% | Val Loss: 0.6947
# Epoch 406 | Train Accuracy=58.93% | Train Loss=0.6684 | Val Accuracy=54.17% | Val Loss: 0.6947
# Epoch 407 | Train Accuracy=58.93% | Train Loss=0.6684 | Val Accuracy=54.17% | Val Loss: 0.6946
# Epoch 408 | Train Accuracy=58.93% | Train Loss=0.6683 | Val Accuracy=54.17% | Val Loss: 0.6946
# Epoch 409 | Train Accuracy=58.93% | Train Loss=0.6683 | Val Accuracy=54.17% | Val Loss: 0.6946
# Epoch 410 | Train Accuracy=58.93% | Train Loss=0.6682 | Val Accuracy=54.17% | Val Loss: 0.6946
# Epoch 411 | Train Accuracy=58.93% | Train Loss=0.6682 | Val Accuracy=54.17% | Val Loss: 0.6945
# Epoch 412 | Train Accuracy=58.93% | Train Loss=0.6681 | Val Accuracy=54.17% | Val Loss: 0.6945
# Epoch 413 | Train Accuracy=58.93% | Train Loss=0.6681 | Val Accuracy=54.17% | Val Loss: 0.6945
# Epoch 414 | Train Accuracy=58.93% | Train Loss=0.6681 | Val Accuracy=54.17% | Val Loss: 0.6945
# Epoch 415 | Train Accuracy=58.93% | Train Loss=0.6680 | Val Accuracy=54.17% | Val Loss: 0.6945
# Epoch 416 | Train Accuracy=58.93% | Train Loss=0.6680 | Val Accuracy=54.17% | Val Loss: 0.6945
# Epoch 417 | Train Accuracy=58.93% | Train Loss=0.6679 | Val Accuracy=54.17% | Val Loss: 0.6944
# Epoch 418 | Train Accuracy=58.93% | Train Loss=0.6679 | Val Accuracy=54.17% | Val Loss: 0.6944
# Epoch 419 | Train Accuracy=58.93% | Train Loss=0.6678 | Val Accuracy=54.17% | Val Loss: 0.6944
# Epoch 420 | Train Accuracy=58.93% | Train Loss=0.6678 | Val Accuracy=54.17% | Val Loss: 0.6944
# Epoch 421 | Train Accuracy=58.93% | Train Loss=0.6678 | Val Accuracy=54.17% | Val Loss: 0.6944
# Epoch 422 | Train Accuracy=58.93% | Train Loss=0.6677 | Val Accuracy=54.17% | Val Loss: 0.6944
# Epoch 423 | Train Accuracy=58.93% | Train Loss=0.6677 | Val Accuracy=54.17% | Val Loss: 0.6944
# Epoch 424 | Train Accuracy=58.93% | Train Loss=0.6676 | Val Accuracy=54.17% | Val Loss: 0.6944
# Epoch 425 | Train Accuracy=58.93% | Train Loss=0.6676 | Val Accuracy=54.17% | Val Loss: 0.6943
# Epoch 426 | Train Accuracy=58.93% | Train Loss=0.6675 | Val Accuracy=54.17% | Val Loss: 0.6943
# Epoch 427 | Train Accuracy=58.93% | Train Loss=0.6675 | Val Accuracy=54.17% | Val Loss: 0.6943
# Epoch 428 | Train Accuracy=58.93% | Train Loss=0.6675 | Val Accuracy=54.17% | Val Loss: 0.6943
# Epoch 429 | Train Accuracy=58.93% | Train Loss=0.6674 | Val Accuracy=54.17% | Val Loss: 0.6943
# Epoch 430 | Train Accuracy=58.93% | Train Loss=0.6674 | Val Accuracy=54.17% | Val Loss: 0.6943
# Epoch 431 | Train Accuracy=58.93% | Train Loss=0.6673 | Val Accuracy=54.17% | Val Loss: 0.6943
# Epoch 432 | Train Accuracy=58.93% | Train Loss=0.6673 | Val Accuracy=54.17% | Val Loss: 0.6943
# Epoch 433 | Train Accuracy=58.93% | Train Loss=0.6673 | Val Accuracy=54.17% | Val Loss: 0.6943
# Epoch 434 | Train Accuracy=58.93% | Train Loss=0.6672 | Val Accuracy=54.17% | Val Loss: 0.6943
# Epoch 435 | Train Accuracy=58.93% | Train Loss=0.6672 | Val Accuracy=54.17% | Val Loss: 0.6943
# Epoch 436 | Train Accuracy=58.93% | Train Loss=0.6671 | Val Accuracy=54.17% | Val Loss: 0.6943
# Epoch 437 | Train Accuracy=58.93% | Train Loss=0.6671 | Val Accuracy=54.17% | Val Loss: 0.6942
# Epoch 438 | Train Accuracy=58.93% | Train Loss=0.6670 | Val Accuracy=54.17% | Val Loss: 0.6942
# Epoch 439 | Train Accuracy=58.93% | Train Loss=0.6670 | Val Accuracy=54.17% | Val Loss: 0.6942
# Epoch 440 | Train Accuracy=58.93% | Train Loss=0.6670 | Val Accuracy=54.17% | Val Loss: 0.6942
# Epoch 441 | Train Accuracy=58.93% | Train Loss=0.6669 | Val Accuracy=54.17% | Val Loss: 0.6942
# Epoch 442 | Train Accuracy=58.93% | Train Loss=0.6669 | Val Accuracy=54.17% | Val Loss: 0.6942
# Epoch 443 | Train Accuracy=58.93% | Train Loss=0.6668 | Val Accuracy=54.17% | Val Loss: 0.6942
# Epoch 444 | Train Accuracy=58.93% | Train Loss=0.6668 | Val Accuracy=54.17% | Val Loss: 0.6942
# Epoch 445 | Train Accuracy=58.93% | Train Loss=0.6667 | Val Accuracy=54.17% | Val Loss: 0.6942
# Epoch 446 | Train Accuracy=58.93% | Train Loss=0.6667 | Val Accuracy=54.17% | Val Loss: 0.6942
# Epoch 447 | Train Accuracy=58.93% | Train Loss=0.6666 | Val Accuracy=54.17% | Val Loss: 0.6942
# Epoch 448 | Train Accuracy=58.93% | Train Loss=0.6666 | Val Accuracy=54.17% | Val Loss: 0.6941
# Epoch 449 | Train Accuracy=58.93% | Train Loss=0.6666 | Val Accuracy=54.17% | Val Loss: 0.6941
# Epoch 450 | Train Accuracy=58.93% | Train Loss=0.6665 | Val Accuracy=54.17% | Val Loss: 0.6941
# Epoch 451 | Train Accuracy=58.93% | Train Loss=0.6665 | Val Accuracy=54.17% | Val Loss: 0.6941
# Epoch 452 | Train Accuracy=58.93% | Train Loss=0.6664 | Val Accuracy=54.17% | Val Loss: 0.6941
# Epoch 453 | Train Accuracy=58.93% | Train Loss=0.6664 | Val Accuracy=54.17% | Val Loss: 0.6940
# Epoch 454 | Train Accuracy=58.93% | Train Loss=0.6663 | Val Accuracy=54.17% | Val Loss: 0.6940
# Epoch 455 | Train Accuracy=58.93% | Train Loss=0.6663 | Val Accuracy=54.17% | Val Loss: 0.6940
# Epoch 456 | Train Accuracy=58.93% | Train Loss=0.6662 | Val Accuracy=54.17% | Val Loss: 0.6940
# Epoch 457 | Train Accuracy=58.93% | Train Loss=0.6662 | Val Accuracy=54.17% | Val Loss: 0.6940
# Epoch 458 | Train Accuracy=58.93% | Train Loss=0.6661 | Val Accuracy=54.17% | Val Loss: 0.6940
# Epoch 459 | Train Accuracy=58.93% | Train Loss=0.6661 | Val Accuracy=54.17% | Val Loss: 0.6940
# Epoch 460 | Train Accuracy=58.93% | Train Loss=0.6660 | Val Accuracy=54.17% | Val Loss: 0.6940
# Epoch 461 | Train Accuracy=58.93% | Train Loss=0.6660 | Val Accuracy=54.17% | Val Loss: 0.6940
# Epoch 462 | Train Accuracy=58.93% | Train Loss=0.6660 | Val Accuracy=54.17% | Val Loss: 0.6940
# Epoch 463 | Train Accuracy=58.93% | Train Loss=0.6659 | Val Accuracy=54.17% | Val Loss: 0.6940
# Epoch 464 | Train Accuracy=58.93% | Train Loss=0.6659 | Val Accuracy=54.17% | Val Loss: 0.6940
# Epoch 465 | Train Accuracy=58.93% | Train Loss=0.6659 | Val Accuracy=54.17% | Val Loss: 0.6940
# Epoch 466 | Train Accuracy=58.93% | Train Loss=0.6658 | Val Accuracy=54.17% | Val Loss: 0.6940
# Epoch 467 | Train Accuracy=58.93% | Train Loss=0.6658 | Val Accuracy=54.17% | Val Loss: 0.6940
# Epoch 468 | Train Accuracy=58.93% | Train Loss=0.6657 | Val Accuracy=54.17% | Val Loss: 0.6940
# Epoch 469 | Train Accuracy=58.93% | Train Loss=0.6657 | Val Accuracy=54.17% | Val Loss: 0.6940
# Epoch 470 | Train Accuracy=58.93% | Train Loss=0.6657 | Val Accuracy=54.17% | Val Loss: 0.6941
# Epoch 471 | Train Accuracy=58.93% | Train Loss=0.6656 | Val Accuracy=54.17% | Val Loss: 0.6941
# Epoch 472 | Train Accuracy=58.93% | Train Loss=0.6656 | Val Accuracy=54.17% | Val Loss: 0.6941
# Epoch 473 | Train Accuracy=58.93% | Train Loss=0.6656 | Val Accuracy=54.17% | Val Loss: 0.6941
# Epoch 474 | Train Accuracy=58.93% | Train Loss=0.6655 | Val Accuracy=54.17% | Val Loss: 0.6941
# Epoch 475 | Train Accuracy=58.93% | Train Loss=0.6655 | Val Accuracy=54.17% | Val Loss: 0.6941
# Epoch 476 | Train Accuracy=58.93% | Train Loss=0.6654 | Val Accuracy=54.17% | Val Loss: 0.6941
# Epoch 477 | Train Accuracy=58.93% | Train Loss=0.6654 | Val Accuracy=54.17% | Val Loss: 0.6941
# Epoch 478 | Train Accuracy=58.93% | Train Loss=0.6654 | Val Accuracy=54.17% | Val Loss: 0.6941
# Epoch 479 | Train Accuracy=58.93% | Train Loss=0.6653 | Val Accuracy=54.17% | Val Loss: 0.6941
# Epoch 480 | Train Accuracy=58.93% | Train Loss=0.6653 | Val Accuracy=54.17% | Val Loss: 0.6941
# Epoch 481 | Train Accuracy=58.93% | Train Loss=0.6653 | Val Accuracy=54.17% | Val Loss: 0.6941
# Epoch 482 | Train Accuracy=58.93% | Train Loss=0.6652 | Val Accuracy=54.17% | Val Loss: 0.6941
# Epoch 483 | Train Accuracy=58.93% | Train Loss=0.6652 | Val Accuracy=54.17% | Val Loss: 0.6941
# Epoch 484 | Train Accuracy=58.93% | Train Loss=0.6651 | Val Accuracy=54.17% | Val Loss: 0.6942
# Epoch 485 | Train Accuracy=58.93% | Train Loss=0.6651 | Val Accuracy=54.17% | Val Loss: 0.6942
# Epoch 486 | Train Accuracy=58.93% | Train Loss=0.6651 | Val Accuracy=54.17% | Val Loss: 0.6942
# Epoch 487 | Train Accuracy=58.93% | Train Loss=0.6650 | Val Accuracy=54.17% | Val Loss: 0.6942
# Epoch 488 | Train Accuracy=58.93% | Train Loss=0.6650 | Val Accuracy=54.17% | Val Loss: 0.6942
# Epoch 489 | Train Accuracy=58.93% | Train Loss=0.6650 | Val Accuracy=54.17% | Val Loss: 0.6942
# Epoch 490 | Train Accuracy=58.93% | Train Loss=0.6649 | Val Accuracy=54.17% | Val Loss: 0.6942
# Epoch 491 | Train Accuracy=58.93% | Train Loss=0.6649 | Val Accuracy=54.17% | Val Loss: 0.6942
# Epoch 492 | Train Accuracy=58.93% | Train Loss=0.6649 | Val Accuracy=54.17% | Val Loss: 0.6942
# Epoch 493 | Train Accuracy=58.93% | Train Loss=0.6648 | Val Accuracy=54.17% | Val Loss: 0.6942
# Epoch 494 | Train Accuracy=58.93% | Train Loss=0.6648 | Val Accuracy=54.17% | Val Loss: 0.6942
# Epoch 495 | Train Accuracy=58.93% | Train Loss=0.6648 | Val Accuracy=54.17% | Val Loss: 0.6942
# Epoch 496 | Train Accuracy=58.93% | Train Loss=0.6647 | Val Accuracy=54.17% | Val Loss: 0.6942
# Epoch 497 | Train Accuracy=58.93% | Train Loss=0.6647 | Val Accuracy=54.17% | Val Loss: 0.6942
# Epoch 498 | Train Accuracy=58.93% | Train Loss=0.6646 | Val Accuracy=54.17% | Val Loss: 0.6943
# Epoch 499 | Train Accuracy=58.93% | Train Loss=0.6646 | Val Accuracy=54.17% | Val Loss: 0.6943
# Train Accuracy: 0.5820
# Loss saved to loss.json
# /Users/cristianleo/Documents/GitHub/capstone-columbia/models/dl.py:240: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X = torch.tensor(X, dtype=torch.float32).to(self.device)

# %%
model.performance.keys()
import matplotlib.pyplot as plt
plt.plot(model.performance['train_loss'])
plt.plot(model.performance['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.show()

# %%
plt.plot(model.performance['train_acc'])
plt.plot(model.performance['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='lower right')
plt.show()

# %%
# preds

# %%
import numpy as np
thresholds = np.linspace(0, 1, 21)
accs = {}
for threshold in thresholds:
    new_preds = np.where(preds.squeeze().detach().numpy() >= threshold, 1, 0)
    accs[threshold.round(2)] = (new_preds == model.y_train.squeeze().detach().numpy()).mean().round(4)
accs
# Out:
# {0.0: 0.4098,
#  0.05: 0.4098,
#  0.1: 0.4098,
#  0.15: 0.4098,
#  0.2: 0.4098,
#  0.25: 0.4098,
#  0.3: 0.4098,
#  0.35: 0.4098,
#  0.4: 0.4098,
#  0.45: 0.4262,
#  0.5: 0.582,
#  0.55: 0.5902,
#  0.6: 0.5902,
#  0.65: 0.5902,
#  0.7: 0.5902,
#  0.75: 0.5902,
#  0.8: 0.5902,
#  0.85: 0.5902,
#  0.9: 0.5902,
#  0.95: 0.5902,
#  1.0: 0.5902}

# %%
model.plot_grad_flow()

# %% [markdown]
# # **ML**

# %%
from ml import ML
model = ML(model_name='Random Forest', binary=True)
# model.train()
preds  = model.predict('train')
# model.predict('val')
# model.predict('test')
# Out:
# Model is not trained yet. Training now...
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# +-----------------------+---------------------+---------------------------+--------------------+
# |        Feature        |   Initial ROC_AUC   |       Transformation      | Tranformed ROC_AUC |
# +-----------------------+---------------------+---------------------------+--------------------+
# |         IYT_x         | 0.49291390091390086 |         sqrt_IYT_x        | 0.6062202982202982 |
# |          XME          | 0.47155940355940357 |          pow_XME          | 0.5704425204425203 |
# |          PICK         |  0.5180413660413661 |          pow_PICK         | 0.6363386243386243 |
# |          REMX         |  0.4314930254930255 |        log_sqrtREMX       | 0.6251361231361232 |
# |          DBB          |  0.6084011544011545 |          pow_DBB          | 0.6587195767195768 |
# |          GLD          |  0.5198239538239539 |            GLD            | 0.5198239538239539 |
# |          IAU          |  0.4296820586820586 |          log_IAU          | 0.5592462722462723 |
# |          GDX          |  0.518979316979317  |          pow_GDX          | 0.557024531024531  |
# |          GDXJ         | 0.42131120731120736 |          pow_GDXJ         | 0.5526782106782107 |
# |          IYM          |  0.5927051467051466 |            IYM            | 0.5927051467051466 |
# |          XLB          | 0.48544781144781146 |          y_J_XLB          | 0.581041366041366  |
# |          VAW          |  0.5612794612794613 |          log_VAW          | 0.627048581048581  |
# |          FXZ          |  0.4340548340548341 |        log_sqrtFXZ        | 0.5393246753246752 |
# |          DJP          | 0.41707647907647916 |         bx_cx_DJP         | 0.6411774891774893 |
# |     price_ferrous     | 0.46938143338143334 |   log_sqrtprice_ferrous   | 0.5671053391053391 |
# |   inventory_ferrous   | 0.48176815776815773 |  bx_cx_inventory_ferrous  | 0.5865127465127464 |
# |     orders_ferrous    |  0.5286050986050986 |    pow2_orders_ferrous    | 0.580922558922559  |
# |   price_non_ferrous   |  0.5164569504569505 |   sqrt_price_non_ferrous  | 0.552075036075036  |
# | inventory_non_ferrous |   0.46098556998557  | y_J_inventory_non_ferrous | 0.6018451178451178 |
# |   orders_non_ferrous  |  0.4345930735930736 |   y_J_orders_non_ferrous  | 0.5964718614718615 |
# |     NUE_sentiment     | 0.47353968253968254 |     log_NUE_sentiment     | 0.4937195767195767 |
# |     STLD_sentiment    |  0.6615488215488216 |       STLD_sentiment      | 0.6615488215488216 |
# |     LKQ_sentiment     |   0.51981240981241  |     pow2_LKQ_sentiment    | 0.5938191438191438 |
# |     NSC_sentiment     |  0.5717479557479558 |       NSC_sentiment       | 0.5717479557479558 |
# |     CLF_sentiment     |  0.5755608465608466 |       CLF_sentiment       | 0.5755608465608466 |
# |      AA_sentiment     |  0.5617383357383356 |      log_AA_sentiment     | 0.6028648388648389 |
# |     VMC_sentiment     | 0.48851948051948063 |    bx_cx_VMC_sentiment    | 0.4995055315055315 |
# |     MLM_sentiment     |  0.493090428090428  |   log_sqrtMLM_sentiment   | 0.5210173160173162 |
# +-----------------------+---------------------+---------------------------+--------------------+
# overall best CV ROC AUC score:  0.6615488215488216
# Training CatBoost...
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 15 fits failed out of a total of 50.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/catboost/core.py", line 5100, in fit
#     self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/catboost/core.py", line 2303, in _fit
#     train_params = self._prepare_train_params(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/catboost/core.py", line 2230, in _prepare_train_params
#     _check_train_params(params)
#   File "_catboost.pyx", line 6105, in _catboost._check_train_params
#   File "_catboost.pyx", line 6124, in _catboost._check_train_params
# _catboost.CatBoostError: /Users/zomb-ml-platform-msk/go-agent-21.2.0/pipelines/BuildMaster/catboost.git/tools/enum_parser/enum_serialization_runtime/enum_runtime.cpp:70: Key 'Round' not found in enum EOverfittingDetectorType. Valid options are: 'None', 'Wilcoxon', 'IncToDec', 'Iter'.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_search.py:952: UserWarning: One or more of the test scores are non-finite: [       nan 0.54833333 0.524      0.524      0.53166667 0.491
#  0.532             nan        nan 0.52266667]
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_search.py:952: UserWarning: One or more of the train scores are non-finite: [       nan 1.         1.         1.         0.99591837 1.
#  1.                nan        nan 1.        ]
#   warnings.warn(
# {'verbose': False, 'random_seed': 42, 'od_wait': 200, 'od_type': 'IncToDec', 'loss_function': 'CrossEntropy', 'learning_rate': 0.01, 'iterations': 1000, 'eval_metric': 'Accuracy', 'depth': 8, 'bagging_temperature': 0.75}
# Train Accuracy: 1.0000
# Val Accuracy: 0.5833
# Test Accuracy: 0.5714
# Loss saved to loss.json
# Loss saved to loss.json
# Loss saved to loss.json
# Model is not trained yet. Training now...
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# ...
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_search.py:909: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/cristianleo/Documents/GitHub/capstone-columbia/models/mlmodels/myrf.py:40: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.model.fit(X_train, y_train)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# {'bootstrap': True, 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 200, 'random_state': 42}
# Train Loss: 0.7869
# Val Loss: 0.4583
# Test Loss: 0.2857
# Loss saved to loss.json

# %% [markdown]
# # **Manual Model**

# %% [markdown]
# ## **Get Data**

# %%
from ingest import Ingest
import numpy as np
ingest = Ingest()
df = ingest.get_data()
df['Target'].isna().sum()
df['Target'] = np.where(df['Target']>0, 1, 0)
df.head()
# X_train, X_val, X_test, y_train, y_val, y_test = ingest.split(val=False)
# Out:
#          date     NUE    STLD     LKQ     NSC     CLF      AA     VMC     MLM  \
# 0  2010-01-31  27.451  10.893   9.012  34.033  33.320  27.704  39.069  67.288
# 1  2010-02-28  27.855  11.718   9.205  37.193  47.040  28.944  38.379  67.322
# 2  2010-03-31  30.533  12.536   9.757  40.701  59.297  31.058  41.998  71.350
# 3  2010-04-30  30.735  11.329  10.128  43.206  52.260  29.292  50.924  81.880
# 4  2010-05-31  29.195  10.572   8.854  41.116  46.685  25.388  44.879  79.617
#
#    price_ferrous  ...  ConsumerSentiment  RetailSales  HousingStarts      HPI  \
# 0          117.6  ...               74.4     346046.0          614.0  145.003
# 1          118.3  ...               73.6     346702.0          604.0  143.053
# 2          147.6  ...               73.6     354147.0          636.0  143.597
# 3          148.0  ...               72.2     357304.0          687.0  145.404
# 4          143.3  ...               73.6     354015.0          583.0  147.040
#
#    NUE_sentiment  STLD_sentiment  NSC_sentiment  CLF_sentiment  AA_sentiment  \
# 0         1.0000             1.0            0.0         0.0000        1.0588
# 1         0.5000             1.0            2.0         0.5714        0.9167
# 2         0.7500             0.5            2.0         0.7500        1.3846
# 3         0.2500             0.5            0.0         1.2500        1.5000
# 4         1.3333             NaN            2.0         1.1111        1.1579
#
#    Target
# 0       0
# 1       1
# 2       1
# 3       1
# 4       0
#
# [5 rows x 32 columns]

# %%
from ingest import Ingest
ingest = Ingest()
X_train, X_val, X_test, y_train, y_val, y_test = ingest.split(val=False,
                                                               drop_unimportant=False, 
                                                               transform=True,
                                                               scale=True
                                                               ) # drop_unimportant=False give the best result for CatBoost
X_train.head()
# Out:
# /Users/cristianleo/Documents/GitHub/capstone-columbia/models/ingest.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[cols] = self.imputer.fit_transform(train[cols])
# /Users/cristianleo/Documents/GitHub/capstone-columbia/models/ingest.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[cols] = self.imputer.transform(test[cols])
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# +-----------------------+---------------------+-------------------------------+--------------------+
# |        Feature        |   Initial ROC_AUC   |         Transformation        | Tranformed ROC_AUC |
# +-----------------------+---------------------+-------------------------------+--------------------+
# |          NUE          |  0.5583087945237267 |            pow_NUE            | 0.5694901118238221 |
# |          STLD         |  0.4225999535909038 |            log_STLD           | 0.5377968745683679 |
# |          LKQ          | 0.47573655172128027 |            y_J_LKQ            | 0.5422414122453715 |
# |          NSC          |  0.4815469491544152 |            y_J_NSC            | 0.6049541668738502 |
# |          CLF          |  0.5272229694639197 |              CLF              | 0.5272229694639197 |
# |           AA          | 0.46194910192873995 |             log_AA            | 0.5599908563030735 |
# |          VMC          | 0.44101967207001147 |           bx_cx_VMC           | 0.5612833095762959 |
# |          MLM          | 0.47936127133299083 |           bx_cx_MLM           | 0.5574123986872855 |
# |     price_ferrous     |  0.4626438792479517 |       pow2_price_ferrous      | 0.5365873015873015 |
# |   inventory_ferrous   |  0.5398856692578412 |     log_inventory_ferrous     | 0.5611492176752357 |
# |     orders_ferrous    |  0.5540425720584092 |         orders_ferrous        | 0.5540425720584092 |
# |   price_non_ferrous   | 0.39697024016707266 |    bx_cx_price_non_ferrous    | 0.6494701213818861 |
# | inventory_non_ferrous |  0.4614044366267217 | log_sqrtinventory_non_ferrous | 0.5531909527124459 |
# |   orders_non_ferrous  |  0.4001853242283106 |     y_J_orders_non_ferrous    | 0.5717605249200273 |
# |          NFP          |  0.5143589743589743 |            sqrt_NFP           | 0.5817888261813601 |
# |      InterestRate     |  0.5159426578323637 |        y_J_InterestRate       | 0.6035341914872457 |
# |    UnemploymentRate   |  0.5178262462776038 |    log_sqrtUnemploymentRate   | 0.605360205028757  |
# |          PPI          |  0.6124719190437515 |              PPI              | 0.6124719190437515 |
# |          CPI          |  0.5924785281962883 |              CPI              | 0.5924785281962883 |
# |          PCE          | 0.48269370825253183 |          log_sqrtPCE          | 0.5649670771661721 |
# |          IPI          | 0.46556488019270825 |            sqrt_IPI           | 0.5765166465008094 |
# |   ConsumerSentiment   |  0.4543613997867392 |     log_ConsumerSentiment     | 0.6063578541870397 |
# |      RetailSales      |         0.5         |       bx_cx_RetailSales       | 0.5756015419974696 |
# |     HousingStarts     |  0.5496185752407472 |         HousingStarts         | 0.5496185752407472 |
# |          HPI          |  0.5671509455853346 |              HPI              | 0.5671509455853346 |
# |     NUE_sentiment     |  0.5287737528936625 |       sqrt_NUE_sentiment      | 0.6046708075735225 |
# |     STLD_sentiment    | 0.45326430256520756 |      sqrt_STLD_sentiment      | 0.5543321620561439 |
# |     NSC_sentiment     |  0.5495270567793191 |       pow_NSC_sentiment       | 0.6759555895336439 |
# |     CLF_sentiment     |  0.498060637075343  |       pow_CLF_sentiment       | 0.5337962350620722 |
# |      AA_sentiment     |  0.5137276400698345 |        log_AA_sentiment       | 0.6424039103807202 |
# +-----------------------+---------------------+-------------------------------+--------------------+
# overall best CV ROC AUC score:  0.6759555895336439
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
#       NUE    STLD     LKQ     NSC     CLF      AA     VMC     MLM  \
# 0  27.451  10.893   9.012  34.033  33.320  27.704  39.069  67.288
# 1  27.855  11.718   9.205  37.193  47.040  28.944  38.379  67.322
# 2  30.533  12.536   9.757  40.701  59.297  31.058  41.998  71.350
# 3  30.735  11.329  10.128  43.206  52.260  29.292  50.924  81.880
# 4  29.195  10.572   8.854  41.116  46.685  25.388  44.879  79.617
#
#    price_ferrous  inventory_ferrous  ...  log_sqrtCLF_sentiment  \
# 0          117.6             1667.0  ...               0.000000
# 1          118.3             1700.0  ...               0.562987
# 2          147.6             1689.0  ...               0.623811
# 3          148.0             1724.0  ...               0.750488
# 4          143.3             1742.0  ...               0.719832
#
#    CLF_sentiment_pca_comb  log_AA_sentiment  sqrt_AA_sentiment  \
# 0                0.617532          0.722123           1.028980
# 1                2.733138          0.650605           0.957445
# 2                3.438377          0.869031           1.176690
# 3                5.669259          0.916291           1.224745
# 4                5.009959          0.769136           1.076058
#
#    bx_cx_AA_sentiment  y_J_AA_sentiment  pow_AA_sentiment  pow2_AA_sentiment  \
# 0            0.461846          0.420398          1.197853           4.238657
# 1            0.160347          0.099459          1.176626           3.673739
# 2            1.105411          1.139523          1.242664           5.686317
# 3            1.320557          1.389224          1.257433           6.250000
# 4            0.663964          0.641488          1.212015           4.656532
#
#    log_sqrtAA_sentiment  AA_sentiment_pca_comb
# 0              0.707533               4.793311
# 1              0.671640               4.166680
# 2              0.777806               6.352538
# 3              0.799642               6.946616
# 4              0.730471               5.249347
#
# [5 rows x 270 columns]

# %%
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
import pandas as pd

# model = LogisticRegression()
model = SVC(probability=True)
pd.set_option('display.max_rows', 500)
accs = pd.DataFrame(columns=['col', 'acc'])
for col in X_train.columns:
    model.fit(X_train[col].values.reshape(-1, 1), y_train.values.reshape(-1, ))
    y_pred = model.predict_proba(X_test[col].values.reshape(-1, 1))[:,1]
    # accs = accs.append({'col': col, 'acc': accuracy_score(y_test, y_pred.round())}, ignore_index=True)
    accs = pd.concat([accs, pd.DataFrame({'col': col, 'acc': accuracy_score(y_test, y_pred.round())}, index=[0])])
# accs.sort_values(by='acc', ascending=False)

cols_to_drop = accs[accs['acc'] < 0.55]['col'].values

X_train.drop(cols_to_drop, axis=1, inplace=True)
X_test.drop(cols_to_drop, axis=1, inplace=True)
X_test=X_test[X_train.columns]
print(X_train.shape[1])
# Out:
# 260

# %% [markdown]
# ## **Transform Data**

# %% [markdown]
# ## **Logistic Regression**

# %%
from sklearn.metrics import accuracy_score

# # train columns not in unimportant features
# X_train = train.drop(['Target'], axis=1)
# # X_train.drop(unimportant_features, axis=1, inplace=True)
# y_train = train['Target']
# X_test = test.drop(['Target'], axis=1)
# # X_test.drop(unimportant_features, axis=1, inplace=True)
# # X_train = X_train.loc[:, X_test.columns]
# y_test = test['Target']


# X_test = X_test[X_train.columns]

# grid search
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()

model.fit(X_train, y_train)
y_pred = model.predict_proba(X_test)[:,1]
print(f"ROC: {roc_auc_score(y_test, y_pred):.2%}")
print(f"Test Accuracy: {accuracy_score(y_test, y_pred.round()):.2%}")
print(f"Train Accuracy: {accuracy_score(y_train, model.predict(X_train).round()):.2%}")
# Out:
# ROC: 56.39%
# Test Accuracy: 57.58%
# Train Accuracy: 62.02%
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# ## **CatBoost**

# %%
# from mlxtend.feature_selection import SequentialFeatureSelector
# # from sklearn.linear_model import LogisticRegression
# import catboost as cb
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.metrics import accuracy_score

# # define the model
# # model = cb.CatBoostClassifier()
# model = RandomForestClassifier()

# # define the feature selector
# sfs = SequentialFeatureSelector(model,
#                                 k_features='best', 
#                                 forward=False, 
#                                 floating=False, 
#                                 scoring='accuracy', 
#                                 cv=None,
#                                 n_jobs=-1,
#                                 verbose=2)

# # fit the feature selector to the data
# sfs.fit(X_train, y_train.values.reshape(-1,))

# # print the selected features and their indices
# print('Selected features:', sfs.k_feature_idx_)

# # transform the data to include only the selected features
# X_train_sfs = sfs.transform(X_train)
# X_test_sfs = sfs.transform(X_test)

# # fit the model on the selected features
# model.fit(X_train_sfs, y_train)

# # predict on the test set
# y_pred = model.predict(X_test_sfs)

# # calculate the accuracy score
# accuracy = accuracy_score(y_test, y_pred)

# # print the accuracy score
# print('Accuracy:', accuracy)

# %%
from catboost import CatBoostClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
model = CatBoostClassifier(
    eval_metric='Accuracy',
    random_seed=42,
    iterations=1000,
    # learning_rate=0.0001,
    )
model.fit(X_train, y_train, 
          eval_set=(X_test, y_test), 
          verbose=True,
          early_stopping_rounds=100,
          use_best_model=True, 
          
        #   plot=True, 
        #   early_stopping_rounds=100
          )
y_pred = model.predict_proba(X_test)[:,1]
print(f"ROC: {roc_auc_score(y_test, y_pred):.2%}")
print(f"Accuracy: {accuracy_score(y_test, y_pred.round()):.2%}")  
print(f"Train Accuracy: {accuracy_score(y_train, model.predict(X_train).round()):.2%}")
# Out:
# Learning rate set to 0.019108
# 0:	learn: 0.6666667	test: 0.3636364	best: 0.3636364 (0)	total: 5.27ms	remaining: 5.26s
# 1:	learn: 0.8062016	test: 0.4242424	best: 0.4242424 (1)	total: 10.1ms	remaining: 5.03s
# 2:	learn: 0.8372093	test: 0.4848485	best: 0.4848485 (2)	total: 13.4ms	remaining: 4.46s
# 3:	learn: 0.8217054	test: 0.5151515	best: 0.5151515 (3)	total: 18ms	remaining: 4.49s
# 4:	learn: 0.8449612	test: 0.5454545	best: 0.5454545 (4)	total: 21.6ms	remaining: 4.29s
# 5:	learn: 0.8449612	test: 0.5151515	best: 0.5454545 (4)	total: 27.5ms	remaining: 4.56s
# 6:	learn: 0.8604651	test: 0.4848485	best: 0.5454545 (4)	total: 32.1ms	remaining: 4.55s
# 7:	learn: 0.8604651	test: 0.5454545	best: 0.5454545 (4)	total: 37.1ms	remaining: 4.6s
# 8:	learn: 0.8759690	test: 0.4545455	best: 0.5454545 (4)	total: 40.5ms	remaining: 4.45s
# 9:	learn: 0.8682171	test: 0.4242424	best: 0.5454545 (4)	total: 46ms	remaining: 4.55s
# 10:	learn: 0.8682171	test: 0.4848485	best: 0.5454545 (4)	total: 50.5ms	remaining: 4.54s
# 11:	learn: 0.8759690	test: 0.4848485	best: 0.5454545 (4)	total: 54.4ms	remaining: 4.48s
# 12:	learn: 0.8992248	test: 0.5151515	best: 0.5454545 (4)	total: 58.9ms	remaining: 4.47s
# 13:	learn: 0.8759690	test: 0.5151515	best: 0.5454545 (4)	total: 62.1ms	remaining: 4.38s
# 14:	learn: 0.8682171	test: 0.5757576	best: 0.5757576 (14)	total: 66.5ms	remaining: 4.37s
# 15:	learn: 0.8759690	test: 0.6060606	best: 0.6060606 (15)	total: 69.8ms	remaining: 4.29s
# 16:	learn: 0.8759690	test: 0.6363636	best: 0.6363636 (16)	total: 75ms	remaining: 4.34s
# 17:	learn: 0.8992248	test: 0.5454545	best: 0.6363636 (16)	total: 78.5ms	remaining: 4.28s
# 18:	learn: 0.8914729	test: 0.5151515	best: 0.6363636 (16)	total: 81.9ms	remaining: 4.23s
# 19:	learn: 0.8759690	test: 0.5151515	best: 0.6363636 (16)	total: 86.9ms	remaining: 4.26s
# 20:	learn: 0.8914729	test: 0.5151515	best: 0.6363636 (16)	total: 90.8ms	remaining: 4.23s
# 21:	learn: 0.8914729	test: 0.5151515	best: 0.6363636 (16)	total: 94ms	remaining: 4.18s
# 22:	learn: 0.9069767	test: 0.5454545	best: 0.6363636 (16)	total: 97.3ms	remaining: 4.13s
# 23:	learn: 0.8992248	test: 0.5757576	best: 0.6363636 (16)	total: 101ms	remaining: 4.12s
# 24:	learn: 0.8992248	test: 0.5757576	best: 0.6363636 (16)	total: 105ms	remaining: 4.08s
# 25:	learn: 0.9069767	test: 0.5757576	best: 0.6363636 (16)	total: 108ms	remaining: 4.06s
# 26:	learn: 0.9224806	test: 0.5454545	best: 0.6363636 (16)	total: 112ms	remaining: 4.03s
# 27:	learn: 0.9147287	test: 0.5454545	best: 0.6363636 (16)	total: 116ms	remaining: 4.02s
# 28:	learn: 0.9147287	test: 0.5454545	best: 0.6363636 (16)	total: 119ms	remaining: 3.98s
# 29:	learn: 0.8992248	test: 0.5151515	best: 0.6363636 (16)	total: 123ms	remaining: 3.97s
# 30:	learn: 0.9147287	test: 0.5151515	best: 0.6363636 (16)	total: 126ms	remaining: 3.95s
# 31:	learn: 0.9224806	test: 0.5757576	best: 0.6363636 (16)	total: 130ms	remaining: 3.94s
# 32:	learn: 0.9069767	test: 0.5151515	best: 0.6363636 (16)	total: 134ms	remaining: 3.92s
# 33:	learn: 0.9069767	test: 0.5454545	best: 0.6363636 (16)	total: 139ms	remaining: 3.94s
# 34:	learn: 0.9069767	test: 0.6060606	best: 0.6363636 (16)	total: 143ms	remaining: 3.94s
# 35:	learn: 0.9069767	test: 0.5757576	best: 0.6363636 (16)	total: 147ms	remaining: 3.93s
# 36:	learn: 0.9147287	test: 0.5454545	best: 0.6363636 (16)	total: 150ms	remaining: 3.9s
# 37:	learn: 0.9147287	test: 0.5151515	best: 0.6363636 (16)	total: 154ms	remaining: 3.89s
# 38:	learn: 0.9147287	test: 0.4848485	best: 0.6363636 (16)	total: 157ms	remaining: 3.87s
# 39:	learn: 0.9224806	test: 0.4848485	best: 0.6363636 (16)	total: 160ms	remaining: 3.85s
# 40:	learn: 0.9147287	test: 0.5454545	best: 0.6363636 (16)	total: 164ms	remaining: 3.84s
# 41:	learn: 0.9147287	test: 0.5454545	best: 0.6363636 (16)	total: 167ms	remaining: 3.81s
# 42:	learn: 0.9147287	test: 0.5757576	best: 0.6363636 (16)	total: 170ms	remaining: 3.79s
# 43:	learn: 0.9069767	test: 0.5454545	best: 0.6363636 (16)	total: 174ms	remaining: 3.78s
# 44:	learn: 0.9069767	test: 0.5454545	best: 0.6363636 (16)	total: 178ms	remaining: 3.77s
# 45:	learn: 0.9069767	test: 0.5757576	best: 0.6363636 (16)	total: 182ms	remaining: 3.77s
# 46:	learn: 0.9069767	test: 0.6060606	best: 0.6363636 (16)	total: 185ms	remaining: 3.75s
# 47:	learn: 0.9069767	test: 0.5454545	best: 0.6363636 (16)	total: 188ms	remaining: 3.74s
# 48:	learn: 0.9069767	test: 0.5757576	best: 0.6363636 (16)	total: 192ms	remaining: 3.72s
# 49:	learn: 0.9069767	test: 0.5454545	best: 0.6363636 (16)	total: 196ms	remaining: 3.72s
# 50:	learn: 0.9069767	test: 0.5757576	best: 0.6363636 (16)	total: 200ms	remaining: 3.73s
# 51:	learn: 0.9069767	test: 0.5757576	best: 0.6363636 (16)	total: 204ms	remaining: 3.72s
# 52:	learn: 0.9069767	test: 0.5151515	best: 0.6363636 (16)	total: 207ms	remaining: 3.71s
# 53:	learn: 0.9147287	test: 0.5454545	best: 0.6363636 (16)	total: 211ms	remaining: 3.69s
# 54:	learn: 0.9147287	test: 0.5454545	best: 0.6363636 (16)	total: 215ms	remaining: 3.69s
# 55:	learn: 0.9147287	test: 0.5454545	best: 0.6363636 (16)	total: 219ms	remaining: 3.69s
# 56:	learn: 0.9147287	test: 0.5151515	best: 0.6363636 (16)	total: 223ms	remaining: 3.69s
# 57:	learn: 0.9224806	test: 0.5757576	best: 0.6363636 (16)	total: 226ms	remaining: 3.67s
# 58:	learn: 0.9147287	test: 0.6060606	best: 0.6363636 (16)	total: 230ms	remaining: 3.66s
# 59:	learn: 0.9147287	test: 0.6060606	best: 0.6363636 (16)	total: 234ms	remaining: 3.67s
# 60:	learn: 0.9302326	test: 0.5757576	best: 0.6363636 (16)	total: 238ms	remaining: 3.67s
# 61:	learn: 0.9302326	test: 0.5757576	best: 0.6363636 (16)	total: 242ms	remaining: 3.67s
# 62:	learn: 0.9379845	test: 0.6060606	best: 0.6363636 (16)	total: 246ms	remaining: 3.66s
# 63:	learn: 0.9379845	test: 0.6060606	best: 0.6363636 (16)	total: 250ms	remaining: 3.65s
# 64:	learn: 0.9379845	test: 0.6060606	best: 0.6363636 (16)	total: 254ms	remaining: 3.65s
# 65:	learn: 0.9379845	test: 0.6060606	best: 0.6363636 (16)	total: 257ms	remaining: 3.63s
# 66:	learn: 0.9457364	test: 0.5757576	best: 0.6363636 (16)	total: 260ms	remaining: 3.62s
# 67:	learn: 0.9534884	test: 0.6060606	best: 0.6363636 (16)	total: 264ms	remaining: 3.61s
# 68:	learn: 0.9457364	test: 0.6060606	best: 0.6363636 (16)	total: 267ms	remaining: 3.6s
# 69:	learn: 0.9379845	test: 0.6060606	best: 0.6363636 (16)	total: 274ms	remaining: 3.63s
# 70:	learn: 0.9457364	test: 0.6060606	best: 0.6363636 (16)	total: 278ms	remaining: 3.64s
# 71:	learn: 0.9534884	test: 0.6060606	best: 0.6363636 (16)	total: 281ms	remaining: 3.63s
# 72:	learn: 0.9534884	test: 0.6060606	best: 0.6363636 (16)	total: 285ms	remaining: 3.62s
# 73:	learn: 0.9457364	test: 0.6363636	best: 0.6363636 (16)	total: 288ms	remaining: 3.61s
# 74:	learn: 0.9457364	test: 0.6363636	best: 0.6363636 (16)	total: 292ms	remaining: 3.6s
# 75:	learn: 0.9534884	test: 0.6363636	best: 0.6363636 (16)	total: 296ms	remaining: 3.6s
# 76:	learn: 0.9612403	test: 0.6060606	best: 0.6363636 (16)	total: 304ms	remaining: 3.64s
# 77:	learn: 0.9689922	test: 0.5757576	best: 0.6363636 (16)	total: 307ms	remaining: 3.63s
# 78:	learn: 0.9689922	test: 0.5757576	best: 0.6363636 (16)	total: 311ms	remaining: 3.62s
# 79:	learn: 0.9534884	test: 0.5757576	best: 0.6363636 (16)	total: 314ms	remaining: 3.61s
# 80:	learn: 0.9534884	test: 0.5757576	best: 0.6363636 (16)	total: 318ms	remaining: 3.6s
# 81:	learn: 0.9612403	test: 0.5454545	best: 0.6363636 (16)	total: 321ms	remaining: 3.6s
# 82:	learn: 0.9612403	test: 0.5454545	best: 0.6363636 (16)	total: 325ms	remaining: 3.59s
# 83:	learn: 0.9767442	test: 0.5757576	best: 0.6363636 (16)	total: 328ms	remaining: 3.58s
# 84:	learn: 0.9767442	test: 0.5757576	best: 0.6363636 (16)	total: 332ms	remaining: 3.58s
# 85:	learn: 0.9689922	test: 0.5454545	best: 0.6363636 (16)	total: 336ms	remaining: 3.57s
# 86:	learn: 0.9689922	test: 0.5454545	best: 0.6363636 (16)	total: 339ms	remaining: 3.56s
# 87:	learn: 0.9767442	test: 0.5151515	best: 0.6363636 (16)	total: 343ms	remaining: 3.56s
# 88:	learn: 0.9767442	test: 0.5151515	best: 0.6363636 (16)	total: 348ms	remaining: 3.56s
# 89:	learn: 0.9844961	test: 0.5151515	best: 0.6363636 (16)	total: 352ms	remaining: 3.55s
# 90:	learn: 0.9844961	test: 0.5151515	best: 0.6363636 (16)	total: 355ms	remaining: 3.55s
# 91:	learn: 0.9922481	test: 0.5151515	best: 0.6363636 (16)	total: 359ms	remaining: 3.54s
# 92:	learn: 0.9922481	test: 0.5151515	best: 0.6363636 (16)	total: 363ms	remaining: 3.54s
# 93:	learn: 0.9844961	test: 0.4848485	best: 0.6363636 (16)	total: 367ms	remaining: 3.53s
# 94:	learn: 0.9844961	test: 0.4848485	best: 0.6363636 (16)	total: 370ms	remaining: 3.52s
# 95:	learn: 0.9844961	test: 0.4848485	best: 0.6363636 (16)	total: 374ms	remaining: 3.52s
# 96:	learn: 0.9844961	test: 0.4848485	best: 0.6363636 (16)	total: 377ms	remaining: 3.51s
# 97:	learn: 0.9922481	test: 0.4848485	best: 0.6363636 (16)	total: 382ms	remaining: 3.52s
# 98:	learn: 0.9922481	test: 0.4848485	best: 0.6363636 (16)	total: 387ms	remaining: 3.52s
# 99:	learn: 0.9922481	test: 0.4848485	best: 0.6363636 (16)	total: 391ms	remaining: 3.52s
# 100:	learn: 1.0000000	test: 0.4848485	best: 0.6363636 (16)	total: 397ms	remaining: 3.53s
# 101:	learn: 1.0000000	test: 0.4848485	best: 0.6363636 (16)	total: 403ms	remaining: 3.55s
# 102:	learn: 1.0000000	test: 0.4545455	best: 0.6363636 (16)	total: 408ms	remaining: 3.56s
# 103:	learn: 1.0000000	test: 0.4545455	best: 0.6363636 (16)	total: 413ms	remaining: 3.56s
# 104:	learn: 1.0000000	test: 0.4545455	best: 0.6363636 (16)	total: 418ms	remaining: 3.56s
# 105:	learn: 1.0000000	test: 0.4545455	best: 0.6363636 (16)	total: 423ms	remaining: 3.57s
# 106:	learn: 1.0000000	test: 0.4848485	best: 0.6363636 (16)	total: 428ms	remaining: 3.57s
# 107:	learn: 1.0000000	test: 0.5151515	best: 0.6363636 (16)	total: 433ms	remaining: 3.58s
# 108:	learn: 1.0000000	test: 0.5454545	best: 0.6363636 (16)	total: 438ms	remaining: 3.58s
# 109:	learn: 1.0000000	test: 0.5454545	best: 0.6363636 (16)	total: 442ms	remaining: 3.58s
# 110:	learn: 1.0000000	test: 0.5454545	best: 0.6363636 (16)	total: 447ms	remaining: 3.58s
# 111:	learn: 1.0000000	test: 0.5454545	best: 0.6363636 (16)	total: 451ms	remaining: 3.58s
# 112:	learn: 1.0000000	test: 0.5454545	best: 0.6363636 (16)	total: 455ms	remaining: 3.57s
# 113:	learn: 1.0000000	test: 0.5454545	best: 0.6363636 (16)	total: 460ms	remaining: 3.57s
# 114:	learn: 1.0000000	test: 0.5454545	best: 0.6363636 (16)	total: 464ms	remaining: 3.57s
# 115:	learn: 1.0000000	test: 0.5454545	best: 0.6363636 (16)	total: 468ms	remaining: 3.56s
# 116:	learn: 1.0000000	test: 0.5454545	best: 0.6363636 (16)	total: 471ms	remaining: 3.56s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6363636364
# bestIteration = 16
#
# Shrink model to first 17 iterations.
# ROC: 56.77%
# Accuracy: 63.64%
# Train Accuracy: 87.60%

# %% [markdown]
# ## **Random Forest**

# %%
# Random Forest
# Random Forest

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# define the parameter grid
param_grid = {
    'n_estimators': [100, 500, 1000],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt', 'log2']
}

# create the model
model = RandomForestClassifier(random_state=42)

# create the grid search object
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5, n_jobs=-1, verbose=2, scoring='accuracy')

# fit the grid search object to the data
grid_search.fit(X_train, y_train)

# print the best parameters and score
print(f"Best parameters: {grid_search.best_params_}")
print(f"Best score: {grid_search.best_score_:.2%}")
# Out:
# Fitting 5 folds for each of 243 candidates, totalling 1215 fits
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   0.3s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   0.3s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   0.3s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   0.4s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   0.3s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.1s
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   0.7s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   0.7s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   0.4s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   0.7s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   0.7s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   0.4s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   0.8s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   0.4s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   0.4s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   0.4s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.1s
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   0.4s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   0.4s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   0.4s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   0.4s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   0.4s
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   0.7s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   0.8s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   0.8s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   0.8s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   0.8s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.1s
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   0.3s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   0.3s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=   0.6s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=   0.7s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   0.3s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   0.3s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   0.3s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=   0.7s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=   0.7s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=   0.7s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.1s
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   0.3s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   0.3s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   0.3s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   0.3s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   0.3s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   0.6s
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   0.6s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   0.6s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   0.6s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   0.7s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.1s
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1000; total time=   0.5s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   0.3s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   0.3s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   0.4s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   0.3s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1000; total time=   0.6s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1000; total time=   0.7s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   0.3s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.1s
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1000; total time=   0.7s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1000; total time=   0.8s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.1s
# ...
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; total time=   0.6s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; total time=   0.6s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; total time=   0.6s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   0.6s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   0.6s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   0.6s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   0.6s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   0.6s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   0.5s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   0.6s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   0.6s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   0.6s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=1000; total time=   0.6s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=   0.6s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=   0.6s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=   0.6s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=   0.6s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=   0.6s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   0.6s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   0.6s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   0.6s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   0.5s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   0.6s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1000; total time=   0.5s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1000; total time=   0.6s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1000; total time=   0.6s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   0.4s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1000; total time=   0.6s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1000; total time=   0.6s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=1000; total time=   0.6s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=1000; total time=   0.6s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=1000; total time=   0.6s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=1000; total time=   0.7s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=1000; total time=   0.6s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   0.2s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=1000; total time=   0.5s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=1000; total time=   0.5s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=1000; total time=   0.5s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=1000; total time=   0.6s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=1000; total time=   0.6s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   0.5s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   0.6s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   0.5s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   0.5s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; total time=   0.6s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; total time=   0.5s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; total time=   0.5s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; total time=   0.5s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; total time=   0.5s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; total time=   0.5s
# Best parameters: {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}
# Best score: 55.80%
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(

# %% [markdown]
# ## **Testing Several ML Models**

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import roc_auc_score, accuracy_score, precision_score, recall_score, f1_score
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.naive_bayes import GaussianNB
import pandas as pd

# train columns not in unimportant features
# X_train = train.drop(['Target'], axis=1)
# X_train.drop(unimportant_features, axis=1, inplace=True)
# y_train = train['Target']

models = {
    'Logistic Regression Tuned': LogisticRegression(
        penalty='l2',
        C=1.0,
        solver='lbfgs',
        max_iter=1000,
        random_state=42,
        n_jobs=-1
    ),
    'Logistic Regression': LogisticRegression(),
    # 'SVC Linear': SVC(kernel='linear', probability=True),
    # 'SVC RBF': SVC(kernel='rbf', probability=True, gamma='auto', random_state=42),
    # 'SVC RBF Tuned': SVC(
    #     C=1.0,
    #     kernel='rbf',
    #     degree=3,
    #     gamma='scale',
    #     coef0=0.0,
    #     shrinking=True,
    #     probability=True,
    #     tol=0.001,
    #     cache_size=200,
    #     class_weight=None,
    #     verbose=False,
    #     max_iter=-1,
    #     decision_function_shape='ovr',
    #     break_ties=False,
    #     random_state=42
    # ),
    # 'SVC Poly': SVC(kernel='poly', probability=True, random_state=42),
    # 'SVC Poly Tuned': SVC(
    #     C=1.0,
    #     kernel='poly',
    #     degree=3,
    #     gamma='scale',
    #     coef0=0.0,
    #     shrinking=True,
    #     probability=True,
    #     tol=0.001,
    #     cache_size=200,
    #     class_weight=None,
    #     verbose=False,
    #     max_iter=-1,
    #     decision_function_shape='ovr',
    #     break_ties=False,
    #     random_state=42
    # ),
    # 'SVC Sigmoid': SVC(kernel='sigmoid', probability=True, random_state=42),
    # 'SVC Sigmoid Tuned': SVC(
    #     C=1.0,
    #     kernel='sigmoid',
    #     degree=3,
    #     gamma='scale',
    #     coef0=0.0,
    #     shrinking=True,
    #     probability=True,
    #     tol=0.001,
    #     cache_size=200,
    #     class_weight=None,
    #     verbose=False,
    #     max_iter=-1,
    #     decision_function_shape='ovr',
    #     break_ties=False,
    #     random_state=42
    # ),
    'LGBM Classifier Tuned': LGBMClassifier(
        boosting_type='gbdt',
        objective='binary',
        metric='accuracy',
        n_estimators=1000,
        max_depth=5,
        num_leaves=31,
        learning_rate=0.001,
        feature_fraction=0.8,
        bagging_fraction=0.8,
        bagging_freq=5,
        verbose=-1,
        random_state=42
    ),
    'LGBM Classifier': LGBMClassifier(),
    'CatBoost Classifier': CatBoostClassifier(verbose=False, random_seed=1),
    "CatBoost Classifier Tuned": CatBoostClassifier(
        # iterations=1000,
        # learning_rate=0.01,
        # depth=5,
        # l2_leaf_reg=3,
        bootstrap_type='Bernoulli',
        subsample=0.7,
        eval_metric='Accuracy',
        metric_period=50,
        od_type='Iter',
        od_wait=45,
        random_seed=42,
        allow_writing_files=False
    ),
    'Random Forest Classifier': RandomForestClassifier(),
    'Random Forest Classifier Tuned': RandomForestClassifier(
        n_estimators=500,
        criterion='gini',
        max_depth=5,
        min_samples_split=2,
        min_samples_leaf=1,
        min_weight_fraction_leaf=0.0,
        max_leaf_nodes=None,
        min_impurity_decrease=0.0,
        bootstrap=True,
        oob_score=True,
        n_jobs=-1,
        random_state=42,
        verbose=0,
        warm_start=False,
        class_weight=None,
        ccp_alpha=0.0,
        max_samples=None,
    ),
    'XGB Classifier': XGBClassifier(),
    'XGB Classifier Tuned': XGBClassifier(
        n_estimators=500,
        max_depth=5,
        learning_rate=0.001,
        subsample=0.7,
        colsample_bytree=0.7,
        random_state=42,
        n_jobs=-1
    )
}

losses = pd.DataFrame(columns=['model', 'Train Accuracy','Val ROC AUC', 'Val Accuracy', 'Val Precision', 'Val Recall', 'Val F1'])
preds = pd.DataFrame()

for name, model in models.items():
    print(f"Evaluating {name}")

    if model.__class__.__name__ in ['LogisticRegression', 'BaseLibSVM', 'GaussianNB', 'SVC', 'RandomForestClassifier']:
        model.fit(X_train, y_train)
    else:
        model.fit(X_train, y_train, eval_set=[(X_test, y_test)])
    y_pred = model.predict_proba(X_test)[:,1]
    train_acc = accuracy_score(y_train, model.predict_proba(X_train)[:,1].round())
    roc = roc_auc_score(y_test, y_pred)
    acc = accuracy_score(y_test, y_pred.round())
    precision = precision_score(y_test, y_pred.round())
    recall = recall_score(y_test, y_pred.round())
    f1 = f1_score(y_test, y_pred.round())

    losses = losses.append({'model': name, 
                            'Train Accuracy': train_acc,
                            'Val ROC AUC': roc, 
                            'Val Accuracy': acc,
                            'Val Precision': precision,
                            'Val Recall': recall,
                            'Val F1': f1
                            }, ignore_index=True)
    model.fit(X_train, y_train)
    preds[name] = model.predict_proba(X_train)[:,1]

losses.sort_values(by='Val Accuracy', ascending=False, inplace=True)
losses
# Out:
# Evaluating Logistic Regression Tuned
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /var/folders/5j/l7cwj9sd0c1gqp3xyv7290sm0000gn/T/ipykernel_45637/3847171394.py:162: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   losses = losses.append({'model': name,
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Evaluating Logistic Regression
# Evaluating LGBM Classifier Tuned
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /var/folders/5j/l7cwj9sd0c1gqp3xyv7290sm0000gn/T/ipykernel_45637/3847171394.py:162: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   losses = losses.append({'model': name,
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# /var/folders/5j/l7cwj9sd0c1gqp3xyv7290sm0000gn/T/ipykernel_45637/3847171394.py:162: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   losses = losses.append({'model': name,
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# Evaluating LGBM Classifier
# [LightGBM] [Info] Number of positive: 54, number of negative: 75
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000086 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 10429
# [LightGBM] [Info] Number of data points in the train set: 129, number of used features: 268
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.418605 -> initscore=-0.328504
# [LightGBM] [Info] Start training from score -0.328504
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 54, number of negative: 75
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000101 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 10429
# [LightGBM] [Info] Number of data points in the train set: 129, number of used features: 268
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.418605 -> initscore=-0.328504
# [LightGBM] [Info] Start training from score -0.328504
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Evaluating CatBoost Classifier
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# /var/folders/5j/l7cwj9sd0c1gqp3xyv7290sm0000gn/T/ipykernel_45637/3847171394.py:162: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   losses = losses.append({'model': name,
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# /var/folders/5j/l7cwj9sd0c1gqp3xyv7290sm0000gn/T/ipykernel_45637/3847171394.py:162: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   losses = losses.append({'model': name,
# Evaluating CatBoost Classifier Tuned
# Learning rate set to 0.019108
# 0:	learn: 0.6821705	test: 0.6363636	best: 0.6363636 (0)	total: 4.56ms	remaining: 4.55s
# 50:	learn: 0.9302326	test: 0.6060606	best: 0.6666667 (6)	total: 176ms	remaining: 3.27s
# Stopped by overfitting detector  (45 iterations wait)
#
# bestTest = 0.6666666667
# bestIteration = 6
#
# Shrink model to first 7 iterations.
# Warning: Overfitting detector is active, thus evaluation metric is calculated on every iteration. 'metric_period' is ignored for evaluation metric.
# /var/folders/5j/l7cwj9sd0c1gqp3xyv7290sm0000gn/T/ipykernel_45637/3847171394.py:162: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   losses = losses.append({'model': name,
# Learning rate set to 0.004297
# 0:	learn: 0.6821705	total: 5ms	remaining: 5s
# 50:	learn: 0.8759690	total: 181ms	remaining: 3.36s
# 100:	learn: 0.8992248	total: 353ms	remaining: 3.14s
# 150:	learn: 0.9069767	total: 524ms	remaining: 2.94s
# 200:	learn: 0.9069767	total: 780ms	remaining: 3.1s
# 250:	learn: 0.9302326	total: 950ms	remaining: 2.83s
# 300:	learn: 0.9534884	total: 1.12s	remaining: 2.6s
# 350:	learn: 0.9534884	total: 1.29s	remaining: 2.38s
# 400:	learn: 0.9689922	total: 1.46s	remaining: 2.18s
# 450:	learn: 0.9767442	total: 1.62s	remaining: 1.97s
# 500:	learn: 0.9767442	total: 1.79s	remaining: 1.78s
# 550:	learn: 0.9844961	total: 1.95s	remaining: 1.59s
# 600:	learn: 1.0000000	total: 2.12s	remaining: 1.41s
# 650:	learn: 1.0000000	total: 2.28s	remaining: 1.22s
# 700:	learn: 1.0000000	total: 2.45s	remaining: 1.04s
# 750:	learn: 1.0000000	total: 2.62s	remaining: 868ms
# 800:	learn: 1.0000000	total: 2.79s	remaining: 693ms
# 850:	learn: 1.0000000	total: 2.96s	remaining: 518ms
# 900:	learn: 1.0000000	total: 3.13s	remaining: 344ms
# 950:	learn: 1.0000000	total: 3.3s	remaining: 170ms
# 999:	learn: 1.0000000	total: 3.47s	remaining: 0us
# Evaluating Random Forest Classifier
# Evaluating Random Forest Classifier Tuned
# /var/folders/5j/l7cwj9sd0c1gqp3xyv7290sm0000gn/T/ipykernel_45637/3847171394.py:151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(X_train, y_train)
# /var/folders/5j/l7cwj9sd0c1gqp3xyv7290sm0000gn/T/ipykernel_45637/3847171394.py:162: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   losses = losses.append({'model': name,
# /var/folders/5j/l7cwj9sd0c1gqp3xyv7290sm0000gn/T/ipykernel_45637/3847171394.py:170: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(X_train, y_train)
# /var/folders/5j/l7cwj9sd0c1gqp3xyv7290sm0000gn/T/ipykernel_45637/3847171394.py:151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(X_train, y_train)
# /var/folders/5j/l7cwj9sd0c1gqp3xyv7290sm0000gn/T/ipykernel_45637/3847171394.py:162: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   losses = losses.append({'model': name,
# /var/folders/5j/l7cwj9sd0c1gqp3xyv7290sm0000gn/T/ipykernel_45637/3847171394.py:170: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(X_train, y_train)
# Evaluating XGB Classifier
# [0]	validation_0-logloss:0.66267
# [1]	validation_0-logloss:0.66763
# [2]	validation_0-logloss:0.68053
# [3]	validation_0-logloss:0.66046
# [4]	validation_0-logloss:0.68530
# [5]	validation_0-logloss:0.67127
# [6]	validation_0-logloss:0.67272
# [7]	validation_0-logloss:0.67433
# [8]	validation_0-logloss:0.70118
# [9]	validation_0-logloss:0.70235
# [10]	validation_0-logloss:0.71944
# [11]	validation_0-logloss:0.72192
# [12]	validation_0-logloss:0.70106
# [13]	validation_0-logloss:0.69799
# [14]	validation_0-logloss:0.70132
# [15]	validation_0-logloss:0.70146
# [16]	validation_0-logloss:0.69825
# [17]	validation_0-logloss:0.70144
# [18]	validation_0-logloss:0.70608
# [19]	validation_0-logloss:0.70946
# [20]	validation_0-logloss:0.71185
# [21]	validation_0-logloss:0.72290
# [22]	validation_0-logloss:0.72022
# [23]	validation_0-logloss:0.71485
# [24]	validation_0-logloss:0.71893
# [25]	validation_0-logloss:0.71856
# [26]	validation_0-logloss:0.71908
# [27]	validation_0-logloss:0.72114
# [28]	validation_0-logloss:0.71603
# [29]	validation_0-logloss:0.71636
# [30]	validation_0-logloss:0.71817
# [31]	validation_0-logloss:0.72518
# [32]	validation_0-logloss:0.73146
# [33]	validation_0-logloss:0.72921
# [34]	validation_0-logloss:0.74034
# [35]	validation_0-logloss:0.74430
# [36]	validation_0-logloss:0.74669
# [37]	validation_0-logloss:0.74443
# [38]	validation_0-logloss:0.74390
# [39]	validation_0-logloss:0.74052
# [40]	validation_0-logloss:0.74222
# [41]	validation_0-logloss:0.75012
# [42]	validation_0-logloss:0.75392
# [43]	validation_0-logloss:0.75485
# [44]	validation_0-logloss:0.75648
# [45]	validation_0-logloss:0.75884
# [46]	validation_0-logloss:0.76849
# [47]	validation_0-logloss:0.77096
# [48]	validation_0-logloss:0.76738
# [49]	validation_0-logloss:0.76564
# [50]	validation_0-logloss:0.76431
# [51]	validation_0-logloss:0.76845
# [52]	validation_0-logloss:0.76196
# [53]	validation_0-logloss:0.76353
# [54]	validation_0-logloss:0.75989
# [55]	validation_0-logloss:0.75927
# [56]	validation_0-logloss:0.75655
# [57]	validation_0-logloss:0.75713
# [58]	validation_0-logloss:0.75432
# [59]	validation_0-logloss:0.75422
# [60]	validation_0-logloss:0.76322
# [61]	validation_0-logloss:0.76082
# [62]	validation_0-logloss:0.76086
# [63]	validation_0-logloss:0.76213
# [64]	validation_0-logloss:0.76686
# [65]	validation_0-logloss:0.77523
# [66]	validation_0-logloss:0.77125
# [67]	validation_0-logloss:0.77164
# [68]	validation_0-logloss:0.76975
# [69]	validation_0-logloss:0.77023
# [70]	validation_0-logloss:0.76917
# [71]	validation_0-logloss:0.77055
# [72]	validation_0-logloss:0.76987
# [73]	validation_0-logloss:0.77440
# [74]	validation_0-logloss:0.77027
# [75]	validation_0-logloss:0.76827
# [76]	validation_0-logloss:0.77744
# [77]	validation_0-logloss:0.77578
# [78]	validation_0-logloss:0.77713
# [79]	validation_0-logloss:0.77660
# [80]	validation_0-logloss:0.77531
# [81]	validation_0-logloss:0.77387
# [82]	validation_0-logloss:0.77327
# [83]	validation_0-logloss:0.77413
# [84]	validation_0-logloss:0.77688
# [85]	validation_0-logloss:0.77796
# [86]	validation_0-logloss:0.77821
# [87]	validation_0-logloss:0.77576
# [88]	validation_0-logloss:0.77513
# [89]	validation_0-logloss:0.77904
# [90]	validation_0-logloss:0.77965
# [91]	validation_0-logloss:0.78444
# [92]	validation_0-logloss:0.79053
# [93]	validation_0-logloss:0.78876
# [94]	validation_0-logloss:0.78929
# [95]	validation_0-logloss:0.78781
# [96]	validation_0-logloss:0.78564
# [97]	validation_0-logloss:0.78626
# [98]	validation_0-logloss:0.78550
# [99]	validation_0-logloss:0.78688
# Evaluating XGB Classifier Tuned
# [0]	validation_0-logloss:0.68150
# [1]	validation_0-logloss:0.68154
# [2]	validation_0-logloss:0.68153
# [3]	validation_0-logloss:0.68153
# [4]	validation_0-logloss:0.68153
# [5]	validation_0-logloss:0.68158
# [6]	validation_0-logloss:0.68151
# [7]	validation_0-logloss:0.68144
# [8]	validation_0-logloss:0.68149
# [9]	validation_0-logloss:0.68143
# [10]	validation_0-logloss:0.68141
# [11]	validation_0-logloss:0.68132
# [12]	validation_0-logloss:0.68134
# [13]	validation_0-logloss:0.68129
# [14]	validation_0-logloss:0.68130
# [15]	validation_0-logloss:0.68126
# [16]	validation_0-logloss:0.68130
# [17]	validation_0-logloss:0.68125
# [18]	validation_0-logloss:0.68126
# [19]	validation_0-logloss:0.68117
# [20]	validation_0-logloss:0.68105
# [21]	validation_0-logloss:0.68103
# [22]	validation_0-logloss:0.68101
# /var/folders/5j/l7cwj9sd0c1gqp3xyv7290sm0000gn/T/ipykernel_45637/3847171394.py:162: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   losses = losses.append({'model': name,
# [23]	validation_0-logloss:0.68099
# [24]	validation_0-logloss:0.68092
# [25]	validation_0-logloss:0.68095
# [26]	validation_0-logloss:0.68084
# [27]	validation_0-logloss:0.68084
# [28]	validation_0-logloss:0.68082
# [29]	validation_0-logloss:0.68074
# [30]	validation_0-logloss:0.68074
# [31]	validation_0-logloss:0.68072
# [32]	validation_0-logloss:0.68071
# [33]	validation_0-logloss:0.68071
# [34]	validation_0-logloss:0.68059
# [35]	validation_0-logloss:0.68057
# [36]	validation_0-logloss:0.68051
# [37]	validation_0-logloss:0.68064
# [38]	validation_0-logloss:0.68062
# [39]	validation_0-logloss:0.68041
# [40]	validation_0-logloss:0.68042
# [41]	validation_0-logloss:0.68046
# [42]	validation_0-logloss:0.68046
# [43]	validation_0-logloss:0.68042
# [44]	validation_0-logloss:0.68040
# [45]	validation_0-logloss:0.68045
# [46]	validation_0-logloss:0.68045
# [47]	validation_0-logloss:0.68046
# [48]	validation_0-logloss:0.68048
# [49]	validation_0-logloss:0.68048
# [50]	validation_0-logloss:0.68048
# [51]	validation_0-logloss:0.68047
# [52]	validation_0-logloss:0.68046
# [53]	validation_0-logloss:0.68049
# [54]	validation_0-logloss:0.68054
# [55]	validation_0-logloss:0.68048
# [56]	validation_0-logloss:0.68047
# [57]	validation_0-logloss:0.68047
# [58]	validation_0-logloss:0.68054
# [59]	validation_0-logloss:0.68059
# [60]	validation_0-logloss:0.68059
# [61]	validation_0-logloss:0.68049
# [62]	validation_0-logloss:0.68050
# [63]	validation_0-logloss:0.68071
# [64]	validation_0-logloss:0.68059
# [65]	validation_0-logloss:0.68052
# [66]	validation_0-logloss:0.68047
# [67]	validation_0-logloss:0.68055
# [68]	validation_0-logloss:0.68055
# [69]	validation_0-logloss:0.68049
# [70]	validation_0-logloss:0.68047
# [71]	validation_0-logloss:0.68042
# [72]	validation_0-logloss:0.68042
# [73]	validation_0-logloss:0.68046
# [74]	validation_0-logloss:0.68043
# [75]	validation_0-logloss:0.68029
# [76]	validation_0-logloss:0.68025
# [77]	validation_0-logloss:0.68024
# [78]	validation_0-logloss:0.68021
# [79]	validation_0-logloss:0.68024
# [80]	validation_0-logloss:0.68015
# [81]	validation_0-logloss:0.68001
# [82]	validation_0-logloss:0.67992
# [83]	validation_0-logloss:0.67990
# [84]	validation_0-logloss:0.67973
# [85]	validation_0-logloss:0.67975
# [86]	validation_0-logloss:0.67964
# [87]	validation_0-logloss:0.67952
# [88]	validation_0-logloss:0.67961
# [89]	validation_0-logloss:0.67955
# [90]	validation_0-logloss:0.67943
# [91]	validation_0-logloss:0.67940
# [92]	validation_0-logloss:0.67946
# [93]	validation_0-logloss:0.67948
# [94]	validation_0-logloss:0.67934
# [95]	validation_0-logloss:0.67924
# [96]	validation_0-logloss:0.67924
# [97]	validation_0-logloss:0.67924
# [98]	validation_0-logloss:0.67921
# [99]	validation_0-logloss:0.67921
# [100]	validation_0-logloss:0.67932
# [101]	validation_0-logloss:0.67932
# [102]	validation_0-logloss:0.67932
# [103]	validation_0-logloss:0.67916
# [104]	validation_0-logloss:0.67913
# [105]	validation_0-logloss:0.67915
# [106]	validation_0-logloss:0.67907
# [107]	validation_0-logloss:0.67903
# [108]	validation_0-logloss:0.67897
# [109]	validation_0-logloss:0.67884
# [110]	validation_0-logloss:0.67876
# [111]	validation_0-logloss:0.67864
# [112]	validation_0-logloss:0.67859
# [113]	validation_0-logloss:0.67857
# [114]	validation_0-logloss:0.67857
# [115]	validation_0-logloss:0.67865
# [116]	validation_0-logloss:0.67866
# [117]	validation_0-logloss:0.67864
# [118]	validation_0-logloss:0.67863
# [119]	validation_0-logloss:0.67856
# [120]	validation_0-logloss:0.67852
# [121]	validation_0-logloss:0.67856
# [122]	validation_0-logloss:0.67857
# [123]	validation_0-logloss:0.67858
# [124]	validation_0-logloss:0.67854
# [125]	validation_0-logloss:0.67862
# [126]	validation_0-logloss:0.67856
# [127]	validation_0-logloss:0.67867
# [128]	validation_0-logloss:0.67866
# [129]	validation_0-logloss:0.67865
# [130]	validation_0-logloss:0.67863
# [131]	validation_0-logloss:0.67865
# [132]	validation_0-logloss:0.67860
# [133]	validation_0-logloss:0.67845
# [134]	validation_0-logloss:0.67842
# [135]	validation_0-logloss:0.67831
# [136]	validation_0-logloss:0.67823
# [137]	validation_0-logloss:0.67822
# [138]	validation_0-logloss:0.67818
# [139]	validation_0-logloss:0.67812
# [140]	validation_0-logloss:0.67812
# [141]	validation_0-logloss:0.67812
# [142]	validation_0-logloss:0.67806
# [143]	validation_0-logloss:0.67798
# [144]	validation_0-logloss:0.67789
# [145]	validation_0-logloss:0.67790
# [146]	validation_0-logloss:0.67795
# [147]	validation_0-logloss:0.67792
# [148]	validation_0-logloss:0.67773
# [149]	validation_0-logloss:0.67772
# [150]	validation_0-logloss:0.67775
# [151]	validation_0-logloss:0.67782
# [152]	validation_0-logloss:0.67783
# [153]	validation_0-logloss:0.67774
# [154]	validation_0-logloss:0.67780
# [155]	validation_0-logloss:0.67779
# [156]	validation_0-logloss:0.67775
# [157]	validation_0-logloss:0.67774
# [158]	validation_0-logloss:0.67761
# [159]	validation_0-logloss:0.67755
# [160]	validation_0-logloss:0.67746
# [161]	validation_0-logloss:0.67740
# [162]	validation_0-logloss:0.67720
# [163]	validation_0-logloss:0.67713
# [164]	validation_0-logloss:0.67719
# [165]	validation_0-logloss:0.67721
# [166]	validation_0-logloss:0.67720
# [167]	validation_0-logloss:0.67726
# [168]	validation_0-logloss:0.67725
# [169]	validation_0-logloss:0.67718
# [170]	validation_0-logloss:0.67719
# [171]	validation_0-logloss:0.67719
# [172]	validation_0-logloss:0.67707
# [173]	validation_0-logloss:0.67696
# [174]	validation_0-logloss:0.67694
# [175]	validation_0-logloss:0.67689
# [176]	validation_0-logloss:0.67701
# [177]	validation_0-logloss:0.67706
# [178]	validation_0-logloss:0.67702
# [179]	validation_0-logloss:0.67690
# [180]	validation_0-logloss:0.67691
# [181]	validation_0-logloss:0.67688
# [182]	validation_0-logloss:0.67689
# [183]	validation_0-logloss:0.67679
# [184]	validation_0-logloss:0.67670
# [185]	validation_0-logloss:0.67675
# [186]	validation_0-logloss:0.67672
# [187]	validation_0-logloss:0.67681
# [188]	validation_0-logloss:0.67681
# [189]	validation_0-logloss:0.67670
# [190]	validation_0-logloss:0.67670
# [191]	validation_0-logloss:0.67659
# [192]	validation_0-logloss:0.67654
# [193]	validation_0-logloss:0.67656
# [194]	validation_0-logloss:0.67658
# [195]	validation_0-logloss:0.67648
# [196]	validation_0-logloss:0.67653
# [197]	validation_0-logloss:0.67644
# [198]	validation_0-logloss:0.67640
# [199]	validation_0-logloss:0.67628
# [200]	validation_0-logloss:0.67628
# [201]	validation_0-logloss:0.67630
# [202]	validation_0-logloss:0.67633
# [203]	validation_0-logloss:0.67635
# [204]	validation_0-logloss:0.67637
# [205]	validation_0-logloss:0.67647
# [206]	validation_0-logloss:0.67643
# [207]	validation_0-logloss:0.67645
# [208]	validation_0-logloss:0.67641
# [209]	validation_0-logloss:0.67642
# [210]	validation_0-logloss:0.67630
# [211]	validation_0-logloss:0.67632
# [212]	validation_0-logloss:0.67628
# [213]	validation_0-logloss:0.67629
# [214]	validation_0-logloss:0.67624
# [215]	validation_0-logloss:0.67631
# [216]	validation_0-logloss:0.67630
# [217]	validation_0-logloss:0.67630
# [218]	validation_0-logloss:0.67651
# [219]	validation_0-logloss:0.67638
# [220]	validation_0-logloss:0.67631
# [221]	validation_0-logloss:0.67616
# [222]	validation_0-logloss:0.67618
# [223]	validation_0-logloss:0.67619
# [224]	validation_0-logloss:0.67609
# [225]	validation_0-logloss:0.67612
# [226]	validation_0-logloss:0.67614
# [227]	validation_0-logloss:0.67607
# [228]	validation_0-logloss:0.67603
# [229]	validation_0-logloss:0.67599
# [230]	validation_0-logloss:0.67593
# [231]	validation_0-logloss:0.67589
# [232]	validation_0-logloss:0.67586
# [233]	validation_0-logloss:0.67588
# [234]	validation_0-logloss:0.67587
# [235]	validation_0-logloss:0.67584
# [236]	validation_0-logloss:0.67586
# [237]	validation_0-logloss:0.67584
# [238]	validation_0-logloss:0.67589
# [239]	validation_0-logloss:0.67585
# [240]	validation_0-logloss:0.67577
# [241]	validation_0-logloss:0.67573
# [242]	validation_0-logloss:0.67574
# [243]	validation_0-logloss:0.67567
# [244]	validation_0-logloss:0.67556
# [245]	validation_0-logloss:0.67544
# [246]	validation_0-logloss:0.67537
# [247]	validation_0-logloss:0.67538
# [248]	validation_0-logloss:0.67539
# [249]	validation_0-logloss:0.67559
# [250]	validation_0-logloss:0.67561
# [251]	validation_0-logloss:0.67561
# [252]	validation_0-logloss:0.67562
# [253]	validation_0-logloss:0.67554
# [254]	validation_0-logloss:0.67554
# [255]	validation_0-logloss:0.67558
# [256]	validation_0-logloss:0.67559
# [257]	validation_0-logloss:0.67557
# [258]	validation_0-logloss:0.67552
# [259]	validation_0-logloss:0.67551
# [260]	validation_0-logloss:0.67551
# [261]	validation_0-logloss:0.67546
# [262]	validation_0-logloss:0.67543
# [263]	validation_0-logloss:0.67535
# [264]	validation_0-logloss:0.67542
# [265]	validation_0-logloss:0.67543
# [266]	validation_0-logloss:0.67545
# [267]	validation_0-logloss:0.67536
# [268]	validation_0-logloss:0.67538
# [269]	validation_0-logloss:0.67532
# [270]	validation_0-logloss:0.67532
# [271]	validation_0-logloss:0.67535
# [272]	validation_0-logloss:0.67526
# [273]	validation_0-logloss:0.67512
# [274]	validation_0-logloss:0.67517
# [275]	validation_0-logloss:0.67519
# [276]	validation_0-logloss:0.67516
# [277]	validation_0-logloss:0.67502
# [278]	validation_0-logloss:0.67497
# [279]	validation_0-logloss:0.67496
# [280]	validation_0-logloss:0.67498
# [281]	validation_0-logloss:0.67498
# [282]	validation_0-logloss:0.67481
# [283]	validation_0-logloss:0.67468
# [284]	validation_0-logloss:0.67455
# [285]	validation_0-logloss:0.67453
# [286]	validation_0-logloss:0.67447
# [287]	validation_0-logloss:0.67444
# [288]	validation_0-logloss:0.67433
# [289]	validation_0-logloss:0.67426
# [290]	validation_0-logloss:0.67425
# [291]	validation_0-logloss:0.67418
# [292]	validation_0-logloss:0.67412
# [293]	validation_0-logloss:0.67414
# [294]	validation_0-logloss:0.67404
# [295]	validation_0-logloss:0.67402
# [296]	validation_0-logloss:0.67382
# [297]	validation_0-logloss:0.67373
# [298]	validation_0-logloss:0.67361
# [299]	validation_0-logloss:0.67350
# [300]	validation_0-logloss:0.67345
# [301]	validation_0-logloss:0.67345
# [302]	validation_0-logloss:0.67349
# [303]	validation_0-logloss:0.67349
# [304]	validation_0-logloss:0.67338
# [305]	validation_0-logloss:0.67343
# [306]	validation_0-logloss:0.67339
# [307]	validation_0-logloss:0.67341
# [308]	validation_0-logloss:0.67342
# [309]	validation_0-logloss:0.67333
# [310]	validation_0-logloss:0.67329
# [311]	validation_0-logloss:0.67314
# [312]	validation_0-logloss:0.67311
# [313]	validation_0-logloss:0.67319
# [314]	validation_0-logloss:0.67313
# [315]	validation_0-logloss:0.67303
# [316]	validation_0-logloss:0.67302
# [317]	validation_0-logloss:0.67302
# [318]	validation_0-logloss:0.67302
# [319]	validation_0-logloss:0.67304
# [320]	validation_0-logloss:0.67293
# [321]	validation_0-logloss:0.67282
# [322]	validation_0-logloss:0.67274
# [323]	validation_0-logloss:0.67266
# [324]	validation_0-logloss:0.67260
# [325]	validation_0-logloss:0.67256
# [326]	validation_0-logloss:0.67249
# [327]	validation_0-logloss:0.67244
# [328]	validation_0-logloss:0.67243
# [329]	validation_0-logloss:0.67254
# [330]	validation_0-logloss:0.67256
# [331]	validation_0-logloss:0.67256
# [332]	validation_0-logloss:0.67278
# [333]	validation_0-logloss:0.67275
# [334]	validation_0-logloss:0.67285
# [335]	validation_0-logloss:0.67281
# [336]	validation_0-logloss:0.67280
# [337]	validation_0-logloss:0.67265
# [338]	validation_0-logloss:0.67267
# [339]	validation_0-logloss:0.67267
# [340]	validation_0-logloss:0.67266
# [341]	validation_0-logloss:0.67260
# [342]	validation_0-logloss:0.67260
# [343]	validation_0-logloss:0.67268
# [344]	validation_0-logloss:0.67265
# [345]	validation_0-logloss:0.67262
# [346]	validation_0-logloss:0.67282
# [347]	validation_0-logloss:0.67282
# [348]	validation_0-logloss:0.67266
# [349]	validation_0-logloss:0.67252
# [350]	validation_0-logloss:0.67246
# [351]	validation_0-logloss:0.67237
# [352]	validation_0-logloss:0.67244
# [353]	validation_0-logloss:0.67242
# [354]	validation_0-logloss:0.67236
# [355]	validation_0-logloss:0.67227
# [356]	validation_0-logloss:0.67229
# [357]	validation_0-logloss:0.67224
# [358]	validation_0-logloss:0.67221
# [359]	validation_0-logloss:0.67217
# [360]	validation_0-logloss:0.67201
# [361]	validation_0-logloss:0.67201
# [362]	validation_0-logloss:0.67205
# [363]	validation_0-logloss:0.67188
# [364]	validation_0-logloss:0.67185
# [365]	validation_0-logloss:0.67185
# [366]	validation_0-logloss:0.67183
# [367]	validation_0-logloss:0.67185
# [368]	validation_0-logloss:0.67182
# [369]	validation_0-logloss:0.67179
# [370]	validation_0-logloss:0.67172
# [371]	validation_0-logloss:0.67167
# [372]	validation_0-logloss:0.67167
# [373]	validation_0-logloss:0.67167
# [374]	validation_0-logloss:0.67165
# [375]	validation_0-logloss:0.67167
# [376]	validation_0-logloss:0.67163
# [377]	validation_0-logloss:0.67157
# [378]	validation_0-logloss:0.67145
# [379]	validation_0-logloss:0.67148
# [380]	validation_0-logloss:0.67148
# [381]	validation_0-logloss:0.67146
# [382]	validation_0-logloss:0.67142
# [383]	validation_0-logloss:0.67133
# [384]	validation_0-logloss:0.67135
# [385]	validation_0-logloss:0.67130
# [386]	validation_0-logloss:0.67120
# [387]	validation_0-logloss:0.67106
# [388]	validation_0-logloss:0.67108
# [389]	validation_0-logloss:0.67103
# [390]	validation_0-logloss:0.67105
# [391]	validation_0-logloss:0.67106
# [392]	validation_0-logloss:0.67104
# [393]	validation_0-logloss:0.67098
# [394]	validation_0-logloss:0.67099
# [395]	validation_0-logloss:0.67096
# [396]	validation_0-logloss:0.67090
# [397]	validation_0-logloss:0.67094
# [398]	validation_0-logloss:0.67091
# [399]	validation_0-logloss:0.67081
# [400]	validation_0-logloss:0.67083
# [401]	validation_0-logloss:0.67091
# [402]	validation_0-logloss:0.67096
# [403]	validation_0-logloss:0.67096
# [404]	validation_0-logloss:0.67092
# [405]	validation_0-logloss:0.67095
# [406]	validation_0-logloss:0.67091
# [407]	validation_0-logloss:0.67088
# [408]	validation_0-logloss:0.67097
# [409]	validation_0-logloss:0.67090
# [410]	validation_0-logloss:0.67088
# [411]	validation_0-logloss:0.67087
# [412]	validation_0-logloss:0.67081
# [413]	validation_0-logloss:0.67073
# [414]	validation_0-logloss:0.67068
# [415]	validation_0-logloss:0.67066
# [416]	validation_0-logloss:0.67068
# [417]	validation_0-logloss:0.67065
# [418]	validation_0-logloss:0.67045
# [419]	validation_0-logloss:0.67046
# [420]	validation_0-logloss:0.67048
# [421]	validation_0-logloss:0.67044
# [422]	validation_0-logloss:0.67048
# [423]	validation_0-logloss:0.67058
# [424]	validation_0-logloss:0.67052
# [425]	validation_0-logloss:0.67045
# [426]	validation_0-logloss:0.67043
# [427]	validation_0-logloss:0.67040
# [428]	validation_0-logloss:0.67037
# [429]	validation_0-logloss:0.67039
# [430]	validation_0-logloss:0.67038
# [431]	validation_0-logloss:0.67035
# [432]	validation_0-logloss:0.67037
# [433]	validation_0-logloss:0.67035
# [434]	validation_0-logloss:0.67037
# [435]	validation_0-logloss:0.67040
# [436]	validation_0-logloss:0.67042
# [437]	validation_0-logloss:0.67026
# [438]	validation_0-logloss:0.67024
# [439]	validation_0-logloss:0.67013
# [440]	validation_0-logloss:0.67004
# [441]	validation_0-logloss:0.66999
# [442]	validation_0-logloss:0.66995
# [443]	validation_0-logloss:0.66991
# [444]	validation_0-logloss:0.66989
# [445]	validation_0-logloss:0.66986
# [446]	validation_0-logloss:0.66986
# [447]	validation_0-logloss:0.66988
# [448]	validation_0-logloss:0.66994
# [449]	validation_0-logloss:0.66990
# [450]	validation_0-logloss:0.66980
# [451]	validation_0-logloss:0.66978
# [452]	validation_0-logloss:0.66981
# [453]	validation_0-logloss:0.66975
# [454]	validation_0-logloss:0.66968
# [455]	validation_0-logloss:0.66966
# [456]	validation_0-logloss:0.66955
# [457]	validation_0-logloss:0.66954
# [458]	validation_0-logloss:0.66954
# [459]	validation_0-logloss:0.66940
# [460]	validation_0-logloss:0.66934
# [461]	validation_0-logloss:0.66938
# [462]	validation_0-logloss:0.66937
# [463]	validation_0-logloss:0.66931
# [464]	validation_0-logloss:0.66918
# [465]	validation_0-logloss:0.66917
# [466]	validation_0-logloss:0.66911
# [467]	validation_0-logloss:0.66914
# [468]	validation_0-logloss:0.66916
# [469]	validation_0-logloss:0.66927
# [470]	validation_0-logloss:0.66924
# [471]	validation_0-logloss:0.66914
# [472]	validation_0-logloss:0.66912
# [473]	validation_0-logloss:0.66905
# [474]	validation_0-logloss:0.66901
# [475]	validation_0-logloss:0.66909
# [476]	validation_0-logloss:0.66910
# [477]	validation_0-logloss:0.66913
# [478]	validation_0-logloss:0.66908
# [479]	validation_0-logloss:0.66903
# [480]	validation_0-logloss:0.66907
# [481]	validation_0-logloss:0.66910
# [482]	validation_0-logloss:0.66912
# [483]	validation_0-logloss:0.66913
# [484]	validation_0-logloss:0.66902
# [485]	validation_0-logloss:0.66897
# [486]	validation_0-logloss:0.66903
# [487]	validation_0-logloss:0.66898
# [488]	validation_0-logloss:0.66904
# [489]	validation_0-logloss:0.66897
# [490]	validation_0-logloss:0.66900
# [491]	validation_0-logloss:0.66900
# [492]	validation_0-logloss:0.66892
# [493]	validation_0-logloss:0.66880
# [494]	validation_0-logloss:0.66867
# [495]	validation_0-logloss:0.66858
# [496]	validation_0-logloss:0.66856
# [497]	validation_0-logloss:0.66855
# [498]	validation_0-logloss:0.66861
# [499]	validation_0-logloss:0.66865
# /var/folders/5j/l7cwj9sd0c1gqp3xyv7290sm0000gn/T/ipykernel_45637/3847171394.py:162: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   losses = losses.append({'model': name,
#                             model  Train Accuracy  Val ROC AUC  Val Accuracy  \
# 5       CatBoost Classifier Tuned        0.860465     0.554511      0.666667
# 9            XGB Classifier Tuned        0.736434     0.642857      0.606061
# 0       Logistic Regression Tuned        0.620155     0.563910      0.575758
# 1             Logistic Regression        0.620155     0.563910      0.575758
# 2           LGBM Classifier Tuned        0.736434     0.620301      0.575758
# 4             CatBoost Classifier        0.875969     0.654135      0.545455
# 3                 LGBM Classifier        1.000000     0.563910      0.515152
# 8                  XGB Classifier        1.000000     0.530075      0.484848
# 6        Random Forest Classifier        1.000000     0.592105      0.454545
# 7  Random Forest Classifier Tuned        0.992248     0.500000      0.393939
#
#    Val Precision  Val Recall    Val F1
# 5       0.666667    0.428571  0.521739
# 9       1.000000    0.071429  0.133333
# 0       0.000000    0.000000  0.000000
# 1       0.000000    0.000000  0.000000
# 2       0.500000    0.571429  0.533333
# 4       0.478261    0.785714  0.594595
# 3       0.437500    0.500000  0.466667
# 8       0.384615    0.357143  0.370370
# 6       0.433333    0.928571  0.590909
# 7       0.400000    0.857143  0.545455

# %% [markdown]
# ## **Testing Several DL Models**

# %%
import tensorflow as tf
import tensorflow_addons as tfa
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import LSTM
from sklearn.metrics import roc_auc_score, accuracy_score
import seaborn as sns
import matplotlib.pyplot as plt

# define the model
nn = keras.Sequential([
    layers.Dense(64, activation='relu', input_shape=[X_train.shape[1]]),
    layers.Dense(64, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

nn_2 = keras.Sequential([
    layers.Dense(64, activation='relu', input_shape=[X_train.shape[1]]),
    layers.Dense(128, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(32, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

lstm = keras.Sequential([
    LSTM(64, input_shape=[X_train.shape[1], 1]),
    layers.Dense(64, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

lstm_2 = keras.Sequential([
    LSTM(64, input_shape=[X_train.shape[1], 1]),
    layers.Dense(128, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

# stacked lstm
lstm_3 = keras.Sequential([
    LSTM(128, input_shape=[X_train.shape[1], 1], return_sequences=True),
    LSTM(64, return_sequences=True),
    LSTM(32),
    # layers.Dense(64, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

# Stacked GRU
gru = keras.Sequential([
    layers.GRU(128, input_shape=[X_train.shape[1], 1], return_sequences=True),
    layers.GRU(64, return_sequences=True),
    layers.GRU(32),
    layers.Dense(64, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

# CNN
cnn = keras.Sequential([
    layers.Conv1D(64, 3, activation='relu', input_shape=[X_train.shape[1], 1]),
    layers.MaxPooling1D(2),
    layers.Conv1D(64, 3, activation='relu'),
    layers.MaxPooling1D(2),
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3, beta_1=0.9, beta_2=0.999)
# optimizer = tfa.optimizers.AdamW(learning_rate=5e-4, beta_1=0.9, beta_2=0.999, weight_decay=1e-6)
models = [nn, lstm, nn_2, lstm_2, lstm_3, gru, cnn]
results = {}

for i, model in list(enumerate(models)):
    # compile the model
    model.compile(
        optimizer=optimizer,
        loss='binary_crossentropy',
        metrics=['accuracy']
    )

    # train the model
    history = model.fit(
        X_train,
        y_train,
        epochs=500,
        batch_size=32,
        validation_data=(X_test, y_test),
        callbacks=[
            keras.callbacks.EarlyStopping(
                monitor='val_accuracy',
                patience=100,
                restore_best_weights=True,
                mode='max'
            ),
            keras.callbacks.ReduceLROnPlateau(
                monitor='val_accuracy',
                factor=0.1,
                patience=50,
                mode='max',
                min_lr=1e-5
            )
        ],
        shuffle=False
    )

    y_pred = model.predict(X_test)
    results[i] = {
        'model': model,
        'history': history,
        'ROC': roc_auc_score(y_test, y_pred),
        'accuracy': accuracy_score(y_test, y_pred.round())
        }
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/500
# 2023-11-06 18:48:52.662395: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 5/5 [==============================] - 1s 134ms/step - loss: 0.6897 - accuracy: 0.5891 - val_loss: 1.0795 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 2/500
# 2023-11-06 18:48:53.298687: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 5/5 [==============================] - 0s 23ms/step - loss: 0.7135 - accuracy: 0.4961 - val_loss: 1.5221 - val_accuracy: 0.4545 - lr: 0.0010
# Epoch 3/500
# 5/5 [==============================] - 0s 24ms/step - loss: 0.7106 - accuracy: 0.4496 - val_loss: 1.3237 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 4/500
# 5/5 [==============================] - 0s 28ms/step - loss: 0.6840 - accuracy: 0.5736 - val_loss: 1.3433 - val_accuracy: 0.4545 - lr: 0.0010
# Epoch 5/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.6953 - accuracy: 0.5426 - val_loss: 1.4610 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 6/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.7070 - accuracy: 0.5426 - val_loss: 1.4934 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 7/500
# 5/5 [==============================] - 0s 18ms/step - loss: 0.6990 - accuracy: 0.5659 - val_loss: 1.3974 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 8/500
# 5/5 [==============================] - 0s 18ms/step - loss: 0.6882 - accuracy: 0.5504 - val_loss: 1.3299 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 9/500
# 5/5 [==============================] - 0s 17ms/step - loss: 0.6875 - accuracy: 0.5581 - val_loss: 1.3287 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 10/500
# 5/5 [==============================] - 0s 17ms/step - loss: 0.6863 - accuracy: 0.5504 - val_loss: 1.3014 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 11/500
# 5/5 [==============================] - 0s 16ms/step - loss: 0.6806 - accuracy: 0.5581 - val_loss: 1.2297 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 12/500
# 5/5 [==============================] - 0s 16ms/step - loss: 0.6753 - accuracy: 0.5426 - val_loss: 1.1825 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 13/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6751 - accuracy: 0.5504 - val_loss: 1.1687 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 14/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6736 - accuracy: 0.5504 - val_loss: 1.1202 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 15/500
# 5/5 [==============================] - 0s 18ms/step - loss: 0.6722 - accuracy: 0.5426 - val_loss: 1.1036 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 16/500
# 5/5 [==============================] - 0s 17ms/step - loss: 0.6738 - accuracy: 0.5426 - val_loss: 1.1010 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 17/500
# 5/5 [==============================] - 0s 16ms/step - loss: 0.6726 - accuracy: 0.5504 - val_loss: 1.0566 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 18/500
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6723 - accuracy: 0.5659 - val_loss: 1.0609 - val_accuracy: 0.4545 - lr: 0.0010
# Epoch 19/500
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6729 - accuracy: 0.5581 - val_loss: 1.0357 - val_accuracy: 0.4545 - lr: 0.0010
# Epoch 20/500
# 5/5 [==============================] - 0s 18ms/step - loss: 0.6710 - accuracy: 0.5736 - val_loss: 1.0073 - val_accuracy: 0.4545 - lr: 0.0010
# Epoch 21/500
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6711 - accuracy: 0.5736 - val_loss: 1.0148 - val_accuracy: 0.4545 - lr: 0.0010
# Epoch 22/500
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6720 - accuracy: 0.5736 - val_loss: 1.0055 - val_accuracy: 0.4545 - lr: 0.0010
# Epoch 23/500
# 5/5 [==============================] - 0s 33ms/step - loss: 0.6702 - accuracy: 0.5736 - val_loss: 0.9626 - val_accuracy: 0.4545 - lr: 0.0010
# Epoch 24/500
# 5/5 [==============================] - 0s 22ms/step - loss: 0.6689 - accuracy: 0.6047 - val_loss: 0.9640 - val_accuracy: 0.4545 - lr: 0.0010
# Epoch 25/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6697 - accuracy: 0.6202 - val_loss: 0.9744 - val_accuracy: 0.4545 - lr: 0.0010
# Epoch 26/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6699 - accuracy: 0.5969 - val_loss: 0.9672 - val_accuracy: 0.4545 - lr: 0.0010
# Epoch 27/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6680 - accuracy: 0.6047 - val_loss: 0.9392 - val_accuracy: 0.4545 - lr: 0.0010
# Epoch 28/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6684 - accuracy: 0.6124 - val_loss: 0.9559 - val_accuracy: 0.4545 - lr: 0.0010
# Epoch 29/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6682 - accuracy: 0.6202 - val_loss: 0.9409 - val_accuracy: 0.4545 - lr: 0.0010
# Epoch 30/500
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6670 - accuracy: 0.6124 - val_loss: 0.9330 - val_accuracy: 0.4545 - lr: 0.0010
# Epoch 31/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6663 - accuracy: 0.6202 - val_loss: 0.9376 - val_accuracy: 0.4545 - lr: 0.0010
# Epoch 32/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6665 - accuracy: 0.6202 - val_loss: 0.9330 - val_accuracy: 0.4545 - lr: 0.0010
# Epoch 33/500
# 5/5 [==============================] - 0s 16ms/step - loss: 0.6652 - accuracy: 0.6124 - val_loss: 0.9174 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 34/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6650 - accuracy: 0.6124 - val_loss: 0.9337 - val_accuracy: 0.4545 - lr: 0.0010
# Epoch 35/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6649 - accuracy: 0.6124 - val_loss: 0.9189 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 36/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6635 - accuracy: 0.6047 - val_loss: 0.9050 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 37/500
# 5/5 [==============================] - 0s 16ms/step - loss: 0.6633 - accuracy: 0.5969 - val_loss: 0.9321 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 38/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6635 - accuracy: 0.6047 - val_loss: 0.9068 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 39/500
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6615 - accuracy: 0.5891 - val_loss: 0.9004 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 40/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6626 - accuracy: 0.6047 - val_loss: 0.9291 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 41/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6614 - accuracy: 0.5814 - val_loss: 0.8927 - val_accuracy: 0.4545 - lr: 0.0010
# Epoch 42/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6605 - accuracy: 0.5891 - val_loss: 0.9124 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 43/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6607 - accuracy: 0.6047 - val_loss: 0.8972 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 44/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6588 - accuracy: 0.6047 - val_loss: 0.8859 - val_accuracy: 0.4545 - lr: 0.0010
# Epoch 45/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6591 - accuracy: 0.5969 - val_loss: 0.8994 - val_accuracy: 0.4545 - lr: 0.0010
# Epoch 46/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6578 - accuracy: 0.5891 - val_loss: 0.8787 - val_accuracy: 0.4848 - lr: 0.0010
# Epoch 47/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6587 - accuracy: 0.5891 - val_loss: 0.9052 - val_accuracy: 0.4545 - lr: 0.0010
# Epoch 48/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6572 - accuracy: 0.5814 - val_loss: 0.8693 - val_accuracy: 0.4545 - lr: 0.0010
# Epoch 49/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6578 - accuracy: 0.6047 - val_loss: 0.8997 - val_accuracy: 0.4545 - lr: 0.0010
# Epoch 50/500
# 5/5 [==============================] - 0s 20ms/step - loss: 0.6567 - accuracy: 0.5891 - val_loss: 0.8616 - val_accuracy: 0.4545 - lr: 0.0010
# Epoch 51/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6567 - accuracy: 0.5969 - val_loss: 0.8947 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 52/500
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6563 - accuracy: 0.5969 - val_loss: 0.8652 - val_accuracy: 0.4545 - lr: 0.0010
# Epoch 53/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6559 - accuracy: 0.6047 - val_loss: 0.8891 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 54/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6548 - accuracy: 0.6047 - val_loss: 0.8622 - val_accuracy: 0.4545 - lr: 0.0010
# Epoch 55/500
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6540 - accuracy: 0.5969 - val_loss: 0.8767 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 56/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6540 - accuracy: 0.5969 - val_loss: 0.8578 - val_accuracy: 0.4545 - lr: 0.0010
# Epoch 57/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6528 - accuracy: 0.5969 - val_loss: 0.8647 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 58/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6530 - accuracy: 0.5891 - val_loss: 0.8457 - val_accuracy: 0.4545 - lr: 0.0010
# Epoch 59/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6520 - accuracy: 0.5969 - val_loss: 0.8411 - val_accuracy: 0.4545 - lr: 0.0010
# Epoch 60/500
# 5/5 [==============================] - 0s 12ms/step - loss: 0.6511 - accuracy: 0.5891 - val_loss: 0.8266 - val_accuracy: 0.4545 - lr: 0.0010
# Epoch 61/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6511 - accuracy: 0.5814 - val_loss: 0.8340 - val_accuracy: 0.4545 - lr: 0.0010
# Epoch 62/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6500 - accuracy: 0.5736 - val_loss: 0.8098 - val_accuracy: 0.4848 - lr: 0.0010
# Epoch 63/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6508 - accuracy: 0.6124 - val_loss: 0.8123 - val_accuracy: 0.4848 - lr: 0.0010
# Epoch 64/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6487 - accuracy: 0.5736 - val_loss: 0.7940 - val_accuracy: 0.4848 - lr: 0.0010
# Epoch 65/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6493 - accuracy: 0.5814 - val_loss: 0.8046 - val_accuracy: 0.4848 - lr: 0.0010
# Epoch 66/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6484 - accuracy: 0.5969 - val_loss: 0.7665 - val_accuracy: 0.4848 - lr: 0.0010
# Epoch 67/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6490 - accuracy: 0.5969 - val_loss: 0.7899 - val_accuracy: 0.4848 - lr: 0.0010
# Epoch 68/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6481 - accuracy: 0.5891 - val_loss: 0.7500 - val_accuracy: 0.5152 - lr: 0.0010
# Epoch 69/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6480 - accuracy: 0.5814 - val_loss: 0.7782 - val_accuracy: 0.4848 - lr: 0.0010
# Epoch 70/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6468 - accuracy: 0.5891 - val_loss: 0.7245 - val_accuracy: 0.5455 - lr: 0.0010
# Epoch 71/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6475 - accuracy: 0.5969 - val_loss: 0.7659 - val_accuracy: 0.5152 - lr: 0.0010
# Epoch 72/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6444 - accuracy: 0.5969 - val_loss: 0.7095 - val_accuracy: 0.5758 - lr: 0.0010
# Epoch 73/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6460 - accuracy: 0.6047 - val_loss: 0.7715 - val_accuracy: 0.5152 - lr: 0.0010
# Epoch 74/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6435 - accuracy: 0.5969 - val_loss: 0.7083 - val_accuracy: 0.5758 - lr: 0.0010
# Epoch 75/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6460 - accuracy: 0.5969 - val_loss: 0.7835 - val_accuracy: 0.4848 - lr: 0.0010
# Epoch 76/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6426 - accuracy: 0.6047 - val_loss: 0.6964 - val_accuracy: 0.5758 - lr: 0.0010
# Epoch 77/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6464 - accuracy: 0.6047 - val_loss: 0.7729 - val_accuracy: 0.5758 - lr: 0.0010
# Epoch 78/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6415 - accuracy: 0.6047 - val_loss: 0.6864 - val_accuracy: 0.5455 - lr: 0.0010
# Epoch 79/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6455 - accuracy: 0.6047 - val_loss: 0.7646 - val_accuracy: 0.5758 - lr: 0.0010
# Epoch 80/500
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6406 - accuracy: 0.6124 - val_loss: 0.6874 - val_accuracy: 0.5455 - lr: 0.0010
# Epoch 81/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6442 - accuracy: 0.5969 - val_loss: 0.7557 - val_accuracy: 0.5758 - lr: 0.0010
# Epoch 82/500
# 5/5 [==============================] - 0s 16ms/step - loss: 0.6387 - accuracy: 0.6202 - val_loss: 0.6989 - val_accuracy: 0.5455 - lr: 0.0010
# Epoch 83/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6428 - accuracy: 0.6279 - val_loss: 0.7521 - val_accuracy: 0.5758 - lr: 0.0010
# Epoch 84/500
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6375 - accuracy: 0.6047 - val_loss: 0.7093 - val_accuracy: 0.5455 - lr: 0.0010
# Epoch 85/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6410 - accuracy: 0.6202 - val_loss: 0.7346 - val_accuracy: 0.5455 - lr: 0.0010
# Epoch 86/500
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6364 - accuracy: 0.6047 - val_loss: 0.7175 - val_accuracy: 0.5758 - lr: 0.0010
# Epoch 87/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6383 - accuracy: 0.5891 - val_loss: 0.7288 - val_accuracy: 0.5455 - lr: 0.0010
# Epoch 88/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6369 - accuracy: 0.5969 - val_loss: 0.7261 - val_accuracy: 0.5758 - lr: 0.0010
# Epoch 89/500
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6378 - accuracy: 0.6124 - val_loss: 0.7209 - val_accuracy: 0.6061 - lr: 0.0010
# Epoch 90/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6343 - accuracy: 0.6202 - val_loss: 0.7327 - val_accuracy: 0.6061 - lr: 0.0010
# Epoch 91/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6349 - accuracy: 0.5969 - val_loss: 0.7088 - val_accuracy: 0.5455 - lr: 0.0010
# Epoch 92/500
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6375 - accuracy: 0.6047 - val_loss: 0.7391 - val_accuracy: 0.5758 - lr: 0.0010
# Epoch 93/500
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6324 - accuracy: 0.6124 - val_loss: 0.7180 - val_accuracy: 0.5758 - lr: 0.0010
# Epoch 94/500
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6361 - accuracy: 0.6202 - val_loss: 0.7366 - val_accuracy: 0.5455 - lr: 0.0010
# Epoch 95/500
# 5/5 [==============================] - 0s 16ms/step - loss: 0.6312 - accuracy: 0.6047 - val_loss: 0.7316 - val_accuracy: 0.5455 - lr: 0.0010
# Epoch 96/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6329 - accuracy: 0.5969 - val_loss: 0.7352 - val_accuracy: 0.5758 - lr: 0.0010
# Epoch 97/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6311 - accuracy: 0.6124 - val_loss: 0.7511 - val_accuracy: 0.5455 - lr: 0.0010
# Epoch 98/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6302 - accuracy: 0.5969 - val_loss: 0.7385 - val_accuracy: 0.5758 - lr: 0.0010
# Epoch 99/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6341 - accuracy: 0.6434 - val_loss: 0.7547 - val_accuracy: 0.5758 - lr: 0.0010
# Epoch 100/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6288 - accuracy: 0.6124 - val_loss: 0.7609 - val_accuracy: 0.5758 - lr: 0.0010
# Epoch 101/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6306 - accuracy: 0.5969 - val_loss: 0.7537 - val_accuracy: 0.5758 - lr: 0.0010
# Epoch 102/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6338 - accuracy: 0.6124 - val_loss: 0.7857 - val_accuracy: 0.5758 - lr: 0.0010
# Epoch 103/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6290 - accuracy: 0.6279 - val_loss: 0.7730 - val_accuracy: 0.5758 - lr: 0.0010
# Epoch 104/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6356 - accuracy: 0.6512 - val_loss: 0.7737 - val_accuracy: 0.6061 - lr: 0.0010
# Epoch 105/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6296 - accuracy: 0.6202 - val_loss: 0.8159 - val_accuracy: 0.5758 - lr: 0.0010
# Epoch 106/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6319 - accuracy: 0.5891 - val_loss: 0.7836 - val_accuracy: 0.6061 - lr: 0.0010
# Epoch 107/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6459 - accuracy: 0.5891 - val_loss: 0.8015 - val_accuracy: 0.5758 - lr: 0.0010
# Epoch 108/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6277 - accuracy: 0.6589 - val_loss: 0.8445 - val_accuracy: 0.5758 - lr: 0.0010
# Epoch 109/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6347 - accuracy: 0.5969 - val_loss: 0.8034 - val_accuracy: 0.5758 - lr: 0.0010
# Epoch 110/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6491 - accuracy: 0.5814 - val_loss: 0.8349 - val_accuracy: 0.5758 - lr: 0.0010
# Epoch 111/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6260 - accuracy: 0.6202 - val_loss: 0.8473 - val_accuracy: 0.6061 - lr: 0.0010
# Epoch 112/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6283 - accuracy: 0.6202 - val_loss: 0.8292 - val_accuracy: 0.6061 - lr: 0.0010
# Epoch 113/500
# 5/5 [==============================] - 0s 18ms/step - loss: 0.6322 - accuracy: 0.6124 - val_loss: 0.8630 - val_accuracy: 0.5758 - lr: 0.0010
# Epoch 114/500
# 5/5 [==============================] - 0s 17ms/step - loss: 0.6238 - accuracy: 0.6124 - val_loss: 0.8743 - val_accuracy: 0.6061 - lr: 0.0010
# Epoch 115/500
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6260 - accuracy: 0.6124 - val_loss: 0.8648 - val_accuracy: 0.5758 - lr: 0.0010
# Epoch 116/500
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6291 - accuracy: 0.6512 - val_loss: 0.9028 - val_accuracy: 0.6061 - lr: 0.0010
# Epoch 117/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6239 - accuracy: 0.6279 - val_loss: 0.9029 - val_accuracy: 0.6061 - lr: 0.0010
# Epoch 118/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6274 - accuracy: 0.6202 - val_loss: 0.8925 - val_accuracy: 0.5455 - lr: 0.0010
# Epoch 119/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6341 - accuracy: 0.5969 - val_loss: 0.9569 - val_accuracy: 0.5758 - lr: 0.0010
# Epoch 120/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6342 - accuracy: 0.6047 - val_loss: 0.9376 - val_accuracy: 0.5455 - lr: 0.0010
# Epoch 121/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6359 - accuracy: 0.6202 - val_loss: 0.9126 - val_accuracy: 0.5455 - lr: 0.0010
# Epoch 122/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6293 - accuracy: 0.5969 - val_loss: 0.9852 - val_accuracy: 0.5758 - lr: 0.0010
# Epoch 123/500
# 5/5 [==============================] - 0s 16ms/step - loss: 0.6336 - accuracy: 0.6047 - val_loss: 0.9602 - val_accuracy: 0.5455 - lr: 0.0010
# Epoch 124/500
# 5/5 [==============================] - 0s 16ms/step - loss: 0.6359 - accuracy: 0.6279 - val_loss: 0.9469 - val_accuracy: 0.5455 - lr: 0.0010
# Epoch 125/500
# 5/5 [==============================] - 0s 16ms/step - loss: 0.6244 - accuracy: 0.6202 - val_loss: 1.0120 - val_accuracy: 0.5455 - lr: 0.0010
# Epoch 126/500
# 5/5 [==============================] - 0s 17ms/step - loss: 0.6334 - accuracy: 0.6047 - val_loss: 0.9745 - val_accuracy: 0.5455 - lr: 0.0010
# Epoch 127/500
# 5/5 [==============================] - 0s 16ms/step - loss: 0.6454 - accuracy: 0.5969 - val_loss: 0.9867 - val_accuracy: 0.5455 - lr: 0.0010
# Epoch 128/500
# 5/5 [==============================] - 0s 17ms/step - loss: 0.6203 - accuracy: 0.6512 - val_loss: 1.0389 - val_accuracy: 0.5455 - lr: 0.0010
# Epoch 129/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.6300 - accuracy: 0.5814 - val_loss: 0.9870 - val_accuracy: 0.5455 - lr: 0.0010
# Epoch 130/500
# 5/5 [==============================] - 0s 16ms/step - loss: 0.6530 - accuracy: 0.5659 - val_loss: 1.0338 - val_accuracy: 0.5455 - lr: 0.0010
# Epoch 131/500
# 5/5 [==============================] - 0s 16ms/step - loss: 0.6261 - accuracy: 0.6279 - val_loss: 1.0730 - val_accuracy: 0.5455 - lr: 0.0010
# Epoch 132/500
# 5/5 [==============================] - 0s 17ms/step - loss: 0.6291 - accuracy: 0.5969 - val_loss: 1.0120 - val_accuracy: 0.5152 - lr: 0.0010
# Epoch 133/500
# 5/5 [==============================] - 0s 16ms/step - loss: 0.6422 - accuracy: 0.5891 - val_loss: 1.0634 - val_accuracy: 0.5455 - lr: 0.0010
# Epoch 134/500
# 5/5 [==============================] - 0s 17ms/step - loss: 0.6301 - accuracy: 0.6202 - val_loss: 1.0735 - val_accuracy: 0.5455 - lr: 0.0010
# Epoch 135/500
# 5/5 [==============================] - 0s 23ms/step - loss: 0.6330 - accuracy: 0.6279 - val_loss: 1.0510 - val_accuracy: 0.5152 - lr: 0.0010
# Epoch 136/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6192 - accuracy: 0.6589 - val_loss: 1.1008 - val_accuracy: 0.5152 - lr: 0.0010
# Epoch 137/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6246 - accuracy: 0.5969 - val_loss: 1.0634 - val_accuracy: 0.5152 - lr: 0.0010
# Epoch 138/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6395 - accuracy: 0.5891 - val_loss: 1.0929 - val_accuracy: 0.5152 - lr: 0.0010
# Epoch 139/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6200 - accuracy: 0.6512 - val_loss: 1.1168 - val_accuracy: 0.5152 - lr: 0.0010
# Epoch 140/500
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6241 - accuracy: 0.6124 - val_loss: 1.1125 - val_accuracy: 0.5152 - lr: 1.0000e-04
# Epoch 141/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6177 - accuracy: 0.6124 - val_loss: 1.1134 - val_accuracy: 0.5455 - lr: 1.0000e-04
# Epoch 142/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6144 - accuracy: 0.6279 - val_loss: 1.1073 - val_accuracy: 0.5455 - lr: 1.0000e-04
# Epoch 143/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6144 - accuracy: 0.6357 - val_loss: 1.0927 - val_accuracy: 0.5152 - lr: 1.0000e-04
# Epoch 144/500
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6146 - accuracy: 0.6434 - val_loss: 1.0807 - val_accuracy: 0.5455 - lr: 1.0000e-04
# Epoch 145/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6153 - accuracy: 0.6202 - val_loss: 1.0761 - val_accuracy: 0.5455 - lr: 1.0000e-04
# Epoch 146/500
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6154 - accuracy: 0.6202 - val_loss: 1.0771 - val_accuracy: 0.5455 - lr: 1.0000e-04
# Epoch 147/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6145 - accuracy: 0.6279 - val_loss: 1.0804 - val_accuracy: 0.5455 - lr: 1.0000e-04
# Epoch 148/500
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6141 - accuracy: 0.6279 - val_loss: 1.0830 - val_accuracy: 0.5455 - lr: 1.0000e-04
# Epoch 149/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6141 - accuracy: 0.6279 - val_loss: 1.0840 - val_accuracy: 0.5455 - lr: 1.0000e-04
# Epoch 150/500
# 5/5 [==============================] - 0s 16ms/step - loss: 0.6142 - accuracy: 0.6279 - val_loss: 1.0848 - val_accuracy: 0.5455 - lr: 1.0000e-04
# Epoch 151/500
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6142 - accuracy: 0.6279 - val_loss: 1.0862 - val_accuracy: 0.5455 - lr: 1.0000e-04
# Epoch 152/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6141 - accuracy: 0.6202 - val_loss: 1.0880 - val_accuracy: 0.5455 - lr: 1.0000e-04
# Epoch 153/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6139 - accuracy: 0.6279 - val_loss: 1.0893 - val_accuracy: 0.5455 - lr: 1.0000e-04
# Epoch 154/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6138 - accuracy: 0.6279 - val_loss: 1.0902 - val_accuracy: 0.5455 - lr: 1.0000e-04
# Epoch 155/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6138 - accuracy: 0.6279 - val_loss: 1.0908 - val_accuracy: 0.5455 - lr: 1.0000e-04
# Epoch 156/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6138 - accuracy: 0.6279 - val_loss: 1.0907 - val_accuracy: 0.5455 - lr: 1.0000e-04
# Epoch 157/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6138 - accuracy: 0.6202 - val_loss: 1.0911 - val_accuracy: 0.5455 - lr: 1.0000e-04
# Epoch 158/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6137 - accuracy: 0.6202 - val_loss: 1.0916 - val_accuracy: 0.5455 - lr: 1.0000e-04
# Epoch 159/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6136 - accuracy: 0.6202 - val_loss: 1.0923 - val_accuracy: 0.5455 - lr: 1.0000e-04
# Epoch 160/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6135 - accuracy: 0.6279 - val_loss: 1.0931 - val_accuracy: 0.5455 - lr: 1.0000e-04
# Epoch 161/500
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6136 - accuracy: 0.6279 - val_loss: 1.0933 - val_accuracy: 0.5455 - lr: 1.0000e-04
# Epoch 162/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6136 - accuracy: 0.6279 - val_loss: 1.0942 - val_accuracy: 0.5455 - lr: 1.0000e-04
# Epoch 163/500
# 5/5 [==============================] - 0s 20ms/step - loss: 0.6136 - accuracy: 0.6279 - val_loss: 1.0953 - val_accuracy: 0.5455 - lr: 1.0000e-04
# Epoch 164/500
# 5/5 [==============================] - 0s 22ms/step - loss: 0.6136 - accuracy: 0.6202 - val_loss: 1.0965 - val_accuracy: 0.5455 - lr: 1.0000e-04
# Epoch 165/500
# 5/5 [==============================] - 0s 16ms/step - loss: 0.6135 - accuracy: 0.6202 - val_loss: 1.0976 - val_accuracy: 0.5455 - lr: 1.0000e-04
# Epoch 166/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6134 - accuracy: 0.6279 - val_loss: 1.0990 - val_accuracy: 0.5455 - lr: 1.0000e-04
# Epoch 167/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6133 - accuracy: 0.6279 - val_loss: 1.1001 - val_accuracy: 0.5152 - lr: 1.0000e-04
# Epoch 168/500
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6133 - accuracy: 0.6279 - val_loss: 1.1006 - val_accuracy: 0.5152 - lr: 1.0000e-04
# Epoch 169/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6133 - accuracy: 0.6202 - val_loss: 1.1018 - val_accuracy: 0.5152 - lr: 1.0000e-04
# Epoch 170/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6132 - accuracy: 0.6202 - val_loss: 1.1031 - val_accuracy: 0.5152 - lr: 1.0000e-04
# Epoch 171/500
# 5/5 [==============================] - 0s 24ms/step - loss: 0.6132 - accuracy: 0.6279 - val_loss: 1.1038 - val_accuracy: 0.5152 - lr: 1.0000e-04
# Epoch 172/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6132 - accuracy: 0.6202 - val_loss: 1.1044 - val_accuracy: 0.5152 - lr: 1.0000e-04
# Epoch 173/500
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6132 - accuracy: 0.6202 - val_loss: 1.1052 - val_accuracy: 0.5152 - lr: 1.0000e-04
# Epoch 174/500
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6131 - accuracy: 0.6279 - val_loss: 1.1062 - val_accuracy: 0.5152 - lr: 1.0000e-04
# Epoch 175/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6130 - accuracy: 0.6279 - val_loss: 1.1070 - val_accuracy: 0.5152 - lr: 1.0000e-04
# Epoch 176/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6130 - accuracy: 0.6279 - val_loss: 1.1081 - val_accuracy: 0.5152 - lr: 1.0000e-04
# Epoch 177/500
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6129 - accuracy: 0.6279 - val_loss: 1.1091 - val_accuracy: 0.5152 - lr: 1.0000e-04
# Epoch 178/500
# 5/5 [==============================] - 0s 20ms/step - loss: 0.6128 - accuracy: 0.6279 - val_loss: 1.1102 - val_accuracy: 0.5152 - lr: 1.0000e-04
# Epoch 179/500
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6127 - accuracy: 0.6279 - val_loss: 1.1112 - val_accuracy: 0.5152 - lr: 1.0000e-04
# Epoch 180/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6127 - accuracy: 0.6279 - val_loss: 1.1122 - val_accuracy: 0.5152 - lr: 1.0000e-04
# Epoch 181/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6126 - accuracy: 0.6279 - val_loss: 1.1133 - val_accuracy: 0.5152 - lr: 1.0000e-04
# Epoch 182/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6126 - accuracy: 0.6279 - val_loss: 1.1144 - val_accuracy: 0.5152 - lr: 1.0000e-04
# Epoch 183/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6125 - accuracy: 0.6279 - val_loss: 1.1160 - val_accuracy: 0.5152 - lr: 1.0000e-04
# Epoch 184/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6124 - accuracy: 0.6279 - val_loss: 1.1174 - val_accuracy: 0.5152 - lr: 1.0000e-04
# Epoch 185/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6124 - accuracy: 0.6279 - val_loss: 1.1181 - val_accuracy: 0.5152 - lr: 1.0000e-04
# Epoch 186/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6123 - accuracy: 0.6279 - val_loss: 1.1197 - val_accuracy: 0.5152 - lr: 1.0000e-04
# Epoch 187/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6122 - accuracy: 0.6279 - val_loss: 1.1211 - val_accuracy: 0.5152 - lr: 1.0000e-04
# Epoch 188/500
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6122 - accuracy: 0.6279 - val_loss: 1.1218 - val_accuracy: 0.5152 - lr: 1.0000e-04
# Epoch 189/500
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6122 - accuracy: 0.6279 - val_loss: 1.1224 - val_accuracy: 0.5152 - lr: 1.0000e-04
# 2/2 [==============================] - 0s 6ms/step
# 2023-11-06 18:49:06.425922: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/500
# 2023-11-06 18:49:06.989093: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-11-06 18:49:07.137731: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 1/5 [=====>........................] - ETA: 3s - loss: 0.6930 - accuracy: 0.5000
# 2023-11-06 18:49:07.322588: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 5/5 [==============================] - ETA: 0s - loss: 0.6886 - accuracy: 0.5659
# 2023-11-06 18:49:07.888171: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-11-06 18:49:07.951695: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 5/5 [==============================] - 2s 175ms/step - loss: 0.6886 - accuracy: 0.5659 - val_loss: 0.6819 - val_accuracy: 0.5758 - lr: 0.0010
# Epoch 2/500
# 5/5 [==============================] - 0s 50ms/step - loss: 0.6824 - accuracy: 0.5814 - val_loss: 0.6850 - val_accuracy: 0.5758 - lr: 0.0010
# Epoch 3/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.6855 - accuracy: 0.5814 - val_loss: 0.6887 - val_accuracy: 0.5758 - lr: 0.0010
# Epoch 4/500
# 5/5 [==============================] - 0s 47ms/step - loss: 0.6895 - accuracy: 0.5814 - val_loss: 0.6923 - val_accuracy: 0.5455 - lr: 0.0010
# Epoch 5/500
# 5/5 [==============================] - 0s 36ms/step - loss: 0.6935 - accuracy: 0.4806 - val_loss: 0.6960 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 6/500
# 5/5 [==============================] - 0s 44ms/step - loss: 0.6975 - accuracy: 0.4109 - val_loss: 0.6992 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 7/500
# 5/5 [==============================] - 0s 38ms/step - loss: 0.7012 - accuracy: 0.4186 - val_loss: 0.7022 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 8/500
# 5/5 [==============================] - 0s 37ms/step - loss: 0.7045 - accuracy: 0.4186 - val_loss: 0.7043 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 9/500
# 5/5 [==============================] - 0s 38ms/step - loss: 0.7067 - accuracy: 0.4186 - val_loss: 0.7055 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 10/500
# 5/5 [==============================] - 0s 36ms/step - loss: 0.7081 - accuracy: 0.4186 - val_loss: 0.7065 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 11/500
# 5/5 [==============================] - 0s 36ms/step - loss: 0.7092 - accuracy: 0.4186 - val_loss: 0.7073 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 12/500
# 5/5 [==============================] - 0s 35ms/step - loss: 0.7102 - accuracy: 0.4186 - val_loss: 0.7078 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 13/500
# 5/5 [==============================] - 0s 36ms/step - loss: 0.7105 - accuracy: 0.4186 - val_loss: 0.7076 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 14/500
# 5/5 [==============================] - 0s 34ms/step - loss: 0.7104 - accuracy: 0.4109 - val_loss: 0.7073 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 15/500
# 5/5 [==============================] - 0s 41ms/step - loss: 0.7101 - accuracy: 0.4186 - val_loss: 0.7069 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 16/500
# 5/5 [==============================] - 0s 36ms/step - loss: 0.7095 - accuracy: 0.4109 - val_loss: 0.7065 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 17/500
# 5/5 [==============================] - 0s 33ms/step - loss: 0.7090 - accuracy: 0.4109 - val_loss: 0.7062 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 18/500
# 5/5 [==============================] - 0s 38ms/step - loss: 0.7086 - accuracy: 0.4109 - val_loss: 0.7060 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 19/500
# 5/5 [==============================] - 0s 35ms/step - loss: 0.7079 - accuracy: 0.3953 - val_loss: 0.7050 - val_accuracy: 0.4545 - lr: 0.0010
# Epoch 20/500
# 5/5 [==============================] - 0s 33ms/step - loss: 0.7061 - accuracy: 0.4186 - val_loss: 0.7030 - val_accuracy: 0.4848 - lr: 0.0010
# Epoch 21/500
# 5/5 [==============================] - 0s 36ms/step - loss: 0.7034 - accuracy: 0.4651 - val_loss: 0.7003 - val_accuracy: 0.5758 - lr: 0.0010
# Epoch 22/500
# 5/5 [==============================] - 0s 32ms/step - loss: 0.7002 - accuracy: 0.5271 - val_loss: 0.6983 - val_accuracy: 0.5455 - lr: 0.0010
# Epoch 23/500
# 5/5 [==============================] - 0s 35ms/step - loss: 0.6956 - accuracy: 0.5194 - val_loss: 0.7124 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 24/500
# 5/5 [==============================] - 0s 36ms/step - loss: 0.6966 - accuracy: 0.5194 - val_loss: 0.7500 - val_accuracy: 0.2424 - lr: 0.0010
# Epoch 25/500
# 5/5 [==============================] - 0s 35ms/step - loss: 0.7102 - accuracy: 0.4574 - val_loss: 0.7745 - val_accuracy: 0.3030 - lr: 0.0010
# Epoch 26/500
# 5/5 [==============================] - 0s 35ms/step - loss: 0.6742 - accuracy: 0.5891 - val_loss: 0.7123 - val_accuracy: 0.4848 - lr: 0.0010
# Epoch 27/500
# 5/5 [==============================] - 0s 33ms/step - loss: 0.7279 - accuracy: 0.5504 - val_loss: 0.7112 - val_accuracy: 0.4848 - lr: 0.0010
# Epoch 28/500
# 5/5 [==============================] - 0s 34ms/step - loss: 0.7027 - accuracy: 0.5581 - val_loss: 0.7073 - val_accuracy: 0.4848 - lr: 0.0010
# Epoch 29/500
# 5/5 [==============================] - 0s 39ms/step - loss: 0.7009 - accuracy: 0.5426 - val_loss: 0.7053 - val_accuracy: 0.5152 - lr: 0.0010
# Epoch 30/500
# 5/5 [==============================] - 0s 35ms/step - loss: 0.6995 - accuracy: 0.5426 - val_loss: 0.7058 - val_accuracy: 0.4545 - lr: 0.0010
# Epoch 31/500
# 5/5 [==============================] - 0s 34ms/step - loss: 0.6994 - accuracy: 0.5504 - val_loss: 0.7073 - val_accuracy: 0.4848 - lr: 0.0010
# Epoch 32/500
# 5/5 [==============================] - 0s 35ms/step - loss: 0.6990 - accuracy: 0.5504 - val_loss: 0.7092 - val_accuracy: 0.4545 - lr: 0.0010
# Epoch 33/500
# 5/5 [==============================] - 0s 34ms/step - loss: 0.6988 - accuracy: 0.5581 - val_loss: 0.7146 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 34/500
# 5/5 [==============================] - 0s 32ms/step - loss: 0.7001 - accuracy: 0.5736 - val_loss: 0.7255 - val_accuracy: 0.4545 - lr: 0.0010
# Epoch 35/500
# 5/5 [==============================] - 0s 35ms/step - loss: 0.7027 - accuracy: 0.5814 - val_loss: 0.7515 - val_accuracy: 0.4545 - lr: 0.0010
# Epoch 36/500
# 5/5 [==============================] - 0s 33ms/step - loss: 0.7083 - accuracy: 0.5504 - val_loss: 0.7731 - val_accuracy: 0.3939 - lr: 0.0010
# Epoch 37/500
# 5/5 [==============================] - 0s 35ms/step - loss: 0.7157 - accuracy: 0.5194 - val_loss: 0.7747 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 38/500
# 5/5 [==============================] - 0s 32ms/step - loss: 0.7223 - accuracy: 0.5194 - val_loss: 0.7856 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 39/500
# 5/5 [==============================] - 0s 33ms/step - loss: 0.7112 - accuracy: 0.5116 - val_loss: 0.8074 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 40/500
# 5/5 [==============================] - 0s 35ms/step - loss: 0.7349 - accuracy: 0.4729 - val_loss: 0.7951 - val_accuracy: 0.3030 - lr: 0.0010
# Epoch 41/500
# 5/5 [==============================] - 0s 33ms/step - loss: 0.6924 - accuracy: 0.5116 - val_loss: 0.7910 - val_accuracy: 0.3636 - lr: 0.0010
# Epoch 42/500
# 5/5 [==============================] - 0s 35ms/step - loss: 0.7487 - accuracy: 0.5194 - val_loss: 0.7824 - val_accuracy: 0.3636 - lr: 0.0010
# Epoch 43/500
# 5/5 [==============================] - 0s 32ms/step - loss: 0.6937 - accuracy: 0.5271 - val_loss: 0.8030 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 44/500
# 5/5 [==============================] - 0s 34ms/step - loss: 0.7093 - accuracy: 0.5349 - val_loss: 0.8021 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 45/500
# 5/5 [==============================] - 0s 33ms/step - loss: 0.6953 - accuracy: 0.5426 - val_loss: 0.8111 - val_accuracy: 0.3636 - lr: 0.0010
# Epoch 46/500
# 5/5 [==============================] - 0s 32ms/step - loss: 0.6881 - accuracy: 0.5426 - val_loss: 0.8301 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 47/500
# 5/5 [==============================] - 0s 32ms/step - loss: 0.7374 - accuracy: 0.4884 - val_loss: 0.8023 - val_accuracy: 0.2121 - lr: 0.0010
# Epoch 48/500
# 5/5 [==============================] - 0s 34ms/step - loss: 0.7324 - accuracy: 0.4961 - val_loss: 0.8145 - val_accuracy: 0.3030 - lr: 0.0010
# Epoch 49/500
# 5/5 [==============================] - 0s 33ms/step - loss: 0.7153 - accuracy: 0.5736 - val_loss: 0.6922 - val_accuracy: 0.5152 - lr: 0.0010
# Epoch 50/500
# 5/5 [==============================] - 0s 33ms/step - loss: 0.9126 - accuracy: 0.4806 - val_loss: 0.8734 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 51/500
# 5/5 [==============================] - 0s 34ms/step - loss: 0.7873 - accuracy: 0.4884 - val_loss: 0.7980 - val_accuracy: 0.5758 - lr: 0.0010
# Epoch 52/500
# 5/5 [==============================] - 0s 36ms/step - loss: 0.7763 - accuracy: 0.5814 - val_loss: 0.7459 - val_accuracy: 0.5758 - lr: 1.0000e-04
# Epoch 53/500
# 5/5 [==============================] - 0s 41ms/step - loss: 0.7225 - accuracy: 0.5814 - val_loss: 0.6979 - val_accuracy: 0.5758 - lr: 1.0000e-04
# Epoch 54/500
# 5/5 [==============================] - 0s 33ms/step - loss: 0.6857 - accuracy: 0.5814 - val_loss: 0.6815 - val_accuracy: 0.5758 - lr: 1.0000e-04
# Epoch 55/500
# 5/5 [==============================] - 0s 35ms/step - loss: 0.6805 - accuracy: 0.5814 - val_loss: 0.6905 - val_accuracy: 0.5758 - lr: 1.0000e-04
# Epoch 56/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.6954 - accuracy: 0.4496 - val_loss: 0.7078 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 57/500
# 5/5 [==============================] - 0s 35ms/step - loss: 0.7135 - accuracy: 0.4186 - val_loss: 0.7211 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 58/500
# 5/5 [==============================] - 0s 34ms/step - loss: 0.7253 - accuracy: 0.4186 - val_loss: 0.7265 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 59/500
# 5/5 [==============================] - 0s 34ms/step - loss: 0.7289 - accuracy: 0.4186 - val_loss: 0.7256 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 60/500
# 5/5 [==============================] - 0s 35ms/step - loss: 0.7267 - accuracy: 0.4186 - val_loss: 0.7214 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 61/500
# 5/5 [==============================] - 0s 33ms/step - loss: 0.7219 - accuracy: 0.4186 - val_loss: 0.7162 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 62/500
# 5/5 [==============================] - 0s 35ms/step - loss: 0.7166 - accuracy: 0.4186 - val_loss: 0.7116 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 63/500
# 5/5 [==============================] - 0s 32ms/step - loss: 0.7120 - accuracy: 0.4186 - val_loss: 0.7080 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 64/500
# 5/5 [==============================] - 0s 35ms/step - loss: 0.7085 - accuracy: 0.4186 - val_loss: 0.7055 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 65/500
# 5/5 [==============================] - 0s 35ms/step - loss: 0.7062 - accuracy: 0.4186 - val_loss: 0.7040 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 66/500
# 5/5 [==============================] - 0s 33ms/step - loss: 0.7048 - accuracy: 0.4186 - val_loss: 0.7032 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 67/500
# 5/5 [==============================] - 0s 33ms/step - loss: 0.7041 - accuracy: 0.4186 - val_loss: 0.7030 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 68/500
# 5/5 [==============================] - 0s 33ms/step - loss: 0.7039 - accuracy: 0.4186 - val_loss: 0.7030 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 69/500
# 5/5 [==============================] - 0s 32ms/step - loss: 0.7041 - accuracy: 0.4186 - val_loss: 0.7033 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 70/500
# 5/5 [==============================] - 0s 33ms/step - loss: 0.7043 - accuracy: 0.4186 - val_loss: 0.7036 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 71/500
# 5/5 [==============================] - 0s 34ms/step - loss: 0.7047 - accuracy: 0.4186 - val_loss: 0.7039 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 72/500
# 5/5 [==============================] - 0s 36ms/step - loss: 0.7050 - accuracy: 0.4186 - val_loss: 0.7042 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 73/500
# 5/5 [==============================] - 0s 32ms/step - loss: 0.7053 - accuracy: 0.4186 - val_loss: 0.7044 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 74/500
# 5/5 [==============================] - 0s 41ms/step - loss: 0.7055 - accuracy: 0.4186 - val_loss: 0.7045 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 75/500
# 5/5 [==============================] - 0s 37ms/step - loss: 0.7056 - accuracy: 0.4186 - val_loss: 0.7046 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 76/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.7057 - accuracy: 0.4186 - val_loss: 0.7047 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 77/500
# 5/5 [==============================] - 0s 40ms/step - loss: 0.7057 - accuracy: 0.4186 - val_loss: 0.7047 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 78/500
# 5/5 [==============================] - 0s 34ms/step - loss: 0.7057 - accuracy: 0.4186 - val_loss: 0.7047 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 79/500
# 5/5 [==============================] - 0s 34ms/step - loss: 0.7057 - accuracy: 0.4186 - val_loss: 0.7047 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 80/500
# 5/5 [==============================] - 0s 36ms/step - loss: 0.7057 - accuracy: 0.4186 - val_loss: 0.7046 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 81/500
# 5/5 [==============================] - 0s 35ms/step - loss: 0.7057 - accuracy: 0.4186 - val_loss: 0.7046 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 82/500
# 5/5 [==============================] - 0s 34ms/step - loss: 0.7056 - accuracy: 0.4186 - val_loss: 0.7046 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 83/500
# 5/5 [==============================] - 0s 36ms/step - loss: 0.7056 - accuracy: 0.4186 - val_loss: 0.7046 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 84/500
# 5/5 [==============================] - 0s 32ms/step - loss: 0.7056 - accuracy: 0.4186 - val_loss: 0.7046 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 85/500
# 5/5 [==============================] - 0s 35ms/step - loss: 0.7056 - accuracy: 0.4186 - val_loss: 0.7046 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 86/500
# 5/5 [==============================] - 0s 35ms/step - loss: 0.7056 - accuracy: 0.4186 - val_loss: 0.7046 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 87/500
# 5/5 [==============================] - 0s 33ms/step - loss: 0.7056 - accuracy: 0.4186 - val_loss: 0.7045 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 88/500
# 5/5 [==============================] - 0s 34ms/step - loss: 0.7056 - accuracy: 0.4186 - val_loss: 0.7045 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 89/500
# 5/5 [==============================] - 0s 35ms/step - loss: 0.7056 - accuracy: 0.4186 - val_loss: 0.7045 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 90/500
# 5/5 [==============================] - 0s 35ms/step - loss: 0.7056 - accuracy: 0.4186 - val_loss: 0.7045 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 91/500
# 5/5 [==============================] - 0s 35ms/step - loss: 0.7056 - accuracy: 0.4186 - val_loss: 0.7045 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 92/500
# 5/5 [==============================] - 0s 34ms/step - loss: 0.7056 - accuracy: 0.4186 - val_loss: 0.7045 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 93/500
# 5/5 [==============================] - 0s 35ms/step - loss: 0.7056 - accuracy: 0.4186 - val_loss: 0.7045 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 94/500
# 5/5 [==============================] - 0s 34ms/step - loss: 0.7056 - accuracy: 0.4186 - val_loss: 0.7045 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 95/500
# 5/5 [==============================] - 0s 32ms/step - loss: 0.7056 - accuracy: 0.4186 - val_loss: 0.7045 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 96/500
# 5/5 [==============================] - 0s 34ms/step - loss: 0.7056 - accuracy: 0.4186 - val_loss: 0.7045 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 97/500
# 5/5 [==============================] - 0s 35ms/step - loss: 0.7056 - accuracy: 0.4186 - val_loss: 0.7045 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 98/500
# 5/5 [==============================] - 0s 32ms/step - loss: 0.7056 - accuracy: 0.4186 - val_loss: 0.7045 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 99/500
# 5/5 [==============================] - 0s 37ms/step - loss: 0.7056 - accuracy: 0.4186 - val_loss: 0.7045 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 100/500
# 5/5 [==============================] - 0s 37ms/step - loss: 0.7056 - accuracy: 0.4186 - val_loss: 0.7045 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 101/500
# 5/5 [==============================] - 0s 34ms/step - loss: 0.7056 - accuracy: 0.4186 - val_loss: 0.7045 - val_accuracy: 0.4242 - lr: 1.0000e-04
# 2/2 [==============================] - 0s 30ms/step
# 2023-11-06 18:49:25.624431: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-11-06 18:49:25.667216: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/500
# 2023-11-06 18:49:25.972458: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 5/5 [==============================] - 1s 108ms/step - loss: 0.6779 - accuracy: 0.5969 - val_loss: 1.2286 - val_accuracy: 0.3939 - lr: 0.0010
# Epoch 2/500
# ...
# 5/5 [==============================] - 1s 154ms/step - loss: 0.6856 - accuracy: 0.5814 - val_loss: 0.6751 - val_accuracy: 0.6061 - lr: 0.0010
# Epoch 2/500
# 5/5 [==============================] - 0s 34ms/step - loss: 0.6901 - accuracy: 0.5116 - val_loss: 0.8090 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 3/500
# 5/5 [==============================] - 0s 32ms/step - loss: 0.7237 - accuracy: 0.4186 - val_loss: 0.8845 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 4/500
# 5/5 [==============================] - 0s 29ms/step - loss: 0.7336 - accuracy: 0.4186 - val_loss: 0.8658 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 5/500
# 5/5 [==============================] - 0s 26ms/step - loss: 0.7200 - accuracy: 0.4186 - val_loss: 0.8240 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 6/500
# 5/5 [==============================] - 0s 18ms/step - loss: 0.7076 - accuracy: 0.4496 - val_loss: 0.8026 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 7/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6991 - accuracy: 0.5271 - val_loss: 0.7945 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 8/500
# 5/5 [==============================] - 0s 18ms/step - loss: 0.6949 - accuracy: 0.5039 - val_loss: 0.8089 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 9/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.6946 - accuracy: 0.4884 - val_loss: 0.8273 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 10/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6900 - accuracy: 0.5116 - val_loss: 0.8102 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 11/500
# 5/5 [==============================] - 0s 22ms/step - loss: 0.6861 - accuracy: 0.5426 - val_loss: 0.8366 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 12/500
# 5/5 [==============================] - 0s 21ms/step - loss: 0.6857 - accuracy: 0.5426 - val_loss: 0.8650 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 13/500
# 5/5 [==============================] - 0s 25ms/step - loss: 0.6860 - accuracy: 0.5426 - val_loss: 0.9078 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 14/500
# 5/5 [==============================] - 0s 17ms/step - loss: 0.6857 - accuracy: 0.5349 - val_loss: 0.9358 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 15/500
# 5/5 [==============================] - 0s 16ms/step - loss: 0.6811 - accuracy: 0.5581 - val_loss: 0.9431 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 16/500
# 5/5 [==============================] - 0s 16ms/step - loss: 0.6810 - accuracy: 0.5504 - val_loss: 0.9868 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 17/500
# 5/5 [==============================] - 0s 22ms/step - loss: 0.6789 - accuracy: 0.5504 - val_loss: 1.0022 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 18/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6753 - accuracy: 0.5581 - val_loss: 1.0170 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 19/500
# 5/5 [==============================] - 0s 18ms/step - loss: 0.6716 - accuracy: 0.5581 - val_loss: 1.0294 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 20/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6663 - accuracy: 0.5814 - val_loss: 1.0215 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 21/500
# 5/5 [==============================] - 0s 16ms/step - loss: 0.6622 - accuracy: 0.6124 - val_loss: 1.0176 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 22/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6587 - accuracy: 0.6279 - val_loss: 1.0076 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 23/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6575 - accuracy: 0.6357 - val_loss: 1.0768 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 24/500
# 5/5 [==============================] - 0s 18ms/step - loss: 0.6540 - accuracy: 0.6202 - val_loss: 1.0548 - val_accuracy: 0.4545 - lr: 0.0010
# Epoch 25/500
# 5/5 [==============================] - 0s 18ms/step - loss: 0.6501 - accuracy: 0.6589 - val_loss: 1.0354 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 26/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6514 - accuracy: 0.6279 - val_loss: 1.1766 - val_accuracy: 0.4545 - lr: 0.0010
# Epoch 27/500
# 5/5 [==============================] - 0s 16ms/step - loss: 0.6452 - accuracy: 0.6434 - val_loss: 1.0755 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 28/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6444 - accuracy: 0.6434 - val_loss: 1.1284 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 29/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6410 - accuracy: 0.6667 - val_loss: 1.1368 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 30/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6378 - accuracy: 0.6744 - val_loss: 1.1209 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 31/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6375 - accuracy: 0.6744 - val_loss: 1.2269 - val_accuracy: 0.4545 - lr: 0.0010
# Epoch 32/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6332 - accuracy: 0.6899 - val_loss: 1.1050 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 33/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6335 - accuracy: 0.6744 - val_loss: 1.2479 - val_accuracy: 0.4545 - lr: 0.0010
# Epoch 34/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6310 - accuracy: 0.6744 - val_loss: 1.1643 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 35/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6278 - accuracy: 0.6899 - val_loss: 1.2386 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 36/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6252 - accuracy: 0.6744 - val_loss: 1.1761 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 37/500
# 5/5 [==============================] - 0s 16ms/step - loss: 0.6238 - accuracy: 0.6667 - val_loss: 1.2154 - val_accuracy: 0.3939 - lr: 0.0010
# Epoch 38/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6191 - accuracy: 0.6667 - val_loss: 1.1696 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 39/500
# 5/5 [==============================] - 0s 16ms/step - loss: 0.6169 - accuracy: 0.6744 - val_loss: 1.1758 - val_accuracy: 0.3939 - lr: 0.0010
# Epoch 40/500
# 5/5 [==============================] - 0s 16ms/step - loss: 0.6150 - accuracy: 0.6822 - val_loss: 1.1528 - val_accuracy: 0.3939 - lr: 0.0010
# Epoch 41/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6117 - accuracy: 0.6822 - val_loss: 1.1440 - val_accuracy: 0.3939 - lr: 0.0010
# Epoch 42/500
# 5/5 [==============================] - 0s 16ms/step - loss: 0.6094 - accuracy: 0.6744 - val_loss: 1.1090 - val_accuracy: 0.3939 - lr: 0.0010
# Epoch 43/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6109 - accuracy: 0.6822 - val_loss: 1.2308 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 44/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6060 - accuracy: 0.6899 - val_loss: 1.1616 - val_accuracy: 0.3939 - lr: 0.0010
# Epoch 45/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6050 - accuracy: 0.6822 - val_loss: 1.2533 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 46/500
# 5/5 [==============================] - 0s 16ms/step - loss: 0.5980 - accuracy: 0.7054 - val_loss: 1.1528 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 47/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5961 - accuracy: 0.6822 - val_loss: 1.3447 - val_accuracy: 0.4545 - lr: 0.0010
# Epoch 48/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5973 - accuracy: 0.7054 - val_loss: 1.0093 - val_accuracy: 0.3939 - lr: 0.0010
# Epoch 49/500
# 5/5 [==============================] - 0s 16ms/step - loss: 0.6114 - accuracy: 0.6589 - val_loss: 1.4402 - val_accuracy: 0.4545 - lr: 0.0010
# Epoch 50/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6107 - accuracy: 0.6822 - val_loss: 0.8791 - val_accuracy: 0.4242 - lr: 0.0010
# Epoch 51/500
# 5/5 [==============================] - 0s 16ms/step - loss: 0.5872 - accuracy: 0.6744 - val_loss: 1.3911 - val_accuracy: 0.4545 - lr: 0.0010
# Epoch 52/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6037 - accuracy: 0.6977 - val_loss: 1.3095 - val_accuracy: 0.4545 - lr: 1.0000e-04
# Epoch 53/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5857 - accuracy: 0.6899 - val_loss: 1.1613 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 54/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5734 - accuracy: 0.6977 - val_loss: 1.0507 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 55/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5736 - accuracy: 0.7054 - val_loss: 1.0090 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 56/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5751 - accuracy: 0.6977 - val_loss: 1.0285 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 57/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5730 - accuracy: 0.6899 - val_loss: 1.0774 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 58/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5708 - accuracy: 0.7209 - val_loss: 1.1243 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 59/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5702 - accuracy: 0.7054 - val_loss: 1.1475 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 60/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5699 - accuracy: 0.7054 - val_loss: 1.1480 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 61/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5694 - accuracy: 0.7132 - val_loss: 1.1397 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 62/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5688 - accuracy: 0.7209 - val_loss: 1.1358 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 63/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5682 - accuracy: 0.7287 - val_loss: 1.1385 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 64/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5676 - accuracy: 0.7287 - val_loss: 1.1448 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 65/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5671 - accuracy: 0.7287 - val_loss: 1.1480 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 66/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5666 - accuracy: 0.7287 - val_loss: 1.1477 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 67/500
# 5/5 [==============================] - 0s 20ms/step - loss: 0.5661 - accuracy: 0.7287 - val_loss: 1.1511 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 68/500
# 5/5 [==============================] - 0s 19ms/step - loss: 0.5656 - accuracy: 0.7287 - val_loss: 1.1534 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 69/500
# 5/5 [==============================] - 0s 16ms/step - loss: 0.5651 - accuracy: 0.7287 - val_loss: 1.1525 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 70/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5646 - accuracy: 0.7209 - val_loss: 1.1573 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 71/500
# 5/5 [==============================] - 0s 16ms/step - loss: 0.5641 - accuracy: 0.7209 - val_loss: 1.1567 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 72/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5637 - accuracy: 0.7209 - val_loss: 1.1550 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 73/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5632 - accuracy: 0.7209 - val_loss: 1.1590 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 74/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5627 - accuracy: 0.7209 - val_loss: 1.1628 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 75/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5623 - accuracy: 0.7209 - val_loss: 1.1637 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 76/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5618 - accuracy: 0.7209 - val_loss: 1.1685 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 77/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5613 - accuracy: 0.7209 - val_loss: 1.1707 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 78/500
# 5/5 [==============================] - 0s 16ms/step - loss: 0.5609 - accuracy: 0.7209 - val_loss: 1.1736 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 79/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5605 - accuracy: 0.7209 - val_loss: 1.1760 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 80/500
# 5/5 [==============================] - 0s 16ms/step - loss: 0.5599 - accuracy: 0.7209 - val_loss: 1.1746 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 81/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5595 - accuracy: 0.7132 - val_loss: 1.1794 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 82/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5590 - accuracy: 0.7209 - val_loss: 1.1843 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 83/500
# 5/5 [==============================] - 0s 16ms/step - loss: 0.5585 - accuracy: 0.7209 - val_loss: 1.1922 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 84/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5581 - accuracy: 0.7209 - val_loss: 1.1903 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 85/500
# 5/5 [==============================] - 0s 23ms/step - loss: 0.5576 - accuracy: 0.7209 - val_loss: 1.1903 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 86/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5570 - accuracy: 0.7209 - val_loss: 1.1935 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 87/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5565 - accuracy: 0.7132 - val_loss: 1.1960 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 88/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5560 - accuracy: 0.7209 - val_loss: 1.1918 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 89/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5555 - accuracy: 0.7287 - val_loss: 1.1938 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 90/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5550 - accuracy: 0.7209 - val_loss: 1.2015 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 91/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5545 - accuracy: 0.7209 - val_loss: 1.2020 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 92/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5540 - accuracy: 0.7209 - val_loss: 1.1930 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 93/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5535 - accuracy: 0.7287 - val_loss: 1.1917 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 94/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5530 - accuracy: 0.7209 - val_loss: 1.2050 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 95/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5524 - accuracy: 0.7209 - val_loss: 1.2102 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 96/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5519 - accuracy: 0.7209 - val_loss: 1.2015 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 97/500
# 5/5 [==============================] - 0s 16ms/step - loss: 0.5514 - accuracy: 0.7209 - val_loss: 1.1972 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 98/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5509 - accuracy: 0.7287 - val_loss: 1.2074 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 99/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5503 - accuracy: 0.7132 - val_loss: 1.2080 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 100/500
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5498 - accuracy: 0.7132 - val_loss: 1.2120 - val_accuracy: 0.4242 - lr: 1.0000e-04
# Epoch 101/500
# 5/5 [==============================] - 0s 16ms/step - loss: 0.5493 - accuracy: 0.7209 - val_loss: 1.2116 - val_accuracy: 0.4242 - lr: 1.0000e-04
# 2/2 [==============================] - 0s 37ms/step
# 2023-11-06 18:51:15.729150: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.

# %%
# print train, val loss and accuracy
for i, result in results.items():
    print(f"Model {i}")
    print(f"Val ROC: {result['ROC']:.2%}")
    print(f"Val Accuracy: {result['accuracy']:.2%}")
    print(f"Train Accuracy: {accuracy_score(y_train, results[i]['model'].predict(X_train).round()):.2%}")
    print()
# Out:
# Model 0
# Val ROC: 65.41%
# Val Accuracy: 60.61%
# 5/5 [==============================] - 0s 3ms/step
# Train Accuracy: 62.02%
#
# Model 1
# Val ROC: 58.65%
# Val Accuracy: 57.58%
# 5/5 [==============================] - 0s 21ms/step
# Train Accuracy: 58.14%
#
# Model 2
# Val ROC: 61.28%
# Val Accuracy: 66.67%
# 5/5 [==============================] - 0s 3ms/step
# Train Accuracy: 48.84%
#
# Model 3
# Val ROC: 54.51%
# Val Accuracy: 63.64%
# 5/5 [==============================] - 0s 14ms/step
# Train Accuracy: 48.06%
#
# Model 4
# Val ROC: 59.40%
# Val Accuracy: 57.58%
# 5/5 [==============================] - 0s 30ms/step
# Train Accuracy: 58.14%
#
# Model 5
# Val ROC: 53.76%
# Val Accuracy: 57.58%
# 5/5 [==============================] - 0s 22ms/step
# Train Accuracy: 58.14%
#
# Model 6
# Val ROC: 60.15%
# Val Accuracy: 60.61%
# 5/5 [==============================] - 0s 5ms/step
# Train Accuracy: 58.14%

# %%
n_rows = len(models)
fig, axs = plt.subplots(n_rows, 2, figsize=(12, 4 * n_rows))
sns.set_palette("Set1")
for i, col in enumerate(models):
    sns.lineplot(results[i]['history'].history['loss'], ax=axs[i, 0])
    sns.lineplot(results[i]['history'].history['val_loss'], ax=axs[i, 0])
    axs[i, 0].set_title(f'Mocdl {i} Loss', fontsize=14)
    axs[i, 0].set_xlabel('Epoch', fontsize=12)
    axs[i, 0].set_ylabel('Loss', fontsize=12)
    axs[i, 0].legend(['train', 'val'], loc='upper right')
    sns.despine()

    sns.lineplot(results[i]['history'].history['accuracy'], ax=axs[i, 1])
    sns.lineplot(results[i]['history'].history['val_accuracy'], ax=axs[i, 1])
    axs[i, 1].set_title(f'Model {i} Accuracy', fontsize=14)
    axs[i, 1].set_xlabel('Epoch', fontsize=12)
    axs[i, 1].set_ylabel('Accuracy', fontsize=12)
    axs[i, 1].legend(['train', 'val'], loc='lower right')
    sns.despine()

fig.tight_layout()

plt.show()

# %%
# create an empty array to store the predicted probabilities of each model
ensemble_preds = np.zeros((X_test.shape[0], len(models)))

# loop through each model and get the predicted probabilities
for i, (name, model) in enumerate(models.items()):
    ensemble_preds[:, i] = model.predict_proba(X_test)[:, 1]

# take the average of the predicted probabilities for each sample
ensemble_preds_mean = np.mean(ensemble_preds, axis=1)

# print the ROC AUC score and accuracy of the ensemble model
ensemble_roc_auc = roc_auc_score(y_test, ensemble_preds_mean)
ensemble_accuracy = accuracy_score(y_test, np.round(ensemble_preds_mean))
print(f"Ensemble ROC AUC: {ensemble_roc_auc}")
print(f"Ensemble Accuracy: {ensemble_accuracy}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/cristianleo/Documents/GitHub/capstone-columbia/models/models.ipynb Cell 23 line 5
#       <a href='vscode-notebook-cell:/Users/cristianleo/Documents/GitHub/capstone-columbia/models/models.ipynb#Y152sZmlsZQ%3D%3D?line=1'>2</a> ensemble_preds = np.zeros((X_test.shape[0], len(models)))
#       <a href='vscode-notebook-cell:/Users/cristianleo/Documents/GitHub/capstone-columbia/models/models.ipynb#Y152sZmlsZQ%3D%3D?line=3'>4</a> # loop through each model and get the predicted probabilities
# ----> <a href='vscode-notebook-cell:/Users/cristianleo/Documents/GitHub/capstone-columbia/models/models.ipynb#Y152sZmlsZQ%3D%3D?line=4'>5</a> for i, (name, model) in enumerate(models.items()):
#       <a href='vscode-notebook-cell:/Users/cristianleo/Documents/GitHub/capstone-columbia/models/models.ipynb#Y152sZmlsZQ%3D%3D?line=5'>6</a>     ensemble_preds[:, i] = model.predict_proba(X_test)[:, 1]
#       <a href='vscode-notebook-cell:/Users/cristianleo/Documents/GitHub/capstone-columbia/models/models.ipynb#Y152sZmlsZQ%3D%3D?line=7'>8</a> # take the average of the predicted probabilities for each sample
#
# AttributeError: 'list' object has no attribute 'items'

# %% [markdown]
# # **VIF Analysis**

# %%
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# create a new dataframe with only the independent variables
X = df.drop(['Target'], axis=1)
# add a constant to the independent variables
X = sm.add_constant(X)

# calculate VIF for each independent variable
vif = pd.DataFrame()
vif["variables"] = X.columns
vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif.sort_values(by='VIF', ascending=False, inplace=True)

# print the VIF dataframe
print(vif)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/cristianleo/Documents/GitHub/capstone-columbia/models/models.ipynb Cell 29 line 1
#      <a href='vscode-notebook-cell:/Users/cristianleo/Documents/GitHub/capstone-columbia/models/models.ipynb#X53sZmlsZQ%3D%3D?line=9'>10</a> vif = pd.DataFrame()
#      <a href='vscode-notebook-cell:/Users/cristianleo/Documents/GitHub/capstone-columbia/models/models.ipynb#X53sZmlsZQ%3D%3D?line=10'>11</a> vif["variables"] = X.columns
# ---> <a href='vscode-notebook-cell:/Users/cristianleo/Documents/GitHub/capstone-columbia/models/models.ipynb#X53sZmlsZQ%3D%3D?line=11'>12</a> vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
#      <a href='vscode-notebook-cell:/Users/cristianleo/Documents/GitHub/capstone-columbia/models/models.ipynb#X53sZmlsZQ%3D%3D?line=12'>13</a> vif.sort_values(by='VIF', ascending=False, inplace=True)
#      <a href='vscode-notebook-cell:/Users/cristianleo/Documents/GitHub/capstone-columbia/models/models.ipynb#X53sZmlsZQ%3D%3D?line=14'>15</a> # print the VIF dataframe
#
# /Users/cristianleo/Documents/GitHub/capstone-columbia/models/models.ipynb Cell 29 line 1
#      <a href='vscode-notebook-cell:/Users/cristianleo/Documents/GitHub/capstone-columbia/models/models.ipynb#X53sZmlsZQ%3D%3D?line=9'>10</a> vif = pd.DataFrame()
#      <a href='vscode-notebook-cell:/Users/cristianleo/Documents/GitHub/capstone-columbia/models/models.ipynb#X53sZmlsZQ%3D%3D?line=10'>11</a> vif["variables"] = X.columns
# ---> <a href='vscode-notebook-cell:/Users/cristianleo/Documents/GitHub/capstone-columbia/models/models.ipynb#X53sZmlsZQ%3D%3D?line=11'>12</a> vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
#      <a href='vscode-notebook-cell:/Users/cristianleo/Documents/GitHub/capstone-columbia/models/models.ipynb#X53sZmlsZQ%3D%3D?line=12'>13</a> vif.sort_values(by='VIF', ascending=False, inplace=True)
#      <a href='vscode-notebook-cell:/Users/cristianleo/Documents/GitHub/capstone-columbia/models/models.ipynb#X53sZmlsZQ%3D%3D?line=14'>15</a> # print the VIF dataframe
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/statsmodels/stats/outliers_influence.py:197, in variance_inflation_factor(exog, exog_idx)
#     195 mask = np.arange(k_vars) != exog_idx
#     196 x_noti = exog[:, mask]
# --> 197 r_squared_i = OLS(x_i, x_noti).fit().rsquared
#     198 vif = 1. / (1. - r_squared_i)
#     199 return vif
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:922, in OLS.__init__(self, endog, exog, missing, hasconst, **kwargs)
#     919     msg = ("Weights are not supported in OLS and will be ignored"
#     920            "An exception will be raised in the next version.")
#     921     warnings.warn(msg, ValueWarning)
# --> 922 super(OLS, self).__init__(endog, exog, missing=missing,
#     923                           hasconst=hasconst, **kwargs)
#     924 if "weights" in self._init_keys:
#     925     self._init_keys.remove("weights")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:748, in WLS.__init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     746 else:
#     747     weights = weights.squeeze()
# --> 748 super(WLS, self).__init__(endog, exog, missing=missing,
#     749                           weights=weights, hasconst=hasconst, **kwargs)
#     750 nobs = self.exog.shape[0]
#     751 weights = self.weights
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:202, in RegressionModel.__init__(self, endog, exog, **kwargs)
#     201 def __init__(self, endog, exog, **kwargs):
# --> 202     super(RegressionModel, self).__init__(endog, exog, **kwargs)
#     203     self.pinv_wexog: Float64Array | None = None
#     204     self._data_attr.extend(['pinv_wexog', 'wendog', 'wexog', 'weights'])
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/statsmodels/base/model.py:270, in LikelihoodModel.__init__(self, endog, exog, **kwargs)
#     269 def __init__(self, endog, exog=None, **kwargs):
# --> 270     super().__init__(endog, exog, **kwargs)
#     271     self.initialize()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/statsmodels/base/model.py:95, in Model.__init__(self, endog, exog, **kwargs)
#      93 missing = kwargs.pop('missing', 'none')
#      94 hasconst = kwargs.pop('hasconst', None)
# ---> 95 self.data = self._handle_data(endog, exog, missing, hasconst,
#      96                               **kwargs)
#      97 self.k_constant = self.data.k_constant
#      98 self.exog = self.data.exog
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/statsmodels/base/model.py:135, in Model._handle_data(self, endog, exog, missing, hasconst, **kwargs)
#     134 def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# --> 135     data = handle_data(endog, exog, missing, hasconst, **kwargs)
#     136     # kwargs arrays could have changed, easier to just attach here
#     137     for key in kwargs:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/statsmodels/base/data.py:675, in handle_data(endog, exog, missing, hasconst, **kwargs)
#     672     exog = np.asarray(exog)
#     674 klass = handle_data_class_factory(endog, exog)
# --> 675 return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
#     676              **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/statsmodels/base/data.py:88, in ModelData.__init__(self, endog, exog, missing, hasconst, **kwargs)
#      86 self.const_idx = None
#      87 self.k_constant = 0
# ---> 88 self._handle_constant(hasconst)
#      89 self._check_integrity()
#      90 self._cache = {}
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/statsmodels/base/data.py:133, in ModelData._handle_constant(self, hasconst)
#     131 check_implicit = False
#     132 exog_max = np.max(self.exog, axis=0)
# --> 133 if not np.isfinite(exog_max).all():
#     134     raise MissingDataError('exog contains inf or nans')
#     135 exog_min = np.min(self.exog, axis=0)
#
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
import xgboost as xgb
import lightgbm as lgb
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import pandas as pd
import numpy as np

def test_models(X_train, X_test, y_train, y_test):
    params = {'random_state': 42}
    models = [LogisticRegression(**params), 
              SVC(**params), 
              RandomForestClassifier(**params, max_depth=5, n_jobs=-1, n_estimators=1000), 
            #   GaussianNB(), 
            #   DecisionTreeClassifier(**params, max_depth=5),
              xgb.XGBClassifier(**params, objective='binary:logistic', max_depth=5, n_jobs=-1, n_estimators=1000),
              lgb.LGBMClassifier(**params, objective='binary', metric='binary_logloss', n_jobs=-1, max_depth=5, n_estimators=1000),
              # LSTM(X_train.values, y_train.values, X_test.values, y_test.values)
              ]
    
    
    scores = pd.DataFrame(columns=['Model', 'Train Accuracy', 'Test Accuracy', 'Precision', 'Recall', 'F1'])
    for model in models:
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        model_name = model.__class__.__name__
        train_loss = model.score(X_train, y_train)
        val_loss = accuracy_score(y_test, y_pred)
        precision = precision_score(y_test, y_pred)
        recall = recall_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)
        scores = scores.append({'Model': model_name, 'Train Accuracy': train_loss, 'Test Accuracy': val_loss, 'Precision': precision, 'Recall': recall, 'F1': f1}, ignore_index=True)
    return scores
    
scores = test_models(X_train, X_test, y_train, y_test)
scores
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /var/folders/5j/l7cwj9sd0c1gqp3xyv7290sm0000gn/T/ipykernel_91972/294152675.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   scores = scores.append({'Model': model_name, 'Train Accuracy': train_loss, 'Test Accuracy': val_loss, 'Precision': precision, 'Recall': recall, 'F1': f1}, ignore_index=True)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /var/folders/5j/l7cwj9sd0c1gqp3xyv7290sm0000gn/T/ipykernel_91972/294152675.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   scores = scores.append({'Model': model_name, 'Train Accuracy': train_loss, 'Test Accuracy': val_loss, 'Precision': precision, 'Recall': recall, 'F1': f1}, ignore_index=True)
# /var/folders/5j/l7cwj9sd0c1gqp3xyv7290sm0000gn/T/ipykernel_91972/294152675.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   scores = scores.append({'Model': model_name, 'Train Accuracy': train_loss, 'Test Accuracy': val_loss, 'Precision': precision, 'Recall': recall, 'F1': f1}, ignore_index=True)
# /var/folders/5j/l7cwj9sd0c1gqp3xyv7290sm0000gn/T/ipykernel_91972/294152675.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   scores = scores.append({'Model': model_name, 'Train Accuracy': train_loss, 'Test Accuracy': val_loss, 'Precision': precision, 'Recall': recall, 'F1': f1}, ignore_index=True)
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Info] Number of positive: 50, number of negative: 72
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000203 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 8370
# [LightGBM] [Info] Number of data points in the train set: 122, number of used features: 252
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.409836 -> initscore=-0.364643
# [LightGBM] [Info] Start training from score -0.364643
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# /var/folders/5j/l7cwj9sd0c1gqp3xyv7290sm0000gn/T/ipykernel_91972/294152675.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   scores = scores.append({'Model': model_name, 'Train Accuracy': train_loss, 'Test Accuracy': val_loss, 'Precision': precision, 'Recall': recall, 'F1': f1}, ignore_index=True)
#                     Model  Train Accuracy  Test Accuracy  Precision    Recall  \
# 0      LogisticRegression        0.770492       0.709677   1.000000  0.307692
# 1                     SVC        0.622951       0.580645   0.000000  0.000000
# 2  RandomForestClassifier        0.983607       0.451613   0.433333  1.000000
# 3           XGBClassifier        1.000000       0.580645   0.500000  0.230769
# 4          LGBMClassifier        1.000000       0.580645   0.500000  0.307692
#
#          F1
# 0  0.470588
# 1  0.000000
# 2  0.604651
# 3  0.315789
# 4  0.380952
